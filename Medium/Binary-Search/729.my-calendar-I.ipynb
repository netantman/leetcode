# %% [markdown]
# ## Attempt 1 - Wrong Answer

# %%
class MyCalendar:

    def __init__(self):
        self.timestamps=[]
        

    def book(self, start: int, end: int) -> bool:
        if end<start:
            return True  ## --> this arrangment is weird...
        
        if len(self.timestamps)<1:
            self.timestamps.append(start)
            self.timestamps.append(end)
            return True
        else:
            if end<=self.timestamps[0]:
                self.timestamps=[start, end]+self.timestamps
                return True
            elif start<=self.timestamps[0]:
                return False
            if start>=self.timestamps[-1]:
                self.timestamps.append(start)
                self.timestamps.append(end)
                return True
            elif end>self.timestamps[-1]:
                return False
           
            L=len(self.timestamps)
            left, right=0, L-1
            while left<right-1:
                mid=(left+right)//2
                if self.timestamps[mid]<=start:
                    left=mid
                else:
                    right=mid
            if left%2==0:
                if end==start and start==self.timestamps[left]:
                    self.timestamps=self.timestamps[:left+1]+[start,end]+self.timestamps[right:]
                    return True
                else:
                    return False
            elif end>right: ## --> typo
                return False
            else:
                self.timestamps=self.timestamps[:left+1]+[start,end]+self.timestamps[right:]
                return True
                
                
            


# Your MyCalendar object will be instantiated and called as such:
# obj = MyCalendar()
# param_1 = obj.book(start,end)

# %% [markdown]
# ## Attempt 2 - Accepted

# %%
class MyCalendar:

    def __init__(self):
        self.timestamps=[]
        

    def book(self, start: int, end: int) -> bool:
        if end<start:
            return True  ## --> this arrangment is weird...
        
        if len(self.timestamps)<1:
            self.timestamps.append(start)
            self.timestamps.append(end)
            return True
        else:
            if end<=self.timestamps[0]:
                self.timestamps=[start, end]+self.timestamps
                return True
            elif start<=self.timestamps[0]:
                return False
            if start>=self.timestamps[-1]:
                self.timestamps.append(start)
                self.timestamps.append(end)
                return True
            elif end>self.timestamps[-1]:
                return False
           
            L=len(self.timestamps)
            left, right=0, L-1
            while left<right-1:
                mid=(left+right)//2
                if self.timestamps[mid]<=start:
                    left=mid
                else:
                    right=mid
            if left%2==0:
                if end==start and start==self.timestamps[left]:
                    self.timestamps=self.timestamps[:left+1]+[start,end]+self.timestamps[right:]
                    return True
                else:
                    return False
            elif end>self.timestamps[right]:
                return False
            else:
                self.timestamps=self.timestamps[:left+1]+[start,end]+self.timestamps[right:]
                return True
                
                
            


# Your MyCalendar object will be instantiated and called as such:
# obj = MyCalendar()
# param_1 = obj.book(start,end)

# %% [markdown]
# ## Lessons and Thoughts
# - Many edge cases
#     - If the interval degenerate to a point
#     - It the interval is an empty set - the arrangement is weird.
# - It seems that in binary search, confusing `idx` and `nums[idx]` is a mistake you tend to make a lot.
