# %% [markdown]
# ## Attempt 1 - Time Limit Exceeded

# %%
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
        
        L = len(s3)
        L1, L2 = len(s1), len(s2)
        if L != L1 + L2:
            return False
        
        if L1 < 1:
            return s2 == s3
        if L2 < 1:
            return s1 == s3
        
        dp = [[] for _ in s3]
        if s1[0] == s3[0]:
            dp[0].append((0, -1))
        if s2[0] == s3[0]:
            dp[0].append((-1, 0))
        
        
        for idx in range(1, L):
            prev = dp[idx - 1]
            for idx1, idx2 in prev:
                if idx1 + 1 < L1 and s1[idx1 + 1] == s3[idx]:
                    dp[idx].append((idx1 + 1, idx2))
                if idx2 + 1 < L2 and s2[idx2 + 1] == s3[idx]:
                    dp[idx].append((idx1, idx2 + 1))
        return len(dp[-1]) > 0

# %% [markdown]
# ## Attempt 2 - Accepted

# %%
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
        
        L = len(s3)
        L1, L2 = len(s1), len(s2)
        if L != L1 + L2:
            return False
        
        if L1 < 1:
            return s2 == s3
        if L2 < 1:
            return s1 == s3
        
        dp = [set([]) for _ in s3]
        if s1[0] == s3[0]:
            dp[0].add((0, -1))
        if s2[0] == s3[0]:
            dp[0].add((-1, 0))
        
        
        for idx in range(1, L):
            prev = dp[idx - 1]
            for idx1, idx2 in prev:
                if idx1 + 1 < L1 and s1[idx1 + 1] == s3[idx]:
                    dp[idx].add((idx1 + 1, idx2))
                if idx2 + 1 < L2 and s2[idx2 + 1] == s3[idx]:
                    dp[idx].add((idx1, idx2 + 1))
        return len(dp[-1]) > 0

# %% [markdown]
# ## Attempt 3 - Time Limit Exceeded

# %%
class Solution {
public:
    int L1;
    int L2;
    int L3;
    string s1;
    string s2;
    string s3;
    bool inner(int p1, int p2, int p3) {
        if (p1 == this->L1) {
            return (this->s2.substr(p2, this->L2 - p2) == this->s3.substr(p3, this->L3 - p3));
        }
        if (p2 == this->L2) {
            return (this->s1.substr(p1, this->L1 - p1) == this->s3.substr(p3, this->L3 - p3));
        }
        if (p3 == this->L3) {
            return false;
        }
        
        if (this->s1[p1] == this->s3[p3]) {
            if (inner(p1 + 1, p2, p3 + 1)) {
                return true;
            }
        }
        
        if (this->s2[p2] == this->s3[p3]) {
            if (inner(p1, p2 + 1, p3 + 1)) {
                return true;
            }            
        }
        
        return false;
        
    }
    bool isInterleave(string s1, string s2, string s3) {
        this->L1 = s1.size();
        this->L2 = s2.size();
        this->L3 = s3.size();
        this->s1 = s1;
        this->s2 = s2;
        this->s3 = s3;
        
        if (this->L3 != this->L1 + this->L2) {
            return false;
        }
        
        return this->inner(0, 0, 0);
    }
};

# %% [markdown]
# ## Attempt 4 - Accepted

# %%
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
#         L1, L2, L3 = len(s1), len(s2), len(s3)
#         if L1 + L2 != L3:
#             return False
        
#         stk = [(0, 0, 0)]
#         visited = set([(0, 0, 0)])
        
#         while stk:
#             p1, p2, p3 = stk[-1]
            
#             if p1 == L1:
#                 return s2[p2:] == s3[p3:]
            
#             if p2 == L2:
#                 return s1[p1:] == s3[p3:]
            
#             if s1[p1] == s3[p3] and (p1 + 1, p2, p3 + 1) not in visited:
#                 stk.append((p1 + 1, p2, p3 + 1))
#                 continue
            
#             if s2[p2] == s3[p3] and (p1, p2 + 1, p3 + 1) not in visited:
#                 stk.append((p1, p2 + 1, p3 + 1))
#                 continue
            
#             stk.pop(-1)
            
        # return False
        
        R, C, L = len(s1), len(s2), len(s3)
        if R + C != L:
            return False
        
        dp = [[False for _ in range(C + 1)] for _ in range(R + 1)]
        
        dp[0][0] = True
        for r in range(1, R + 1):
            dp[r][0] = (s1[:r] == s3[:r])
        for c in range(1, C + 1):
            dp[0][c] = (s2[:c] == s3[:c])
        
        for r in range(1, R + 1):
            for c in range(1, C + 1):
                # if r == R:
                #     dp[r][c] = dp[r][c - 1] and (s2[c] == s3[r + c])
                #     continue
                # if c == C:
                #     dp[r][c] = dp[r - 1][c] and (s1[r] == s3[r + c])
                #     continue
                
                if s1[r - 1] == s3[r - 1 + c]:
                    dp[r][c] = dp[r][c] or dp[r - 1][c]
                if s2[c - 1] == s3[r + c - 1]:
                    dp[r][c] = dp[r][c] or dp[r][c - 1]
        
        return dp[-1][-1]

# %% [markdown]
# ## Lessons and Thoughts
# - There are many duplicates in `dp`.
# - Attempt 2 is a sequence dp, and it is probably too tricky to think of during interviews. Another probably more straightforward dp idea is probably do two-dimensional dp, where `dp[i][j]` means whether `s3[:i+j]` can be interleaved by `s1[:i]` and `s2[:j]`: Attempt 4 is such approach.
