# %% [markdown]
# ## Attempt 1 - Wrong Answer

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        n1,n2=[],[]
        curr=l1
        while l1 is not None:
            n1.append(l1.val)
            l1=l1.next
        while l2 is not None:
            n2.append(l2.val)
            l2=l2.next
        carry=0
        res=""
        while len(n1)>0 and len(n2)>0:
            num1=int(n1.pop(-1))
            num2=int(n2.pop(-1))
            curr=num1+num2+carry
            if curr>=10:
                res=str(curr-10)+res
                carry=1
            else:
                res=str(curr)+res
                carry=0
        while len(n1)>0:
            num1=int(n1.pop(-1))
            curr=num1+carry
            if curr>=10:
                res=str(curr-10)+res
                carry=1
            else:
                res=str(curr)+res
                carry=0
        while len(n2)>0:
            num1=int(n2.pop(-1))  ##  --> typo!!!
            curr=num2+carry
            if curr>=10:
                res=str(curr-10)+res
                carry=1
            else:
                res=str(curr)+res
                carry=0
        if carry>0:
            res="1"+res
        
        zero=ListNode()
        curr=zero
        for c in res:
            curr.next=ListNode(val=c)
            curr=curr.next
        return zero.next

# %% [markdown]
# ## Attempt 2 - Accepted

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        n1,n2=[],[]
        curr=l1
        while l1 is not None:
            n1.append(l1.val)
            l1=l1.next
        while l2 is not None:
            n2.append(l2.val)
            l2=l2.next
        carry=0
        res=""
        while len(n1)>0 and len(n2)>0:
            num1=int(n1.pop(-1))
            num2=int(n2.pop(-1))
            curr=num1+num2+carry
            if curr>=10:
                res=str(curr-10)+res
                carry=1
            else:
                res=str(curr)+res
                carry=0
        while len(n1)>0:
            num1=int(n1.pop(-1))
            curr=num1+carry
            if curr>=10:
                res=str(curr-10)+res
                carry=1
            else:
                res=str(curr)+res
                carry=0
        while len(n2)>0:
            num2=int(n2.pop(-1))
            curr=num2+carry
            if curr>=10:
                res=str(curr-10)+res
                carry=1
            else:
                res=str(curr)+res
                carry=0
        if carry>0:
            res="1"+res
        
        zero=ListNode()
        curr=zero
        for c in res:
            curr.next=ListNode(val=c)
            curr=curr.next
        return zero.next

# %% [markdown]
# ## Lessons and Thoughts
# - Very similar to Problem 2 - just be very careful how you copy!
