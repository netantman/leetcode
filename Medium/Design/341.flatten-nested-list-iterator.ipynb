# %% [markdown]
# ## Attempt 1 - Wrong Answer

# %%
# """
# This is the interface that allows for creating nested lists.
# You should not implement it, or speculate about its implementation
# """
#class NestedInteger:
#    def isInteger(self) -> bool:
#        """
#        @return True if this NestedInteger holds a single integer, rather than a nested list.
#        """
#
#    def getInteger(self) -> int:
#        """
#        @return the single integer that this NestedInteger holds, if it holds a single integer
#        Return None if this NestedInteger holds a nested list
#        """
#
#    def getList(self) -> [NestedInteger]:
#        """
#        @return the nested list that this NestedInteger holds, if it holds a nested list
#        Return None if this NestedInteger holds a single integer
#        """

class NestedIterator:
    def __init__(self, nestedList: [NestedInteger]):
        self.nested=nestedList
        self.head=None
    
    def next(self) -> int:
        if self.head is None:
            self.head=self.nested.pop(0)
            #self.nested=self.nested[1:]
            
        if self.head.isInteger():
            res=self.head.getInteger()
            self.head=None
            return res
        else:
            curr=self.head.getList()
            tip=curr[0]
            while not tip.isInteger():
                self.nested=curr[1:]+self.nested
                curr=tip.getList()
                tip=curr[0]
            self.nested=curr[1:]+self.nested
            self.head=None
            return curr[0]
            
    def hasNext(self) -> bool:
        flag=self.head is not None  ## --> head can be an empty list instead of None
        flag=flag or len(self.nested)>0
        return flag
         

# Your NestedIterator object will be instantiated and called as such:
# i, v = NestedIterator(nestedList), []
# while i.hasNext(): v.append(i.next())

# %% [markdown]
# ## Attempt 2 - Wrong Answer

# %%
# """
# This is the interface that allows for creating nested lists.
# You should not implement it, or speculate about its implementation
# """
#class NestedInteger:
#    def isInteger(self) -> bool:
#        """
#        @return True if this NestedInteger holds a single integer, rather than a nested list.
#        """
#
#    def getInteger(self) -> int:
#        """
#        @return the single integer that this NestedInteger holds, if it holds a single integer
#        Return None if this NestedInteger holds a nested list
#        """
#
#    def getList(self) -> [NestedInteger]:
#        """
#        @return the nested list that this NestedInteger holds, if it holds a nested list
#        Return None if this NestedInteger holds a single integer
#        """

class NestedIterator:
    def __init__(self, nestedList: [NestedInteger]):
        self.nested=nestedList
        if len(self.nested)>0:
            self.head=self.nested.pop(0)
        else:
            self.head=None
    
    def next(self) -> int:
            
        if self.head.isInteger():
            res=self.head.getInteger()
            if len(self.nested)>0:
                self.head=self.nested.pop(0)
            else:
                self.head=None
            return res
        else:
            curr=self.head.getList()
            tip=curr[0]
            self.nested=curr[1:]+self.nested
            while not tip.isInteger():
                curr=tip.getList()
                tip=curr.pop(0)
                self.nested=curr+self.nested
            if len(self.nested)>0:
                self.head=self.nested.pop(0)
            else:
                self.head=None
            return tip
            
    def hasNext(self) -> bool:
        if self.head is None:
            return False
        if self.head.isInteger():
            return True
        else:
            if len(self.nested)>0:
                while len(self.nested)>0:
                    curr=self.head.getList()
                    if len(curr)<1:
                        return False
                    tip=curr.pop(0)
                    self.nested=curr+self.nested
                    while not tip.isInteger():
                        curr=tip.getList()
                        if len(curr)<1:
                            return False
                        tip=curr[0]
                        self.nested=curr[1:]+self.nested
                    self.head=tip
                    return True
            else:
                curr=self.head.getList()
                if len(curr)<1:
                    return False
                tip=curr.pop(0)
                self.nested=curr+self.nested
                while not tip.isInteger():
                    curr=tip.getList()
                    if len(curr)<1:
                        return False
                    tip=curr[0]
                    self.nested=curr[1:]+self.nested
                self.head=tip
                return True

            
            
        
         

# Your NestedIterator object will be instantiated and called as such:
# i, v = NestedIterator(nestedList), []
# while i.hasNext(): v.append(i.next())

# %% [markdown]
# ## Attempt 3 - Accepted

# %%
# """
# This is the interface that allows for creating nested lists.
# You should not implement it, or speculate about its implementation
# """
#class NestedInteger:
#    def isInteger(self) -> bool:
#        """
#        @return True if this NestedInteger holds a single integer, rather than a nested list.
#        """
#
#    def getInteger(self) -> int:
#        """
#        @return the single integer that this NestedInteger holds, if it holds a single integer
#        Return None if this NestedInteger holds a nested list
#        """
#
#    def getList(self) -> [NestedInteger]:
#        """
#        @return the nested list that this NestedInteger holds, if it holds a nested list
#        Return None if this NestedInteger holds a single integer
#        """

class NestedIterator:
    def __init__(self, nestedList: [NestedInteger]):
        self.nested=nestedList
        self.data=[]
        self.index=0
        while len(self.nested)>0:
            head=self.nested.pop(0)
            if head.isInteger():
                self.data.append(head)
            else:
                temp=head.getList()
                self.nested=temp+self.nested ## --> the previous attempts are over-thinking; when encounter a list of nested, just simply put them back
    
    def next(self) -> int:
        idx=self.index
        self.index+=1
        return self.data[idx]
        
            
    def hasNext(self) -> bool:
        return self.index<len(self.data)
            
            
        
         

# Your NestedIterator object will be instantiated and called as such:
# i, v = NestedIterator(nestedList), []
# while i.hasNext(): v.append(i.next())

# %% [markdown]
# ## Lessons and Thoughts
# - Spent almost a whole day on this, because you wanted to deal with a list on `head`; see comments on the accepted attempt.
# - `pop` is very useful for list, and probably faster too!
