# %% [markdown]
# ## Attempt 1 - Runtime Error

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def largestBSTSubtree(self, root: Optional[TreeNode]) -> int:
        self.nodes = 0
        def inner(root):
            minn, maxx = float('inf'), float('-inf')
            nodes = 0
            isBST = True
            if root.left is None and root.right is None:
                minn, maxx = root.val, root.val
                nodes = 1
            elif root.left is None:
                r_minn, r_maxx, r_nodes, r_isBST = inner(root.right)
                minn = min(minn, r_minn, root.val)
                maxx = max(maxx, r_maxx, root.val)
                nodes = r_nodes + 1
                if r_minn <= root.val:
                    isBST = False
                isBST = isBST and r_isBST
                if isBST and nodes > self.nodes:
                    self.res, self.nodes = root, nodes
            elif root.right is None:
                l_minn, l_maxx, l_nodes, l_isBST = inner(root.left)
                minn = min(minn, l_minn, root.val)
                maxx = max(maxx, l_maxx, root.val)
                nodes = l_nodes + 1
                if l_maxx >= root.val:
                    isBST = False
                isBST = isBST and l_isBST
                if isBST and nodes > self.nodes:
                    self.res, self.nodes = root, nodes
            else:
                l_minn, l_maxx, l_nodes, l_isBST = inner(root.left)
                r_minn, r_maxx, r_nodes, r_isBST = inner(root.right)
                nodes = l_nodes + r_nodes + 1
                minn = min(minn, r_minn, l_minn, root.val)
                maxx = max(maxx, r_maxx, l_maxx, root.val)
                if r_minn <= root.val or l_maxx >= root.val:
                    isBST = False
                isBST = isBST and l_isBST and r_isBST
            
            if isBST and nodes > self.nodes:
                self.nodes = nodes
            
            return minn, maxx, nodes, isBST
        
        inner(root)
        return self.nodes

# %% [markdown]
# ## Attempt 2 - Accepted

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def largestBSTSubtree(self, root: Optional[TreeNode]) -> int:
        if root is None:
            return 0
        
        self.nodes = 0
        def inner(root):
            minn, maxx = float('inf'), float('-inf')
            nodes = 0
            isBST = True
            if root.left is None and root.right is None:
                minn, maxx = root.val, root.val
                nodes = 1
            elif root.left is None:
                r_minn, r_maxx, r_nodes, r_isBST = inner(root.right)
                minn = min(minn, r_minn, root.val)
                maxx = max(maxx, r_maxx, root.val)
                nodes = r_nodes + 1
                if r_minn <= root.val:
                    isBST = False
                isBST = isBST and r_isBST
                if isBST and nodes > self.nodes:
                    self.res, self.nodes = root, nodes
            elif root.right is None:
                l_minn, l_maxx, l_nodes, l_isBST = inner(root.left)
                minn = min(minn, l_minn, root.val)
                maxx = max(maxx, l_maxx, root.val)
                nodes = l_nodes + 1
                if l_maxx >= root.val:
                    isBST = False
                isBST = isBST and l_isBST
                if isBST and nodes > self.nodes:
                    self.res, self.nodes = root, nodes
            else:
                l_minn, l_maxx, l_nodes, l_isBST = inner(root.left)
                r_minn, r_maxx, r_nodes, r_isBST = inner(root.right)
                nodes = l_nodes + r_nodes + 1
                minn = min(minn, r_minn, l_minn, root.val)
                maxx = max(maxx, r_maxx, l_maxx, root.val)
                if r_minn <= root.val or l_maxx >= root.val:
                    isBST = False
                isBST = isBST and l_isBST and r_isBST
            
            if isBST and nodes > self.nodes:
                self.nodes = nodes
            
            return minn, maxx, nodes, isBST
        
        inner(root)
        return self.nodes

# %% [markdown]
# ## Lessons and Thoughts
# - Always forget to check empty trees!
