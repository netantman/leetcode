# %% [markdown]
# ## Attempt 1 - Wrong Answer. And get the question wrong: any 'O' that is not adjacent to border 'O' should not be flipped as well.

# %%
class Solution:
    def solve(self, board: List[List[str]]) -> None:
        """
        Do not return anything, modify board in-place instead.
        """
        if len(board)<1:
            return 
        numRows=len(board)
        numCols=len(board[0])
        if numRows<=2 or numCols<=2:
            return
        
        for r in range(1, numRows-1):
            for c in range(1, numCols-1):
                if board[r][c]=='X':
                    continue
                else:
                    queue=[(r,c)]
                    while len(queue)>0:
                        head=queue[0]
                        queue=queue[1:]
                        ## --> forgot to change the one that you are looking at to 'X' first!
                        if r-1>0 and board[r-1][c]=='O':
                            board[r-1][c]='X'
                            queue.append((r-1,c))
                        if c-1>0 and board[r][c-1]=='O':
                            board[r][c-1]='X'
                            queue.append((r,c-1))
                        if r+1<numRows and board[r+1][c]=='O':
                            board[r+1][c]='X'
                            queue.append((r+1,c))
                        if r+1<numCols and board[r][c+1]=='O':
                            board[r][c+1]='X'
                            queue.append((r,c+1))
        
        return

# %% [markdown]
# ## Attempt 2 - Wrong Answer

# %%
class Solution:
    def solve(self, board: List[List[str]]) -> None:
        """
        Do not return anything, modify board in-place instead.
        """
        if len(board)<1:
            return 
        numRows=len(board)
        numCols=len(board[0])
        if numRows<=2 or numCols<=2:
            return
        
        hard_o=set()
        for rr in {0, numRows-1}:
            for cc in {0, numCols-1}: ## --> you were meant to do four lines, but you only did four corners
                if board[rr][cc]=='X':
                    continue
                else:
                    queue=[(rr,cc)]
                    while len(queue)>0:
                        head=queue[0]
                        queue=queue[1:]
                        hard_o.add(head)
                        r,c=head
                        if r-1>=0 and board[r-1][c]=='O' and ((r-1,c) not in hard_o):
                            queue.append((r-1,c))
                        if c-1>=0 and board[r][c-1]=='O' and ((r,c-1) not in hard_o):
                            queue.append((r,c-1))
                        if r+1<numRows and board[r+1][c]=='O' and ((r+1,c) not in hard_o):
                            queue.append((r+1,c))
                        if c+1<numCols and board[r][c+1]=='O'  and ((r,c+1) not in hard_o):
                            queue.append((r,c+1))
        
        for rr in range(1, numRows-1):
            for cc in range(1, numCols-1):
                if board[rr][cc]=="O" and ((rr, cc) not in hard_o):
                    board[rr][cc]="X"
        
        return

# %% [markdown]
# ## Attempt 3 - Time Limit Exceeded

# %%
class Solution:
    def solve(self, board: List[List[str]]) -> None:
        """
        Do not return anything, modify board in-place instead.
        """
        if len(board)<1:
            return 
        numRows=len(board)
        numCols=len(board[0])
        if numRows<=2 or numCols<=2:
            return
        
        hard_o=set()
        for rr in {0, numRows-1}:
            for cc in range(numCols):
                if board[rr][cc]=='X':
                    continue
                else:
                    queue=[(rr,cc)]
                    while len(queue)>0:
                        head=queue[0]
                        queue=queue[1:]
                        ## --> if head is hard_o, no need to check
                        hard_o.add(head)
                        r,c=head
                        if r-1>=0 and board[r-1][c]=='O' and ((r-1,c) not in hard_o):
                            queue.append((r-1,c))
                        if c-1>=0 and board[r][c-1]=='O' and ((r,c-1) not in hard_o):
                            queue.append((r,c-1))
                        if r+1<numRows and board[r+1][c]=='O' and ((r+1,c) not in hard_o):
                            queue.append((r+1,c))
                        if c+1<numCols and board[r][c+1]=='O'  and ((r,c+1) not in hard_o):
                            queue.append((r,c+1))
        
        for rr in range(numRows):
            for cc in {0, numCols-1}:
                if board[rr][cc]=='X':
                    continue
                else:
                    queue=[(rr,cc)]
                    while len(queue)>0:
                        head=queue[0]
                        queue=queue[1:]
                        ## --> if head is hard_o, no need to check
                        hard_o.add(head)
                        r,c=head
                        if r-1>=0 and board[r-1][c]=='O' and ((r-1,c) not in hard_o):
                            queue.append((r-1,c))
                        if c-1>=0 and board[r][c-1]=='O' and ((r,c-1) not in hard_o):
                            queue.append((r,c-1))
                        if r+1<numRows and board[r+1][c]=='O' and ((r+1,c) not in hard_o):
                            queue.append((r+1,c))
                        if c+1<numCols and board[r][c+1]=='O'  and ((r,c+1) not in hard_o):
                            queue.append((r,c+1))
        
        for rr in range(1, numRows-1):
            for cc in range(1, numCols-1):
                if board[rr][cc]=="O" and ((rr, cc) not in hard_o):
                    board[rr][cc]="X"
        
        return

# %% [markdown]
# ## Attempt 4 - Accepted

# %%
class Solution:
    def solve(self, board: List[List[str]]) -> None:
        """
        Do not return anything, modify board in-place instead.
        """
        if len(board)<1:
            return 
        numRows=len(board)
        numCols=len(board[0])
        if numRows<=2 or numCols<=2:
            return
        
        hard_o=set()
        for rr in {0, numRows-1}:
            for cc in range(numCols):
                if board[rr][cc]=='X':
                    continue
                else:
                    queue=[(rr,cc)]
                    while len(queue)>0:
                        head=queue[0]
                        queue=queue[1:]
                        if head in hard_o:
                            continue
                        hard_o.add(head)
                        r,c=head
                        if r-1>=0 and board[r-1][c]=='O' and ((r-1,c) not in hard_o):
                            queue.append((r-1,c))
                        if c-1>=0 and board[r][c-1]=='O' and ((r,c-1) not in hard_o):
                            queue.append((r,c-1))
                        if r+1<numRows and board[r+1][c]=='O' and ((r+1,c) not in hard_o):
                            queue.append((r+1,c))
                        if c+1<numCols and board[r][c+1]=='O'  and ((r,c+1) not in hard_o):
                            queue.append((r,c+1))
        
        for rr in range(numRows):
            for cc in {0, numCols-1}:
                if board[rr][cc]=='X':
                    continue
                else:
                    queue=[(rr,cc)]
                    while len(queue)>0:
                        head=queue[0]
                        queue=queue[1:]
                        if head in hard_o:
                            continue
                        hard_o.add(head)
                        r,c=head
                        if r-1>=0 and board[r-1][c]=='O' and ((r-1,c) not in hard_o):
                            queue.append((r-1,c))
                        if c-1>=0 and board[r][c-1]=='O' and ((r,c-1) not in hard_o):
                            queue.append((r,c-1))
                        if r+1<numRows and board[r+1][c]=='O' and ((r+1,c) not in hard_o):
                            queue.append((r+1,c))
                        if c+1<numCols and board[r][c+1]=='O'  and ((r,c+1) not in hard_o):
                            queue.append((r,c+1))
        
        for rr in range(1, numRows-1):
            for cc in range(1, numCols-1):
                if board[rr][cc]=="O" and ((rr, cc) not in hard_o):
                    board[rr][cc]="X"
        
        return

# %% [markdown]
# ## Lessons and Thoughts
# - Try to make use of processed and cached results as much as possible
# - How to access the edge of a matrix?
