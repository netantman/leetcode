# %% [markdown]
# ## Attempt 1 - Wrong Answer

# %%
class Solution:
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        
        L=len(wordList)
        if L<1:
            return 0
        wordL=len(wordList[0])
        wordList=wordList+[beginWord]
        if endWord not in wordList:
            return 0
        
        next_cache={w:set() for w in wordList}
        for i in range(L):   ## --> adding the beginWord in the wordList, but forgot to adjust for the length
            for j in range(L):
                if i==j:
                    continue
                w1, w2=wordList[i], wordList[j]
                com=[1 if w1[idx]==w2[idx] else 0 for idx in range(wordL)]
                if sum(com)==wordL-1:
                    next_cache[w1].add(w2)
                    next_cache[w2].add(w1)
        
        visit={w:None for w in wordList}
        visit[beginWord]=0
        queue=[(0, beginWord)]
        while len(queue)>0:
            head=queue[0]
            queue=queue[1:]
            next_words=next_cache[head[1]]
            if endWord in next_words:
                return head[0]+1
            else:
                for w in next_words:
                    if visit[w] is None:
                        visit[w]=head[0]+1
                        queue.append((head[0]+1, w))
        
        return 0

# %% [markdown]
# ## Attempt 2 - Time Limit Exceeded

# %%
class Solution:
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        
        L=len(wordList)
        if L<1:
            return 0
        wordL=len(wordList[0])
        wordList=wordList+[beginWord]
        if endWord not in wordList:
            return 0
        
        next_cache={w:set() for w in wordList}
        for i in range(L+1):
            for j in range(L+1):
                if i==j:
                    continue
                w1, w2=wordList[i], wordList[j]
                com=[1 if w1[idx]==w2[idx] else 0 for idx in range(wordL)]
                if sum(com)==wordL-1:
                    next_cache[w1].add(w2)
                    next_cache[w2].add(w1)
        
        visit={w:None for w in wordList}
        visit[beginWord]=0
        queue=[(1, beginWord)]
        while len(queue)>0:
            head=queue[0]
            queue=queue[1:]
            next_words=next_cache[head[1]]
            if endWord in next_words:
                return head[0]+1
            else:
                for w in next_words:
                    if visit[w] is None:
                        visit[w]=head[0]+1
                        queue.append((head[0]+1, w))
        
        return 0

# %% [markdown]
# ## Attempt 3 - Still Time Limit Exceeded, even if do not build next_cache

# %%
class Solution:
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        
        L=len(wordList)
        if L<1:
            return 0
        wordL=len(wordList[0])
        wordList=wordList+[beginWord]
        L=len(wordList)
        if endWord not in wordList:
            return 0
        
        visited={beginWord}
        queue=[(1, beginWord)]
        while len(queue)>0:
            head=queue[0]
            level, word=head
            queue=queue[1:]
            for idx in range(L):
                w=wordList[idx]
                if w==word:
                    continue
                elif w in visited:
                    pass
                else:
                    com=[1 if w[i]==word[i] else 0 for i in range(wordL)]
                    if sum(com)==wordL-1:
                        if w==endWord:
                            return level+1
                        queue.append((level+1, w))
                        visited.add(w)
        
        return 0

# %% [markdown]
# ## Attempt 4 - Looking for adjacent word by changing one letter, rather than loop through all the words in wordList can make it faster, especially when wordList is very long. But this is still Wrong Answer.

# %%
class Solution:
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        
        L=len(wordList)
        if L<1:
            return 0
        wordL=len(wordList[0])
        wordList=wordList+[beginWord]
        L=len(wordList)
        if endWord not in wordList:
            return 0
        wordList=set(wordList)
        
        letters='abcdefghijklmnopgrstuvwxyz'  ## --> typo here!
        letters={c for c in letters}
        visited={beginWord}
        queue=[(1, beginWord)]
        while len(queue)>0:
            head=queue[0]
            level, word=head
            queue=queue[1:]
            
            for pos in range(wordL):
                for c in letters:
                    w=[char for char in word]
                    w[pos]=c
                    w="".join(w)
                    if w==endWord:
                        return level+1
                    elif (w==word) or (w in visited):
                        continue
                    else:
                        if w in wordList:
                            queue.append((level+1, w))
                            visited.add(w)
        
        return 0

# %% [markdown]
# ## Attempt 5 - Accepted

# %%
class Solution:
    def ladderLength(self, beginWord: str, endWord: str, wordList: List[str]) -> int:
        
        L=len(wordList)
        if L<1:
            return 0
        wordL=len(wordList[0])
        wordList=wordList+[beginWord]
        L=len(wordList)
        if endWord not in wordList:
            return 0
        wordList=set(wordList)
        
        letters='abcdefghijklmnopqrstuvwxyz'
        letters={c for c in letters}
        visited={beginWord}
        queue=[(1, beginWord)]
        while len(queue)>0:
            head=queue[0]
            level, word=head
            queue=queue[1:]
            
            for pos in range(wordL):
                for c in letters:
                    w=[char for char in word]
                    w[pos]=c
                    w="".join(w)
                    if w==endWord:
                        return level+1
                    elif (w==word) or (w in visited):
                        continue
                    else:
                        if w in wordList:
                            queue.append((level+1, w))
                            visited.add(w)
        
        return 0

# %% [markdown]
# ## Lessons and Thoughts
# - This is BFS alright, but building the neighboring word cache for all the words in the wordList will take a long time. So the problem is to ask you to change each letter to come up with the next word.
