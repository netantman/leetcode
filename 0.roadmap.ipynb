# %% [markdown]
# 1. [Two Sum](Easy/Array/1.two-sum.ipynb)
# 2. [Add Two Numbers](Medium/Linked-List/2.add-two-numbers.ipynb)
# 3. [Longest Substring Without Repeating Characters](Medium/Two-Pointers/Chasing-Two-Pointers/3.longest-substring-without-repeating-characters.ipynb)
# 4. Medium of Two Sorted Arrays (Hard)
# 5. [Longest Palindromic Substring](Medium/String/5.longest-palindromic-substring.ipynb)
# 6. [ZigZag Conversion](Medium/String/6.zigzag-conversion.ipynb)
# 7. [Reverse Integer](Easy/Maths/7.reverse-integer.ipynb)
# 8. [String to Integer (atoi)](Medium/String/8.string-to-integer-(atoi).ipynb)
# 9. [Palindrome Number](Easy/Maths/9.palindrome-number.ipynb)
# 10. Regular Expression Matching (Hard)
# 11. [Container with Most Water](Medium/Two-Pointers/Converging-Two-Pointers/11.container-with-most-water.ipynb)
# 12. [Integer to Roman](Medium/String/12.integer-to-roman.ipynb)
# 13. [Roman to Integer](Easy/String/13.roman-to-integer.ipynb)
# 14. [Longest Common Prefix](Easy/String/14.longest-common-prefix.ipynb)
# 15. [3Sum](Medium/Two-Pointers/Converging-Two-Pointers/15.3sum.ipynb)
# 16. [3Sum Closest](Medium/Two-Pointers/Converging-Two-Pointers/16.3sum-closest.ipynb)
# 17. [Letter Combinations of a Phone Number](Medium/Backtracking/17.letter-combinations-of-a-phone-number.ipynb)
# 18. [4Sum](Medium/Two-Pointers/Converging-Two-Pointers/19.4sum.ipynb)
# 19. [Remove Nth Node From End of List](Medium/Linked-List/19.remove-nth-node-from-end-of-list.ipynb)
# 20. [Valid Parentheses](Easy/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/20.valid-parentheses.ipynb)
# 21. [Merge Two Sorted Lists](Easy/String/21.merge-two-sorted-lists.ipynb)
# 22. [Generate Parentheses](Medium/Dynamic-Programming/Cached-Search/22.generate-parentheses.ipynb)
# 23. Merge k Sorted Lists (Hard)
# 24. [Swap Nodes in Pairs](Medium/Linked-List/24.swap-nodes-in-pairs.ipynb)
# 25. Reverse Nodes in k-Group (Hard)
# 26. [Remove Duplicates from Sorted Array](Easy/Two-Pointers/Chasing-Two-Pointers/26.remove-duplicates-from-sorted-array.ipynb)
# 27. [Remove Element](Easy/Two-Pointers/Converging-Two-Pointers/27.remove-element.ipynb)
# 28. [Implement strStr()](Easy/String/28.implement-strStr().ipynb)
# 29. [Divide Two Integers](Medium/Bit-Manipulation/29.divide-two-integers.ipynb)
# 30. Substring with Concatenation of All Words (Hard)
# 31. [Next Permutation](Medium/Array/31.next-permutation.ipynb)
# 32. Longest Valid Parentheses (Hard)
# 33. [Search in Rotated Sorted Array](Medium/Binary-Search/33.search-in-rotated-sorted-array.ipynb)
# 34. [Find First and Last Position of Element in Sorted Array](Medium/Binary-Search/34.find-first-and-last-position-of-element-in-sorted-array.ipynb)
# 35. [Search Insert Position](Easy/Binary-Search/35.search-insert-position.ipynb)
# 36. [Valid Sudoku](Medium/Hash-Table/36.valid-sudoku.ipynb)
# 37.	Sudoku Solver (Hard)
# 38. [Count and Say](Easy/String/38.count-and-say.ipynb)
# 39. [Combination Sum](Medium/Dynamic-Programming/Cached-Search/39.combination-sum.ipynb)
# 40. [Combination Sum II](Medium/Dynamic-Programming/Cached-Search/40.combination-sum-II.ipynb)
# 41. First Missing Positive (Hard)
# 42. Trapping Rain Water (Hard)
# 43. [Multiply Strings](Medium/Maths/43.multiply-strings.ipynb)
# 44. Wildcard Matching (Hard)
# 45. [Jump Game II](Medium/Breadth-First-Search/Shortest-Path/45.jump-game-II.ipynb)
# 46. [Permutations](Medium/Dynamic-Programming/Cached-Search/46.permutation.ipynb)
# 47. [Permutations II](Medium/Dynamic-Programming/Cached-Search/47.permutations-II.ipynb)
# 48. [Rotate Image](Medium/Array/48.rotate-image.ipynb)
# 49. [Group Anagrams](Medium/Hash-Table/49.group-anagrams.ipynb)
# 50. [Pow(x, n)](Medium/Bit-Manipulation/50.pow(x,n).ipynb)
# 51.	N-Queens (Hard)
# 52. N-Queens II (Hard)
# 53. [Maximum Subarray](Easy/Dynamic-Programming/53.maximum-subarray.ipynb)
# 54. [Spiral Matrix](Medium/Array/54.spiral-matrix.ipynb)
# 55. [Jump Game](Medium/Greedy/55.jump-game.ipynb)
# 56. [Merge Intervals](Medium/Sort/56.merge-intervals.ipynb)
# 57.	[Insert Interval](Medium/Sort/57.insert-interval.ipynb)
# 58. [Length of Last Word](Easy/String/58.length-of-last-word.ipynb)
# 59. [Spiral Matrix II](Medium/Array/59.spiral-matrix-II.ipynb)
# 60. [Permutation Sequence](Medium/Dynamic-Programming/Cached-Search/60.permutation-sequence.ipynb)
# 61. [Rotate List](Medium/Linked-List/61.rotate-list.ipynb)
#
# (07/05/2020 checkpoint, increment: 47, cumulative: 47)

# %% [markdown]
# 62. [Unique Paths](Medium/Dynamic-Programming/Coordinate/62.unique-paths.ipynb)
# 63. [Unique Paths II](Medium/Dynamic-Programming/Coordinate/63.unique-paths-II.ipynb)
# 64. [Minimum Path Sum](Medium/Dynamic-Programming/64.minimum-path-sum.ipynb)
# 65.	Valid Number (Hard)
# 66. [Plus One](Easy/Array/66.plus-one.ipynb)
# 67. [Add Binary](Easy/String/67.add-binary.ipynb)
# 68. Text Justification (Hard)
# 69. [Sqrt(x)](Easy/Binary-Search/69.sqrt(x).ipynb)
# 70. [Climbing Stairs](Easy/Dynamic-Programming/Sequence/70.climbing-stairs.ipynb)
#
# 71. [Simplify Path](Medium/Stack/71.simplify-path.ipynb)
# 72. Edit Distance (Hard)
# 73. [Set Matrix Zeroes](Medium/Array/73.set-matrix-zeroes.ipynb)
# 74. [Search a 2D Matrix](Medium/Binary-Search/74.search-a-2D-matrix.ipynb)
# 75. [Sort Colors](Medium/Two-Pointers/Converging-Two-Pointers/75.sort-colors.ipynb)
# 76. Minimum Window Substring (Hard)
# 77. [Combinations](Medium/Dynamic-Programming/Cached-Search/77.combinations.ipynb)
# 78. [Subsets](Medium/Dynamic-Programming/Cached-Search/78.subsets.ipynb)
# 79. [Word Search](Medium/Depth-First-Serch/79.word-search.ipynb)
#
# 80. [Remove Duplicates from Sorted Array II](Medium/Two-Pointers/Chasing-Two-Pointers/80.remove-duplicates-from-sorted-array-II.ipynb)
# 81. [Search in Rotated Sorted Array II](Medium/Binary-Search/81.search-in-rotated-sorted-array-II.ipynb)
# 82. [Remove Duplicates from Sorted List II](Medium/Linked-List/82.remove-duplicates-from-sorted-list-II.ipynb)
# 83. [Remove Duplicates from Sorted List](Medium/Linked-List/83.remove-duplicates-from-sorted-list.ipynb)
# 84. Largest Rectangle in Histogram (Hard)
# 85. Maximal Rectangle (Hard)
# 86. [Partition List](Medium/Linked-List/86.partition-list.ipynb)
# 87.	Scramble String (Hard)
# 88. [Merge Sorted Array](Easy/Array/88.merge-sorted-array.ipynb)
# 89. [Gray Code](Medium/Dynamic-Programming/Cached-Search/89.gray-code.ipynb)
#
# 90. [Subsets II](Medium/Dynamic-Programming/Cached-Search/90.subsets-II.ipynb)
# 91. [Decode Ways](Medium/Dynamic-Programming/Sequence/91.decode-ways.ipynb)
# 92. [Reverse Linked List II](Medium/Linked-List/92.reverse-linked-list-II.ipynb)
# 93. [Restore IP Addresses](Medium/Dynamic-Programming/Cached-Search/93.restore-IP-addresses.ipynb)
# 94. [Binary Tree Inorder Traversal](Medium/Tree/Recursion/94.binary-tree-inorder-traversal.ipynb)
# 95. [Unique Binary Search Trees II](Medium/Tree/Recursion/95.unique-binary-search-trees-II.ipynb)
# 96. [Unique Binary Search Trees](Medium/Tree/Recursion/96.unique-binary-search-trees.ipynb)
# 97. [Interleaving String](Medium/Dynamic-Programming/Sequence/97.interleaving-string.ipynb)
# 98. [Validate Binary Search Tree](Medium/Tree/Recursion/98.validate-binary-search-tree.ipynb)
# 99. [Recover Binary Search Tree](Medium/Tree/BST/99.recover-binary-search-tree.ipynb)
# 100. [Same Tree](Easy/Tree/Recursion/100.same-tree.ipynb)
# 101. [Symmetric Tree](Easy/Tree/Recursion/101.symmetric-tree.ipynb)
# 102. [Binary Tree Level Order Traversal](Medium/Tree/Level-Traversal/102.binary-tree-level-order-traversal.ipynb)
# 103. [Binary Tree Zigzag Level Order Traversal](Medium/Tree/Level-Traversal/103.binary-tree-zigzag-level-order-traversal.ipynb)
#
# 104. [Maximum Depth of Binary Tree](Easy/Tree/Recursion/104.maximum-depth-of-binary-tree.ipynb)
# 105. [Construct Binary Tree from Preorder and Inorder Traversal](Medium/Tree/Recursion/105.construct-binary-tree-from-preorder-and-inorder-traversal.ipynb)
# 106. [Construct Binary Tree from Inorder and Postorder Traversal](Medium/Tree/Recursion/106.construct-binary-tree-from-inorder-and-postorder-traversal.ipynb)
# 107. [Binary Tree Level Order Traversal II](Easy/Tree/Level-Traversal/107.binary-tree-level-order-traversal-II.ipynb)
# 108. [Convert Sorted Array to Binary Search Tree](Medium/Tree/BST/108.convert-sorted-array-to-binary-search-tree.ipynb)
# 109. [Convert Sorted List to Binary Search Tree](Medium/Tree/BST/109.convert-sorted-list-to-binary-search-tree.ipynb)
# 110. [Balanced Binary Tree](Easy/Tree/Recursion/110.balanced-binary-tree.ipynb)
# 111. [Minimum Depth of Binary Tree](Easy/Tree/Level-Traversal/111.minimum-depth-of-binary-tree.ipynb)
# 112. [Path Sum](Easy/Tree/Recursion/112.path-sum.ipynb)
# 113. [Path Sum II](Medium/Tree/Recursion/113.path-sum-II.ipynb)
# 114. [Flatten Binary Tree to Linked List](Medium/Tree/Recursion/114.flatten-binary-tree-to-linked-list.ipynb)
# 115. Distinct Subsequences (Hard)
# 116. [Populating Next Right Pointers in Each Node](Medium/Tree/Recursion/116.populating-next-right-pointers-in-each-node.ipynb)
# 117. [Populating Next Right Pointers in Each Node II](Medium/Tree/Recursion/117.populating-next-right-pointers-in-each-node-II.ipynb)
# 118. [Pascal's Triangle](Easy/Math/118.pascal's-triangle.ipynb)
# 119. [Pascal's Triangle II](Easy/Math/119.pascal's-triangle-II.ipynb)
#
# 120. [Triangle](Medium/Dynamic-Programming/120.triangle.ipynb)
# 121. [Best Time to Buy and Sell Stock](Easy/Dynamic-Programming/Sequence/121.best-time-to-buy-and-sell-stock.ipynb)
# 122. [Best Time to Buy and Sell Stock II](Easy/Array/122.best-time-to-buy-and-sell-stock-II.ipynb)
# 123. Best Time to Buy and Sell Stock III (Hard)
# 124. Binary Tree Maximum Path Sum (Hard)
# 125. [Valid Palindrome](Easy/String/125.valid-palindrome.ipynb)
# 126. Word Ladder II (Hard)
# 127. [Word Ladder](Medium/Breadth-First-Search/Shortest-Path/127.word-ladder.ipynb)
# 128. [Longest Consecutive Sequence](Medium/Two-Pointer/Chasing-Two-Pointers/128.longest-consecutive-sequence.ipynb)
# 129. [Sum Root to Leaf Numbers](Medium/Tree/Recursion/129.sum-root-to-leaf-numbers.ipynb)
# 130. [Surrounded Regions](Medium/Breadth-First-Search/Queue-Implementation/130.surrounded-regions.ipynb)
# 131. [Palindrome Partitioning](Medium/Dynamic-Programming/Sequence/131.palindrome-partitioning.ipynb)
# 132. Palindrome Partitioning II (Hard)
# 133. [Clone Graph](Medium/Graph/133.clone-graph.ipynb)
# 134. [Gas Station](Medium/Two-Pointers/Chasing-Two-Pointers/134.gas-station.ipynb)
# 135. Candy (Hard)
# 136. [Single Number](Easy/Bit-Manipulation/136.single-number.ipynb)
# 137. [Single Number II](Medium/Bit-Manipulation/137.single-number-II.ipynb)
#
# 138. [Copy List with Random Pointer](Medium/Linked-List/138.copy-list-with-random-pointer.ipynb)
# 139. [Word Break](Medium/Dynamic-Programming/Sequence/139.word-break.ipynb)
# 140. Word Break II (Hard)
# 141. [Linked List Cycle](Easy/Two-Pointers/Chasing-Two-Pointers/141.linked-list-cycle.ipynb)
# 142. [Linked List Cycle II](Medium/Two-Pointers/Chasing-Two-Pointers/142.linked-list-cycle-II.ipynb)
# 143. [Reorder List](Medium/Linked-List/143.reorder-list.ipynb)
# 144. [Binary Tree Preorder Traversal](Medium/Tree/Recursion/144.binary-tree-preorder-traversal.ipynb)
# 145. [Binary Tree Postorder Traversal](Medium/Tree/Recursion/145.binary-tree-postorder-traversal.ipynb)
# 146. [LRU Cache](Medium/Design/146.LRU-cache.ipynb)
# 147. [Insertion Sort List](Medium/Sort/147.insertion-sort-list.ipynb)
# 148. [Sort List](Medium/Sort/148.sort-list.ipynb)
# 149. Max Points on a Line (Hard)
# 150. [Evaluate Reverse Polish Notation](Medium/Stack/150.evaluate-reverse-polish-notation.ipynb)
# 151. [Reverse Words in a String](Medium/String/151.reverse-words-in-a-string.ipynb)
# 152. [Maximum Product Subarray](Medium/Dynamic-Programming/Interval-Dividing/152.maximum-product-subarray.ipynb)
# 153. [Find Minimum in Rotated Sorted Array](Medium/Binary-Search/153.find-minimum-in-rotated-sorted-array.ipynb)
# 154. Find Minimum in Rotated Sorted Array II (Hard)
# 155. [Min Stack](Easy/Stack/155.min-stack.ipynb)
# 156. [Binary Tree Upside Down](Medium/Tree/Level-Traversal/156.binary-tree-upside-down.ipynb)
# 157. [Read N Characters Given Read4](Easy/String/157.read-N-characters-given-read4.ipynb)
# 158. Read N Characters Given Read4 II - Call multiple times (Hard, Locked)
# 159. [Longest Substring with At Most Two Distinct Characters](Medium/Two-Pointers/Chasing-Two-Pointers/159.longest-substring-with-at-most-two-distinct-characters.ipynb)
# 160. [Intersection of Two Linked Lists](Easy/Linked-List/160.intersection-of-two-linked-lists.ipynb)
# 161. [One Edit Distance](Medium/Two-Pointers/Chasing-Two-Pointers/161.one-edit-distance.ipynb)
# 162. [Find Peak Element](Medium/Binary-Search/162.find-peak-element.ipynb)
#
# (07/12/2020 checkpoint, increment: 76, cumulative: 123)

# %% [markdown]
# 163. [Missing Ranges](Easy/String/163.missing-ranges.ipynb)
# 164. Maximum Gap (Hard)
# 165. [Compare Version Numbers](Medium/String/165.compare-version-numbers.ipynb)
# 166. [Fraction to Recurring Decimal](Medium/Maths/166.fraction-to-recurring-decimal.ipynb)
# 167. [Two Sum II - Input array is sorted](Easy/Two-Pointers/Converging-Two-Pointers/167.two-sum-II-input-array-is-sorted.ipynb)
# 168. [Excel Sheet Column Title](Easy/Maths/168.excel-sheet-column-title.ipynb)
# 169. [Majority Element](Easy/Hash-Table/169.majority-element.ipynb)
# 170. Two Sum III - Data structure design (Hard, Locked)
# 171. [Excel Sheet Column Number](Easy/Maths/171.excel-sheet-column-number.ipynb)
# 172. [Factorial Trailing Zeroes](Easy/Maths/172.factorial-trailing-zeroes.ipynb)
# 173. [Binary Search Tree Iterator](Medium/Design/173.binary-search-tree-iterator.ipynb)
# 174. Dungeon Game (Hard)
# 175. (Not algo)
# 176. (Not algo)
# 177. (Not algo)
# 178. (Not algo)
# 179. [Largest Number](Medium/Sort/179.largest-number.ipynb)
# 180. (Not algo)
# 181. (Not algo)
# 182. (Not algo)
# 183. (Not algo)
# 184. (Not algo)
# 185. (Not algo)
# 186. [Reverse Words in a String II](Medium/String/186.reverse-words-in-a-string-II.ipynb)
# 187. [Repeated DNA Sequences](Medium/Hash-Table/187.repeated-DNA-sequences.ipynb)
# 188. Best Time to Buy and Sell Stock IV (Hard)
# 189. [Rotate Array](Easy/Array/189.rotate-array.ipynb)
# 190. [Reverse Bits](Easy/Bit-Manipulation/190.reverse-bits.ipynb)
#
# 191. [Number of 1 Bits](Easy/Bit-Manipulation/191.number-of-1-bits.ipynb)
# 192. (Not algo)
# 193. (Not algo)
# 194. (Not algo)
# 195. (Not algo)
# 196. (Not algo)
# 197. (Not algo)
# 198. [House Robber](Easy/Dynamic-Programming/Sequence/198.house-robber.ipynb)
# 199. [Binary Tree Right Side View](Medium/Tree/Level-Traversal/199.binary-tree-right-side-view.ipynb)
# 200. [Number of Islands](Medium/Depth-First-Search/Union-Find/200.number-of-islands.ipynb)
# 201. [Bitwise AND of Numbers Range](Medium/Bit-Manipulation/201.bitwise-AND-of-numbers-range.ipynb)
# 202. [Happy Number](Easy/Maths/202.happy-number.ipynb)
# 203. [Remove Linked List Elements](Easy/Linked-List/203.remove-linked-list-elements.ipynb)
# 204. [Count Primes](Easy/Maths/204.count-primes.ipynb)
# 205. [Isomorphic Strings](Easy/String/205.isomorphic-strings.ipynb)
# 206. [Reverse Linked List](Easy/Linked-List/206.reverse-linked-list.ipynb)
#
# 207. [Course Schedule](Medium/Depth-First-Search/Topological-Sort/207.course-schedule.ipynb)
# 208. [Implement Trie (Prefix Tree)](Medium/Design/208.implement-trie.ipynb)
# 209. [Minimum Size Subarray Sum](Medium/Two-Pointers/Chasing-Two-Pointers/209.minimum-size-subarray-sum.ipynb)
# 210. [Course Schedule II](Medium/Breadth-First-Search/Topological-Sort/210.course-schedule-II.ipynb)
# 211. [Add and Search Word - Data structure design](Medium/Design/211.add-and-search-word-data-structure-design.ipynb)
# 212. Word Search II (Hard)
# 213. [House Robber II](Medium/Dynamic-Programming/Sequence/213.house-robber-II.ipynb)
# 214. Shortest Palindrome (Hard)
# 215. [Kth Largest Element in an Array](Medium/Heap/215.kth-largest-element-in-an-array.ipynb)
# 216. [Combination Sum III](Medium/Dynamic-Programming/Cached-Search/216.combination-sum-III.ipynb)
# 217. [Contains Duplicate](Easy/Array/217.contains-duplicate.ipynb)
# 218. The Skyline Problem (Hard)
# 219. [Contains Duplicate II](Easy/Hash-Table/219.contains-duplicate-II.ipynb)
# 220. [Contains Duplicate III](Medium/Ordered-Dict/220.contains-duplicate-III.ipynb)
# 221. [Maximal Square](Medium/Dynamic-Programming/Coordinate/221.maximal-square.ipynb)
#
# 222. [Count Complete Tree Nodes](Medium/Tree/Level-Traversal/222.count-complete-tree-nodes.ipynb)
# 223. [Rectangle Area](Medium/Maths/223.rectangle-area.ipynb)
# 224. Basic Calculator (Hard)
# 225. [Implement Stack using Queues](Easy/Design/225.implement-stack-using-queues.ipynb)
# 226. [Invert Binary Tree](Easy/Tree/Recursion/226.invert-binary-tree.ipynb)
# 227. [Basic Calculator II](Medium/String/227.basic-calculator-II.ipynb)
# 228. [Summary Ranges](Medium/Array/228.summary-ranges.ipynb)
# 229. [Majority Element II](Medium/Array/229.majority-element-II.ipynb)
# 230. [Kth Smallest Element in a BST](Medium/Tree/230.Kth-smallest-element-in-a-BST.ipynb)
# 231. [Power of Two](Easy/Bit-Manipulation/231.power-of-two.ipynb)
# 232. [Implement Queue using Stacks](Easy/Design/232.implement-queue-using-stacks.ipynb)
# 233. Number of Digit One (Hard)
# 234. [Palindrome Linked List](Easy/Linked-List/234.palindrome-linked-list.ipynb)
# 235. [Lowest Common Ancestor of a Binary Search Tree](Easy/Tree/Recursion/235.lowest-common-ancestor-of-a-binary-search-tree.ipynb)
# 236. [Lowest Common Ancestor of a Binary Tree](Medium/Tree/Recursion/236.lowest-common-ancestor-of-a-binary-tree.ipynb)
# 237. [Delete Node in a Linked List](Easy/Linked-List/237.delete-node-in-a-linked-list.ipynb)
# 238. [Product of Array Except Self](Medium/Array/238.product-of-array-except-self.ipynb)
# 239. Sliding Window Maximum (Hard)
#
# 240. [Search a 2D Matrix II](Medium/Divide-and-Conquer/240.search-a-2D-matrix-II.ipynb)
# 241. [Different Ways to Add Parentheses](Medium/Divide-and-Conquer/241.different-ways-to-add-parentheses.ipynb)
# 242. [Valid Anagram](Easy/Hash-Table/242.valid-anagram.ipynb)
# 243. [Shortest Word Distance](Easy/String/243.shortest-word-distance.ipynb)
# 244. [Shortest Word Distance II](Medium/String/244.shortest-word-distance-II.ipynb)
# 245. [Shortest Word Distance III](Medium/String/245.shortest-word-distance-III.ipynb)
# 246. [Strobogrammatic Number](Easy/String/246.strobogrammatic-number.ipynb)
# 247. [Strobogrammatic Number II](Medium/Maths/247.strobogrammatic-number-II.ipynb)
# 248. Strobogrammatic Number III (Hard, Locked)
# 249. [Group Shifted Strings](Medium/String/249.group-shifted-strings.ipynb)
# 250. [Count Univalue Subtrees](Medium/Tree/Recursion/250.count-univalue-subtrees.ipynb)
# 251. [Flatten 2D Vector](Medium/Design/251.flatten-2D-vector.ipynb)
# 252. [Meeting Rooms](Easy/Sort/252.meeting-rooms.ipynb)
# 253. [Meeting Rooms II](Medium/Heap/253.meeting-rooms-II.ipynb)
# 254. [Factor Combinations](Medium/Maths/254.factor-combinations.ipynb)
# 255. [Verify Preorder Sequence in Binary Search Tree](Medium/Tree/BST/255.verify-preorder-sequence-in-binary-search-tree.ipynb)
# 256. [Paint House](Medium/Dynamic-Programming/Sequence/256.paint-house.ipynb)
# 257. [Binary Tree Paths](Easy/Tree/Recursion/257.binary-tree-paths.ipynb)
# 258. [Add Digits](Easy/Maths/258.add-digits.ipynb)
# 259. [3Sum Smaller](Medium/Two-Pointers/Converging-Two-Pointers/259.3Sum-smaller.ipynb)
# 260. [Single Number III](Medium/Bit-Manipulation/260.single-number-III.ipynb)
# 261. [Graph Valid Tree](Medium/Graph/261.graph-valid-tree.ipynb)
# 262. (Not algo)
# 263. [Ugly Number](Easy/Maths/263.ugly-number.ipynb)
# 264. [Ugly Number II](Medium/Heap/264.ugly-number-II.ipynb)
# 265. Paint House II (Hard, Locked)
# 266. [Palindrome Permutation](Easy/String/266.palindrome-permutation.ipynb)
# 267. [Palindrome Permutation II](Medium/String/267.palindrome-permutation-II.ipynb)
# 268. [Missing Number](Easy/Bit-Manipulation/268.missing-number.ipynb)
# 269. Alien Dictionary (Hard, Locked)
# 270. [Closest Binary Search Tree Value](Easy/Tree/BST/270.closest-binary-search-tree-value.ipynb)
# 271. [Encode and Decode Strings](Medium/String/271.encode-and-decode-strings.ipynb)
# 272. Closest Binary Search Tree Value II (Hard, Locked)
# 273. Integer to English Words (Hard)
# 274. [H-Index](Medium/Sort/274.H-index.ipynb)
# 275. [H-Index II](Medium/Binary-Search/275.H-index-II.ipynb)
# 276. [Paint Fence](Medium/Dynamic-Programming/Sequence/276.paint-fence.ipynb)
# 277. [Find the Celebrity](Medium/Greedy/277.find-the-celebrity.ipynb)
# 278. [First Bad Version](Easy/Binary-Search/278.first-bad-version.ipynb)
# 279. [Perfect Squares](Medium/Breadth-First-Search/Queue-Implementation/279.perfect-squares.ipynb)
# 280. [Wiggle Sort](Medium/Greedy/280.wiggle-sort.ipynb)
# 281. [Zigzag Iterator](Medium/Design/281.zigzag-iterator.ipynb)
# 282. Expression Add Operators (Hard)
# 283. [Move Zeroes](Easy/Two-Pointers/Chasing-Two-Pointers/283.move-zeroes.ipynb)
# 284. [Peeking Iterator](Medium/Design/284.peeking-iterator.ipynb)
# 285. [Inorder Successor in BST](Medium/Tree/BST/285.inorder-successor-in-BST.ipynb)
# 286. [Walls and Gates](Medium/Breadth-First-Search/Shortest-Path/286.walls-and-gates.ipynb)
# 287. [Find the Duplicate Number](Medium/Two-Pointers/Chasing-Two-Pointers/287.find-the-duplicate-number.ipynb)
# 288. [Unique Word Abbreviation](Medium/Design/288.unique-word-abbreviation.ipynb)
#
# 289. [Game of Life](Medium/Array/289.game-of-life.ipynb)
# 290. [Word Pattern](Easy/Hash-Table/290.word-pattern.ipynb)
# 291. [Word Pattern II](Medium/Dynamic-Programming/Cached-Search/291.word-pattern-II.ipynb)
# 292. [Nim Game](Easy/Maths/292.nim-game.ipynb)
# 293. [Flip Game](Easy/String/293.flip-game.ipynb)
# 294. [Flip Game II](Medium/Dynamic-Programming/Cached-Search/294.flip-game-II.ipynb)
# 295. Find Median from Data Stream (Hard)
# 296. Best Meeting Point (Hard, Locked)
# 297. Serialize and Deserialize Binary Tree (Hard)
# 298. [Binary Tree Longest Consecutive Sequence](Medium/Tree/Recursion/298.binary-tree-longest-consecutive-sequence.ipynb)
# 299. [Bulls and Cows](Easy/Hash-Table/299.bulls-and-cows.ipynb)
# 300. [Longest Increasing Subsequence](Medium/Dynamic-Programming/Coordinate/300.longest-increasing-subsequence.ipynb)
# 301. Remove Invalid Parentheses (Hard)
# 302. Smallest Rectangle Enclosing Black Pixels (Hard, Locked)
# 303. [Range Sum Query - Immutable](Easy/Dynamic-Programming/Sequence/303.range-sum-query-immutable.ipynb)
# 304. [Range Sum Query 2D - Immutable](Medium/Dynamic-Programming/Double-Sequence/304.range-sum-query-2D-immutable.ipynb)
# 305. Number of Islands II (Hard)
# 306. [Additive Number](Medium/Maths/306.additive-number.ipynb)
#
# 307. [Range Sum Query - Mutable](Medium/Special-Data-Structure/307.range-sum-query-mutable.ipynb)
# 308. Range Sum Query 2D - Mutable (Hard, Locked)
# 309. [Best Time to Buy and Sell Stock with Cooldown](Medium/Dynamic-Programming/Sequence/309.best-time-to-buy-and-sell-stock-with-cooldown.ipynb)
# 310. [Minimum Height Trees](Medium/Breadth-First-Search/Topological-Sort/310.minimum-height-trees.ipynb)
# 311. [Sparse Matrix Multiplication](Medium/Maths/311.sparse-matrix-multiplication.ipynb)
# 312. Burst Balloons (Hard)
# 313. [Super Ugly Number](Medium/Maths/313.super-ugly-number.ipynb)
# 314. [Binary Tree Vertical Order Traversal](Medium/Tree/Level-Traversal/314.binary-tree-vertical-order-traversal.ipynb)
# 315. Count of Smaller Numbers After Self (Hard)
# 316. [Remove Duplicate Letters](Medium/Greedy/316.remove-duplicate-letters.ipynb)
# 317. Shortest Distance from All Buildings (Hard, Locked)
#
# (07/19/2020 checkpoint, increment: 77, cumulative: 200)

# %% [markdown]
# 318. [Maximum Product of Word Lengths](Medium/Bit-Manipulation/318.maximum-product-of-word-lengths.ipynb)
# 319. [Bulb Switcher](Medium/Maths/319.bulb-switcher.ipynb)
# 320. [Generalized Abbreviation](Medium/Dynamic-Programming/Cached-Search/320.generalized-abbreviation.ipynb)
# 321. Create Maximum Number (Hard)
# 322. [Coin Change](Medium/Dynamic-Programming/Backpack/322.coin-change.ipynb)
# 323. [Number of Connected Components in an Undirected Graph](Medium/Depth-First-Search/323.number-of-connected-components-in-an-undirected-graph.ipynb)
# 324. [Wiggle Sort II](Medium/Sort/324.wiggle-sort-II.ipynb)
# 325. [Maximum Size Subarray Sum Equals k](Medium/Cumsum/325.maximum-size-subarray-sum-equals-k.ipynb)
# 326. [Power of Three](Easy/Maths/326.power-of-three.ipynb)
# 327. Count of Range Sum (Hard)
# 328. [Odd Even Linked List](Medium/Linked-List/328.odd-even-linked-list.ipynb)
# 329. Longest Increasing Path in a Matrix (Hard)
# 330. Patching Array (Hard)
# 331. [Verify Preorder Serialization of a Binary Tree](Medium/Tree/331.verify-preorder-serialization-of-a-binary-tree.ipynb)
# 332. [Reconstruct Itinerary](Medium/Depth-First-Search/332.reconstruct-itinerary.ipynb)
# 333. [Largest BST Subtree](Medium/Tree/BST/333.largest-BST-subtree.ipynb)
# 334. [Increasing Triplet Subsequence](Medium/Dynamic-Programming/334.increasing-triplet-subsequence.ipynb)
# 335. Self Crossing (Hard)
# 336. Palindrome Pairs (Hard)
# 337. [House Robber III](Medium/Dynamic-Programming/Sequence/337.house-robber-III.ipynb)
# 338. [Counting Bits](Medium/Bit-Manipulation/338.counting-bits.ipynb)
# 339. [Nested List Weight Sum](Medkum/Design/339.nested-list-weight-sum.ipynb)
# 340. [Longest Substring with At Most K Distinct Characters](Medium/Two-Pointers/Chasing-Two-Pointers/340.longest-substring-with-at-most-K-distinct-characters.ipynb)
#
# 341. [Flatten Nested List Iterator](Medium/Design/341.flatten-nested-list-iterator.ipynb)
# 342. [Power of Four](Easy/Maths/342.power-of-four.ipynb)
# 343. [Integer Break](Medium/Dynamic-Programming/Sequence/343.integer-break.ipynb)
# 344. [Reverse String](Easy/Two-Pointers/Converging-Two-Pointers/344.reverse-string.ipynb)
# 345. [Reverse Vowels of a String](Easy/Two-Pointers/Converging-Two-Pointers/345.reverse-vowels-of-a-string.ipynb)
# 346. Moving Average from Data Stream (Easy, Locked)
# 347. [Top K Frequent Elements](Medium/Heap/347.top-K-frequent-elements.ipynb)
# 348. [Design Tic-Tac-Toe](Medium/Array/348.design-tic-tac-toe.ipynb)
# 349. [Intersection of Two Arrays](Easy/Hash-Table/349.intersection-of-two-arrays.ipynb)
# 350. [Intersection of Two Arrays II](Easy/Hash-Table/350.intersection-of-two-arrays-II.ipynb)
# 351. Android Unlock Patterns (Medium, Locked)
# 352. Data Stream as Disjoint Intervals (Hard)
# 353. Design Snake Game (Medium, Locked)
# 354. Russian Doll Envelopes (Hard)
# 355. [Design Twitter](Medium/Design/355.design-twitter.ipynb)
# 356. [Line Reflection](Medium/Maths/356.line-reflection.ipynb)
# 357. [Count Numbers with Unique Digits](Medium/Maths/357.count-numbers-with-unique-digits.ipynb)
# 358. Rearrange String k Distance Apart (Hard)
# 359. Logger Rate Limiter (Easy, Locked)
# 360. Sort Transformed Array (Medium, Locked)
# 361. Bomb Enemy (Medium, Locked)
# 362. Design Hit Counter (Medium, Locked)
# 363. Max Sum of Rectangle No Larger Than K (Hard)
# 364. Nested List Weight Sum II (Medium, Locked)
# 365. [Water and Jug Problem](Medium/Maths/365.water-and-jug-problem.ipynb)
# 366. Find Leaves of Binary Tree (Medium, Locked)
# 367. [Valid Perfect Square](Easy/Binary-Search/367.valid-perfect-square.ipynb)
# 368. [Largest Divisible Subset](Medium/Dynamic-Programming/Sequence/368.largest-divisible-subset.ipynb)
# 369. Plus One Linked List (Medium, Locked)
# 370. Range Addition (Medium, Locked)
# 371. [Sum of Two Integers](Medium/Bit-Manipulation/371.sum-of-two-integers.ipynb)
#
# 372. [Super Pow](Medium/Maths/372.super-pow.ipynb)
# 373. [Find K Pairs with Smallest Sums](Medium/Heapq/373.find-K-pairs-with-smallest-sums.ipynb)
# 374. [Guess Number Higher or Lower](Easy/Binary-Search/374.guess-number-higher-or-lower.ipynb)
# 375. [Guess Number Higher or Lower II](Medium/Dynamic-Programming/375.guess-number-higher-or-lower-II.ipynb)
# 376. [Wiggle Subsequence](Medium/Dynamic-Programming/Cached-Search/376.wiggle-subsequence.ipynb)
# 377. [Combination Sum IV](Medium/Dynamic-Programming/Sequence/377.combination-sum-IV.ipynb)
# 378. [Kth Smallest Element in a Sorted Matrix](Medium/Heap/378.Kth-smallest-element-in-a-sorted-matrix.ipynb)
# 379. Design Phone Directory (Medium, Locked)
# 380. [Insert Delete GetRandom O(1)](Medium/Design/380.insert-delete-getRandom-O(1).ipynb)
# 381. Insert Delete GetRandom O(1) - Duplicates allowed (Hard)
# 382. [Linked List Random Node](Medium/Maths/382.linked-list-random-node.ipynb)
# 383. [Ransom Note](Medium/Hash-Table/383.ransom-note.ipynb)
# 384. [Shuffle an Array](Medium/Design/384.shuffle-an-array.ipynb)
#
# 385. [Mini Parser](Medium/Stack/385.mini-parser.ipynb)
# 386. [Lexicographical Numbers](Medium/String/386.lexicographical-numbers.ipynb)
# 387. [First Unique Character in a String](Easy/Hash-Table/387.first-unique-character-in-a-string.ipynb)
# 388. [Longest Absolute File Path](Medium/String/388.longest-absolute-file-path.ipynb)
# 389. [Find the Difference](Easy/Hash-Table/389.find-the-difference.ipynb)
# 390. [Elimination Game](Medium/Maths/390.elimination-game.ipynb)
# 391. Perfect Rectangle (Hard)
# 392. [Is Subsequence](Easy/Dynamic-Programming/Double-Sequence/392.is-subsequence.ipynb)
# 393. UTF-8 Validation (Medium, not finished-background info too complex)
# 394. [Decode String](Medium/Stack/394.decode-string.ipynb)
# 395. [Longest Substring with At Least K Repeating Characters](Medium/Divide-and-Conquer/395.longest-substring-with-at-least-K-repeating-characters.ipynb)
# 396. [Rotate Function](Medium/Maths/396.rotate-function.ipynb)
#
# 397. [Integer Replacement](Medium/Maths/397.integer-replacement.ipynb)
# 398. [Random Pick Index](Medium/Maths/398.random-pick-index.ipynb)
# 399. [Evaluate Division](Medium/Graph/399.evaluate-division.ipynb)
# 400. [Nth Digit](Medium/Math/400.Nth-digit.ipynb)
# 401. [Binary Watch](Easy/Maths/401.binary-watch.ipynb)
# 402. [Remove K Digits](Medium/Stack/402.remove-K-digits.ipynb)
# 403. Frog Jump (Hard)
# 404. [Sum of Left Leaves](Easy/Tree/Recursion/404.sum-of-left-leaves.ipynb)
# 405. Convert a Number to Hexadecimal (Easy, not finished-background info too complex)
# 406. [Queue Reconstruction by Height](Medium/Maths/406.queue-reconstruction-by-height.ipynb)
# 407. Trapping Rain Water II (Hard)
# 408. Valid Word Abbreviation (Easy, Locked)
# 409. [Longest Palindrome](Easy/Hash-Table/409.longest-palindrome.ipynb)
# 410. Split Array Largest Sum (Hard)
# 411. Minimum Unique Word Abbreviation (Hard, Locked)
# 412. [Fizz Buzz](Easy/Maths/412.fizz-buzz.ipynb)
#
# 413. [Arithmetic Slices](Medium/Maths/413.arithmetic-slices.ipynb)
# 414. [Third Maximum Number](Easy/Array/414.third-maximum-number.ipynb)
# 415. [Add Strings](Easy/String/415.add-strings.ipynb)
# 416. [Partition Equal Subset Sum](Medium/Dynamic-Programming/Sequence/416.partition-equal-subset-sum.ipynb)
# 417. [Pacific Atlantic Water Flow](Medium/Breadth-First-Search/Queue-Implementation/417.pacific-atlantic-water-flow.ipynb)
# 418. Sentence Screen Fitting (Medium, Locked)
# 419. [Battleships in a Board](Medium/Maths/419.battleships-in-a-board.ipynb)
# 420. Strong Password Checker (Hard)
# 421. [Maximum XOR of Two Numbers in an Array](Medium/Bit-Manipulation/421.maximum-XOR-of-two-numbers-in-an-array.ipynb)
# 422. Valid Word Square (Easy, Locked)
# 423. [Reconstruct Original Digits from English](Medium/Maths/423.reconstruct-original-digits-from-english.ipynb)
# 424. [Longest Repeating Character Replacement](Medium/Two-Pointers/424.longest-repeating-character-replacement.ipynb)
# 425. Word Squares (Hard, Locked)
# 426. Convert Binary Search Tree to Sorted Doubly Linked List (Medium, Locked)
# 427. Construct Quad Tree (Medium, not finished-background info too complex)
# 428. Serialize and Deserialize N-ary Tree (Hard, Locked)
# 429. [N-ary Tree Level Order Traversal](Medium/Breadth-First-Search/Level-Traversal/429.N-ary-tree-level-order-traversal.ipynb)
#
# 430. [Flatten a Multilevel Doubly Linked List](Medium/Depth-First-Search/430.flatten-a-multilevel-doubly-linked-list.ipynb)
# 431. Encode N-ary Tree to Binary Tree (Hard, Locked)
# 432. All O one Data Structure (Hard)
# 433. [Minimum Genetic Mutation](Medium/Breadth-First-Search/Shortest-Path/433.minimum-genetic-mutation.ipynb)
# 434. [Number of Segments in a String](Easy/String/434.number-of-segments-in-a-string.ipynb)
# 435. [Non-overlapping Intervals](Medium/Sort/435.non-overlapping-intervals.ipynb)
# 436. [Find Right Interval](Medium/Binary-Search/436.find-right-interval.ipynb)
# 437. [Path Sum III](Medium/Tree/Recursion/437.path-sum-III.ipynb)
# 438. [Find All Anagrams in a String](Medium/Two-Pointers/Chasing-Two-Pointers/438.find-all-anagrams-in-a-string.ipynb)
# 439. Ternary Expression Parser (Medium, Locked)
# 440. K-th Smallest in Lexicographical Order (Hard)
# 441. [Arranging Coins](Easy/Binary-Search/441.arranging-coins.ipynb)
# 442. [Find All Duplicates in an Array](Medium/Hash-Table/442.find-all-duplicates-in-an-array.ipynb)
# 443. [String Compression](Easy/String/443.string-compression.ipynb)
# 444. Sequence Reconstruction (Medium, Locked)
# 445. [Add Two Numbers II](Medium/Linked-List/445.add-two-numbers-II.ipynb)
# 446. Arithmetic Slices II - Subsequence (Hard)
#
# (07/26/2020 checkpoint, increment: 77, cumulative: 277)

# %% [markdown]
# 447. [Number of Boomerangs](Easy/Hash-Table/447.number-of-boomerangs.ipynb)
# 448. [Find All Numbers Disappeared in an Array](Easy/Array/448.find-all-numbers-disappeared-in-an-array.ipynb)
# 449. [Serialize and Deserialize BST](Medium/Tree/Recursion/449.serialize-and-deserialize-BST.ipynb)
# 450. [Delete Node in a BST](Medium/Tree/Recursion/450.delete-node-in-a-BST.ipynb)
# 451. [Sort Characters By Frequency](Medium/Heap/451.sort-characters-by-frequency.ipynb)
# 452. [Minimum Number of Arrows to Burst Balloons](Medium/Greedy/452.minimum-number-of-arrows-to-burst-balloons.ipynb)
# 453. [Minimum Moves to Equal Array Elements](Easy/Maths/453.minimum-moves-to-equal-array-elements.ipynb)
# 454. [4Sum II](Medium/Hash-Table/454.4Sum-II.ipynb)
# 455. [Assign Cookies](Easy/Greedy/455.assign-cookies.ipynb)
# 456. [132 Pattern](Medium/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/456.132-pattern.ipynb)
#
# 457. [Circular Array Loop](Medium/Two-Pointers//Chasing-Two-Pointers/457.circular-array-loop.ipynb)
# 458. Poor Pigs (Hard)
# 459. [Repeated Substring Pattern](Easy/String/459.repeated-substring-pattern.ipynb)
# 460. LFU Cache (Hard)
# 461. [Hamming Distance](Easy/Bit-Manipulation/461.hamming-distance.ipynb)
# 462. [Minimum Moves to Equal Array Elements II](Medium/Maths/462.minimum-moves-to-equal-array-elements-II.ipynb)
# 463. [Island Perimeter](Easy/Maths/463.island-perimeter.ipynb)
# 464. [Can I Win](Medium/Dynamic-Programming/Cached-Search/464.can-I-win.ipynb)
# 465. Optimal Account Balancing (Hard, Locked)
# 466. Count The Repetitions (Hard)
# 467. [Unique Substrings in Wraparound String](Medium/Dynamic-Programming/Cached-Search/467.unique-substrings-in-wraparound-string.ipynb)
# 468. Validate IP Address (Medium, not finished-background info too complex)
# 469. Convex Polygon (Medium, Locked)
# 470. [Implement Rand10() Using Rand7()](Medium/Maths/470.implement-rand10()-using-rand7().ipynb)
# 471. Encode String with Shortest Length (Hard, Locked)
# 472. Concatenated Words (Hard)
# 473. [Matchsticks to Square](Medium/Depth-First-Search/473.matchsticks-to-square.ipynb)
# 474. [Ones and Zeroes](Medium/Dynamic-Programming/Double-Sequence/474.ones-and-zeroes.ipynb)
#
# 475. [Heaters](Easy/Binary-Search/475.heaters.ipynb)
# 476. [Number Complement](Easy/Bit-Manipulation/476.number-complement.ipynb)
# 477. [Total Hamming Distance](Medium/Bit-Manipulation/477.total-hamming-distance.ipynb)
# 478. [Generate Random Point in a Circle](Medium/Maths/478.generate-random-point-in-a-circle.ipynb)
# 479. Largest Palindrome Product (Hard)
# 480. Sliding Window Median (Hard)
# 481. Magical String (Medium, not finished since not understanding the question...)
# 482. [License Key Formatting](Easy/String/482.license-key-formatting.ipynb)
# 483. Smallest Good Base (Hard)
# 484. Find Permutation (Medium, Locked)
# 485. [Max Consecutive Ones](Easy/Array/485.max-consecutive-ones.ipynb)
# 486. [Predict the Winner](Medium/Dynamic-Programming/Cached-Search/486.predict-the-winner.ipynb)
# 487. Max Consecutive Ones II (Medium, Locked)
# 488. Zuma Game (Hard)
# 489. (Not algo)
# 490. The Maze (Medium, Locked)
# 491. [Increasing Subsequences](Medium/Dynamic-Programming/Cached-Search/491.increasing-subsequences.ipynb)
# 492. [Construct the Rectangle](Easy/Array/492.construct-the-rectangle.ipynb)
# 493. Reverse Pairs (Hard)
# 494. [Target Sum](Medium/Dynamic-Programming/Backpack/494.target-sum.ipynb)
# 495. [Teemo Attacking](Medium/Array/495.teemo-attacking.ipynb)
#
# 496. [Next Greater Element I](Easy/Stack/Monotonic-Stack/496.next-greater-element-I.ipynb)
# 497. [Random Point in Non-overlapping Rectangles](Medium/Maths/497.random-point-in-non-overlapping-rectangles.ipynb)
# 498. [Diagonal Traverse](Medium/Array/498.diagonal-traverse.ipynb)
# 499. The Maze III (Hard)
# 500. [Keyboard Row](Easy/Hash-Table/500.keyboard-row.ipynb)
# 501. [Find Mode in Binary Search Tree](Easy/Tree/Recursion/501.find-mode-in-binary-search-tree.ipynb)
# 502. IPO (Hard)
# 503. [Next Greater Element II](Medium/Stack/Monotonic-Stack/503.next-greater-element-II.ipynb)
# 504. [Base 7](Easy/Maths/504.base-7.ipynb)
# 505. The Maze II (Hard)
# 506. [Relative Ranks](Easy/Array/506.relative-ranks.ipynb)
# 507. [Perfect Number](Easy/Maths/507.perfect-number.ipynb)
# 508. [Most Frequent Subtree Sum](Medium/Tree/Recursion/508.most-frequent-subtree-sum.ipynb)
# 509. [Fibonacci Number](Easy/Dynamic-Programming/Sequence/509.fibonacci-number.ipynb)
# 510. Inorder Successor in BST II (Medium, Locked)
# 511. (Not algo)
# 512. (Not algo)
#
# 513. [Find Bottom Left Tree Value](Medium/Tree/Level-Traversal/513.find-bottom-left-tree-value.ipynb)
# 514. Freedom Trail (Hard)
# 515. [Find Largest Value in Each Tree Row](Medium/Tree/Level-Traversal/515.find-largest-value-in-each-tree-row.ipynb)
# 516. [Longest Palindromic Subsequence](Medium/Dynamic-Programming/516.longest-palindromic-subsequence.ipynb)
# 517. Super Washing Machines (Hard)
# 518. [Coin Change 2](Medium/Dynamic-Programming/Backpack/518.coin-change-2.ipynb)
# 519. [Random Flip Matrix](Medium/Maths/519.random-flip-matrix.ipynb)
# 520. [Detect Capital](Easy/String/520.detect-capital.ipynb)
# 521. [Longest Uncommon Subsequence I](Easy/String/521.longest-uncommon-subsequence-I.ipynb)
# 522. [Longest Uncommon Subsequence II](Medium/Two-Pointers/Chasing-Two-Pointers/522.longest-uncommon-subsequence-II.ipynb)
# 523. [Continuous Subarray Sum](Medium/Dynamic-Programming/Sequence/523.continuous-subarray-sum.ipynb)
# 524. [Longest Word in Dictionary through Deleting](Medium/Two-Pointers/Racing-Two-Pointers/524.longest-word-in-dictionary-through-deleting.ipynb)
#
# 525. [Contiguous Array](Medium/Cumsum/525.contiguous-array.ipynb)
# 526. [Beautiful Arrangement](Medium/Depth-First-Search/526.beautiful-arrangement.ipynb)
# 527. Word Abbreviation (Hard, Locked)
# 528. [Random Pick with Weight](Medium/Binary-Search/528.random-pick-with-weight.ipynb)
# 529. [Minesweeper](Medium/Depth-First-Search/529.Minesweeper.ipynb)
# 530. [Minimum Absolute Difference in BST](Easy/Tree/Recursion/530.minimum-absolute-difference-in-BST.ipynb)
# 531. Lonely Pixel I (Medium, Locked)
# 532. [K-diff Pairs in an Array](Easy/Hash-Table/532.K-diff-pairs-in-an-array.ipynb)
# 533. Lonely Pixel II (Medium, Locked)
# 534. (Not algo)
# 535. Encode and Decode TinyURL (Medium, not finished since background too complex)
# 536. Construct Binary Tree from String (Medium, Locked)
# 537. [Complex Number Multiplication](Medium/Maths/537.complex-number-multiplication.ipynb)
# 538. [Convert BST to Greater Tree](Easy/Tree/BST/538.convert-BST-to-greater-tree.ipynb)
# 539. [Minimum Time Difference](Medium/String/539.minimum-time-difference.ipynb)
# 540. [Single Element in a Sorted Array](Medium/Binary-Search/540.single-element-in-a-sorted-array.ipynb)
#
# 541. [Reverse String II](Easy/String/541.reverse-string-II.ipynb)
# 542. [01 Matrix](Medium/Breadth-First-Search/Shortest-Path/542.01-matrix.ipynb)
# 543. [Diameter of Binary Tree](Easy/Trees/Recursion/543.diameter-of-binary-tree.ipynb)
# 544. Output Contest Matches (Medium, Locked)
# 545. Boundary of Binary Tree (Medium, Locked)
# 546. Remove Boxes (Hard)
# 547. [Friend Circles](Medium/Depth-First-Search/Union-Find/547.friend-circles.ipynb)
# 548. Split Array with Equal Sum (Medium, Locked)
# 549. Binary Tree Longest Consecutive Sequence II (Medium, Locked)
# 550. (Not algo)
# 551. [Student Attendance Record I](Easy/String/551.student-attendance-record-I.ipynb)
# 552. Student Attendance Record II (Hard)
# 553. [Optimal Division](Medium/Maths/553.optimal-division.ipynb)
# 554. [Brick Wall](Medium/Hash-Table/554.brick-wall.ipynb)
# 555. Split Concatenated Strings (Medium, Locked)
# 556. [Next Greater Element III](Medium/Maths/556.next-greater-element-III.ipynb)
# 557. [Reverse Words in a String III](Easy/String/557.reverse-words-in-a-string-III.ipynb)
# 558. Logical OR of Two Binary Grids Represented as Quad-Trees (Medium, not finished-background info too complex)
# 559. [Maximum Depth of N-ary Tree](Easy/Tree/Level-Traversal/559.maximum-depth-of-N-ary-tree.ipynb)
# 560. [Subarray Sum Equals K](Medium/Cumsum/560.subarray-sum-equals-K.ipynb)
# 561. [Array Partition I](Easy/Maths/561.array-partition-I.ipynb)
# 562. Longest Line of Consecutive One in Matrix (Medium, Locked)
# 563. [Binary Tree Tilt](Easy/Tree/Recursion/563.binary-tree-tilt.ipynb)
# 564. Find the Closest Palindrome (Hard)
# 565. [Array Nesting](Medium/Linked-List/565.array-nesting.ipynb)
#
# (08/02/2020 checkpoint, increment: 76, cumulative: 353)

# %% [markdown]
# 566. [Reshape the Matrix](Easy/Array/566.reshape-the-matrix.ipynb)
# 567. [Permutation in String](Medium/Two-Pointers/Chasing-Two-Pointers/567.permutation-in-string.ipynb)
# 568. Maximum Vacation Days (Hard, Locked)
# 569. (Not algo)
# 570. (Not algo)
# 571. (Not algo)
# 572. [Subtree of Another Tree](Easy/Tree/572.subtree-of-another-tree.ipynb)
# 573. Squirrel Simulation (Medium, Locked)
# 574. (Not algo)
# 575. [Distribute Candies](Easy/Hash-Table/575.distribute-candies.ipynb)
# 576. [Out of Boundary Paths](Medium/Dynamic-Programming/576.out-of-boundary-paths.ipynb)
# 577. (Not algo)
# 578. (Not algo)
# 579. (Not algo)
# 580. (Not algo)
# 581. [Shortest Unsorted Continuous Subarray](Easy/Sort/581.shortest-unsorted-continuous-subarray.ipynb)
# 582. Kill Process (Medium, Locked)
# 583. [Delete Operation for Two Strings](Medium/Dynamic-Programming/Double-Sequence/583.delete-operation-for-two-strings.ipynb)
# 584. (Not algo)
# 585. (Not algo)
# 586. (Not algo)
# 587. Erect the Fence (Hard)
# 588. Design In-Memory File System (Hard, Locked)
# 589. [N-ary Tree Preorder Traversal](Easy/Tree/Recursion/589.N-ary-tree-preorder-traversal.ipynb)
# 590. [N-ary Tree Postorder Traversal](Easy/Tree/Recursion/590.N-ary-tree-postorder-traversal.ipynb)
# 591. Tag Validator (Hard)
# 592. [Fraction Addition and Subtraction](Medium/Maths/592.fraction-addition-and-subtraction.ipynb)
#
# 593. [Valid Square](Medium/Maths/593.valid-square.ipynb)
# 594. [Longest Harmonious Subsequence](Easy/Hash-Table/594.longest-harmonious-subsequence.ipynb)
# 595. (Not algo)
# 596. (Not algo)
# 597. (Not algo)
# 598. [Range Addition II](Easy/Maths/598.range-addition-II.ipynb)
# 599. [Minimum Index Sum of Two Lists](Easy/Hash-Table/599.minimum-index-sum-of-two-lists.ipynb)
# 600. Non-negative Integers without Consecutive Ones (Hard)
# 601. (Not algo)
# 602. (Not algo)
# 603. (Not algo)
# 604. Design Compressed String Iterator (Easy, Locked)
# 605. [Can Place Flowers](Easy/Array/605.can-place-flowers.ipynb)
# 606. [Construct String from Binary Tree](Easy/Tree/Recursion/606.construct-string-from-binary-tree.ipynb)
# 607. (Not algo)
# 608. (Not algo)
# 609. [Find Duplicate File in System](Medium/String/609.find-duplicate-file-in-system.ipynb)
# 610. (Not algo)
# 611. [Valid Triangle Number](Medium/Binary-Search/611.valid-triangle-number.ipynb)
# 612. (Not algo)
# 613. (Not algo)
# 614. (Not algo)
# 615. (Not algo)
# 616. Add Bold Tag in String (Medium, Locked)
# 617. [Merge Two Binary Trees](Easy/Trees/Recursion/617.merge-two-binary-trees.ipynb)
# 618. (Not algo)
# 619. (Not algo)
# 620. (Not algo)
# 621. [Task Scheduler](Medium/Greedy/621.task-scheduler.ipynb)
#
# 622. [Design Circular Queue](Medium/Design/622.design-circular-queue.ipynb)
# 623. [Add One Row to Tree](Medium/Tree/Level-Traversal/623.add-one-row-to-tree.ipynb)
# 624. Maximum Distance in Arrays (Easy, Locked)
# 625. Minimum Factorization (Medium, Locked)
# 626. (Not algo)
# 627. (Not algo)
# 628. [Maximum Product of Three Numbers](Easy/Maths/628.maximum-product-of-three-numbers.ipynb)
# 629. K Inverse Pairs Array (Hard)
# 630. Course Schedule III (Hard)
# 631. Design Excel Sum Formula (Hard, Locked)
# 632. Smallest Range Covering Elements from K Lists (Hard)
# 633. [Sum of Square Numbers](Easy/Two-Pointers/Converging-Two-Pointers/633.sum-of-square-numbers.ipynb)
# 634. Find the Derangement of An Array (Medium, Locked)
# 635. Design Log Storage System (Medium, Locked)
# 636. [Exclusive Time of Functions](Medium/Stack/636.exclusive-time-of-functions.ipynb)
# 637. [Average of Levels in Binary Tree](Easy/Tree/637.average-of-levels-in-binary-tree.ipynb)
# 638. [Shopping Offers](Medium/Depth-First-Search/638.shopping-offers.ipynb)
# 639. (Not algo)
# 640. [Solve the Equation](Medium/Maths/640.solve-the-equation.ipynb)
# 641. [Design Circular Deque](Medium/Design/641.design-circular-deque.ipynb)
# 642. Design Search Autocomplete System (Hard, Locked)
# 643. [Maximum Average Subarray I](Easy/Cumsum/643.maximum-average-subarray-I.ipynb)
# 644. Maximum Average Subarray II (Hard, Locked)
# 645. [Set Mismatch](Easy/Hash-Table/645.set-mismatch.ipynb)
# 646. [Maximum Length of Pair Chain](Medium/Dynamic-Programming/Cached-Search/646.maximum-length-of-pair-chain.ipynb)
# 647. [Palindromic Substrings](Medium/String/647.palindromic-substrings.ipynb)
# 648. [Replace Words](Medium/Hash-Table/648.replace-words.ipynb)
# 649. [Dota2 Senate](Medium/Greedy/649.Dota2-senate.ipynb)
# 650. [2 Keys Keyboard](Medium/Dynamic-Programming/650.2-keys-keyboard.ipynb)
# 651. 4 Keys Keyboar (Medium, Locked)
# 652. [Find Duplicate Subtrees](Medium/Tree/652.find-duplicate-subtrees.ipynb)
# 653. [Two Sum IV - Input is a BST](Easy/Tree/BST/653.two-sum-IV-input-is-a-BST.ipynb)
# 654. [Maximum Binary Tree](Medium/Tree/Recursion/654.maximum-binary-tree.ipynb)
# 655. [Print Binary Tree](Medium/Tree/Recursion/655.print-binary-tree.ipynb)
# 656. Coin Path (Hard, Locked)
# 657. [Robot Return to Origin](Easy/String/657.robot-return-to-origin.ipynb)
# 658. [Find K Closest Elements](Medium/Binary-Search/658.find-K-closest-elements.ipynb)
# 659. [Split Array into Consecutive Subsequences](Medium/Heap/659.split-array-into-consecutive-subsequences.ipynb)
# 660. Remove 9 (Hard, Locked)
# 661. [Image Smoother](Easy/Array/661.image-smoother.ipynb)
# 662. [Maximum Width of Binary Tree](Medium/Tree/Level-Traversal/662.maximum-width-of-binary-tree.ipynb)
# 663. Equal Tree Partition (Medium, Locked)
# 664. Strange Printer (Hard)
# 665. [Non-decreasing Array](Easy/Array/665.non-decreasing-array.ipynb)
# 666. Path Sum IV (Medium, Locked)
# 667. [Beautiful Arrangement II](Medium/Array/667.beautiful-arrangement-II.ipynb)
# 668. Kth Smallest Number in Multiplication Table (Hard)
# 669. [Trim a Binary Search Tree](Easy/Tree/Recursion/669.trim-a-binary-search-tree.ipynb)
# 670. [Maximum Swap](Medium/Maths/670.maximum-swap.ipynb)
# 671. [Second Minimum Node In a Binary Tree](Easy/Tree/Recursion/671.second-minimum-node-in-a-binary-tree.ipynb)
# 672. [Bulb Switcher II](Medium/Maths/672.bulb-switcher-II.ipynb)
# 673. [Number of Longest Increasing Subsequence](Medium/Dynamic-Programming/Sequence/673.number-of-longest-increasing-subsequence.ipynb)
# 674. [Longest Continuous Increasing Subsequence](Easy/Array/674.longest-continuous-increasing-subsequence.ipynb)
# 675. Cut Off Trees for Golf Event (Hard)
# 676. [Implement Magic Dictionary](Medium/Hash-Table/676.implement-magic-dictionary.ipynb)
# 677. [Map Sum Pairs](Medium/Special-Data-Structure/677.map-sum-pairs.ipynb)
# 678. [Valid Parenthesis String](Medium/String/678.valid-parenthesis-string.ipynb)
# 679. 24 Game (Hard)
# 680. [Valid Palindrome II](Easy/String/680.valid-palindrome-II.ipynb)
# 681. Next Closest Time (Medium, Locked)
# 682. [Baseball Game](Easy/Stack/682.baseball-game.ipynb)
# 683. K Empty Slots (Hard, Locked)
# 684. [Redundant Connection](Medium/Graph/684.redundant-connection.ipynb)
# 685. Redundant Connection II (Hard)
# 686. [Repeated String Match](Easy/String/686.repeated-string-match.ipynb)
# 687. [Longest Univalue Path](Easy/Tree/Recursion/687.longest-univalue-path.ipynb)
# 688. [Knight Probability in Chessboard](Medium/Dynamic-Programming/688.knight-probability-in-chessboard.ipynb)
# 689. Maximum Sum of 3 Non-Overlapping Subarrays (Hard)
# 690. [Employee Importance](Easy/Breadth-First-Search/Level-Traversal/690.employee-importance.ipynb)
# 691. Stickers to Spell Word (Hard)
# 692. [Top K Frequent Words](Medium/Heap/692.top-K-frequent-words.ipynb)
# 693. [Binary Number with Alternating Bits](Easy/Bit-Manipulation/693.binary-number-with-alternating-bits.ipynb)
# 694. Number of Distinct Islands (Medium, Locked)
#
# 695. [Max Area of Island](Medium/Depth-First-Search/695.max-area-of-island.ipynb)
# 696. [Count Binary Substrings](Easy/Two-Pointers/Chasing-Two-Pointers/696.count-binary-substrings.ipynb)
# 697. [Degree of an Array](Easy/Array/697.degree-of-an-array.ipynb)
# 698. [Partition to K Equal Sum Subsets](Medium/Depth-First-Search/698.partition-to-k-equal-sum-subsets.ipynb)
# 699. Falling Squares (Hard)
# 700. [Search in a Binary Search Tree](Easy/Tree/Recursion/700.search-in-a-binary-search-tree.ipynb)
# 701. [Insert into a Binary Search Tree](Medium/Tree/Recursion/701.insert-into-a-binary-search-tree.ipynb)
# 702. Search in a Sorted Array of Unknown Size (Medium, Locked)
# 703. [Kth Largest Element in a Stream](Easy/Heap/703.Kth-largest-element-in-a-stream.ipynb)
# 704. [Binary Search](Easy/Binary-Search/704.binary-search.ipynb)
# 705. [Design HashSet](Easy/Design/705.design-hashset.ipynb)
# 706. [Design HashMap](Easy/Design/706.design-hashmap.ipynb)
# 707. [Design Linked List](Medium/Design/707.design-linked-list.ipynb)
# 708. Insert into a Sorted Circular Linked List (Medium, Locked)
# 709. [To Lower Case](Easy/String/709.to-lower-case.ipynb)
# 710. Random Pick with Blacklist (Hard)
# 711. Number of Distinct Islands II (Hard, Locked)
# 712. [Minimum ASCII Delete Sum for Two Strings](Medium/Dynamic-Programming/Double-Sequence/712.minimum-ASCII-delete-sum-for-two-strings.ipynb)
# 713. [Subarray Product Less Than K](Medium/Two-Pointers/Chasing-Two-Pointers/713.subarray-product-less-than-K.ipynb)
#
# (08/09/2020 checkpoint, increment: 79, cumulative: 432 - blackout week)

# %% [markdown]
# 714. [Best Time to Buy and Sell Stock with Transaction Fee](Medium/Dynamic-Programming/Sequence/714.best-time-to-buy-and-sell-stock-with-transaction-fee.ipynb)
# 715. Range Module (Hard)
# 716. Max Stack (Easy, Locked)
# 717. [1-bit and 2-bit Characters](Easy/Dynamic-Programming/Sequence/717.1-bit-and-2-bit-characters.ipynb)
# 718. [Maximum Length of Repeated Subarray](Medium/Dynamic-Programming/Double-Sequence/718.maximum-length-of-repeated-subarray.ipynb)
# 719. Find K-th Smallest Pair Distance (Hard)
# 720. [Longest Word in Dictionary](Easy/Special-Data-Structure/720.longest-word-in-dictionary.ipynb)
# 721. [Accounts Merge](Medium/Graph/721.accounts-merge.ipynb)
# 722. [Remove Comments](Medium/String/722.remove-comments.ipynb)
# 723. Candy Crush (Medium, Locked)
# 724. [Find Pivot Index ](Easy/Array/724.find-pivot-index.ipynb)
# 725. [Split Linked List in Parts](Medium/Cumsum/725.split-linked-list-in-parts.ipynb)
# 726. Number of Atoms (Hard)
# 727. Minimum Window Subsequence (Hard, Locked)
# 728. [Self Dividing Numbers](Easy/Maths/728.self-dividing-numbers.ipynb)
# 729. [My Calendar I](Medium/Binary-Search/729.my-calendar-I.ipynb)
# 730. Count Different Palindromic Subsequences (Hard)
#
# 731. [My Calendar II](Medium/Array/731.my-calendar-II.ipynb)
# 732. (Not algo)
# 733. [Flood Fill](Easy/Breadth-First-Search/Level-Traversal/733.flood-fill.ipynb)
# 734. Sentence Similarity (Easy, Locked)
# 735. [Asteroid Collision](Medium/Stack/735.asteroid-collision.ipynb)
# 736. Parse Lisp Expression (Hard)
# 737. Sentence Similarity II (Medium, Locked)
# 738. [Monotone Increasing Digits](Medium/Greedy/738.monotone-increasing-digits.ipynb)
# 739. [Daily Temperatures](Medium/Stack/Monotonic-Stack/739.daily-temperatures.ipynb)
# 740. [Delete and Earn](Medium/Dynamic-Programming/740.delete-and-earn.ipynb)
# 741. Cherry Pickup (Hard)
# 742. Closest Leaf in a Binary Tree (Medium, Locked)
# 743. [Network Delay Time](Medium/Breadth-First-Search/Shortest-Path/743.network-delay-time.ipynb)
# 744. [Find Smallest Letter Greater Than Target](Easy/Binary-Search/744.find-smallest-letter-greater-than-target.ipynb)
# 745. Prefix and Suffix Search (Hard)
# 746. [Min Cost Climbing Stairs](Easy/Dynamic-Programming/Sequence/746.min-cost-climbing-stairs.ipynb)
# 747. [Largest Number At Least Twice of Others](Easy/Array/747.largest-number-at-least-twice-of-others.ipynb)
#
# 748. [Shortest Completing Word](Easy/Hash-Table/748.shortest-completing-word.ipynb)
# 749. Contain Virus (Hard)
# 750. Number Of Corner Rectangles (Medium, Locked)
# 751. IP to CIDR (Medium, Locked)
# 752. [Open the Lock](Medium/Breadth-First-Search/Queue-Implementation/752.open-the-lock.ipynb)
# 753. Cracking the Safe (Hard)
# 754. [Reach a Number](Medium/Maths/754.reach-a-number.ipynb)
# 755. Pour Water (Medium, Locked)
# 756. [Pyramid Transition Matrix](Medium/Depth-First-Search/756.pyramid-transition-matrix.ipynb)
# 757. Set Intersection Size At Least Two (Hard)
# 758. Bold Words in String (Easy, Locked)
# 759. Employee Free Time (Hard, Locked)
# 760. Find Anagram Mappings (Easy, Locked)
# 761. Special Binary String (Hard)
# 762. [Prime Number of Set Bits in Binary Representation](Easy/Bit-Manipulation/762.prime-number-of-set-bits-in-binary-representation.ipynb)
# 763. [Partition Labels](Medium/Greedy/763.partition-labels.ipynb)
# 764. [Largest Plus Sign](Medium/Dynamic-Programming/Double-Sequence/764.largest-plus-sign.ipynb)
# 765. Couples Holding Hands (Hard)
# 766. [Toeplitz Matrix](Easy/Array/766.toeplitz-matrix.ipynb)
# 767. [Reorganize String](Medium/Sort/767.reorganize-string.ipynb)
# 768. Max Chunks To Make Sorted II (Hard)
# 769. [Max Chunks To Make Sorted](Medium/Array/769.max-chunks-to-make-sorted.ipynb)
# 770. Basic Calculator IV (Hard)
#
# 771. [Jewels and Stones](Easy/Hash-Table/771.jewels-and-stones.ipynb)
# 772. Basic Calculator III (Hard, Locked)
# 773. Sliding Puzzle (Hard)
# 774. Minimize Max Distance to Gas Station (Hard, Locked)
# 775. [Global and Local Inversions](Medium/Maths/775.global-and-local-inversions.ipynb)
# 776. Split BST (Medium, Locked)
# 777. [Swap Adjacent in LR String](Medium/Maths/777.swap-adjacent-in-LR-string.ipynb)
# 778. Swim in Rising Water (Hard)
# 779. [K-th Symbol in Grammar](Medium/Maths/779.k-th-symbol-in-grammar.ipynb)
# 780. Reaching Points (Hard)
# 781. [Rabbits in Forest](Medium/Maths/781.rabbits-in-forest.ipynb)
# 782. Transform to Chessboard (Hard)
# 783. [Minimum Distance Between BST Nodes](Easy/Tree/Recursion/783.minimum-distance-between-BST-nodes.ipynb)
# 784. [Letter Case Permutation](Medium/Dynamic-Programming/Cached-Search/784.letter-case-permutation.ipynb)
# 785. [Is Graph Bipartite?](Medium/Breadth-First-Search/Queue-Implementation/785.is-graph-bipartite.ipynb)
# 786. K-th Smallest Prime Fraction (Hard)
# 787. [Cheapest Flights Within K Stops](Medium/Graph/787.cheapest-flights-within-K-stops.ipynb)
# 788. [Rotated Digits](Medium/Maths/788.rotated-digits.ipynb)
# 789. [Escape The Ghosts](Medium/Maths/789.escape-the-ghosts.ipynb)
#
# 790. [Domino and Tromino Tiling](Medium/Dynamic-Programming/Double-Sequence/790.domino-and-tromino-tiling.ipynb)
# 791. [Custom Sort String](Medium/String/791.custom-sort-string.ipynb)
# 792. [Number of Matching Subsequences](Medium/Two-Pointers/Racing-Two-Pointers/792.number-of-matching-subsequences.ipynb)
# 793. Preimage Size of Factorial Zeroes Function (Hard)
# 794. [Valid Tic-Tac-Toe State](Medium/Maths/794.valid-tic-tac-toe-state.ipynb)
# 795. [Number of Subarrays with Bounded Maximum](Medium/Array/795.number-of-subarrays-with-bounded-maximum.ipynb)
# 796. [Rotate String](Easy/String/796.rotate-string.ipynb)
# 797. [All Paths From Source to Target](Medium/Depth-First-Search/797.all-paths-from-source-to-target.ipynb)
# 798. Smallest Rotation with Highest Score (Hard)
# 799. [Champagne Tower](Medium/Maths/799.champagne-tower.ipynb)
# 800. Similar RGB Color (Easy, Locked)
# 801. [Minimum Swaps To Make Sequences Increasing](Medium/Dynamic-Programming/Sequence/801.minimum-swaps-to-make-sequences-increasing.ipynb)
# 802. [Find Eventual Safe States](Medium/Graph/802.find-eventual-safe-states.ipynb)
# 803. Bricks Falling When Hit (Hard)
#
# 804. [Unique Morse Code Words](Easy/String/804.unique-morse-code-words.ipynb)
# 805. Split Array With Same Average (Hard)
# 806. [Number of Lines To Write String](Easy/String/806.number-of-lines-to-write-string.ipynb)
# 807. [Max Increase to Keep City Skyline](Medium/Maths/807.max-increase-to-keep-city-skyline.ipynb)
# 808. [Soup Servings](Medium/Dynamic-Programming/Double-Sequence/808.soup-servings.ipynb)
# 809. [Expressive Words](Medium/String/809.expressive-words.ipynb)
# 810. Chalkboard XOR Game (Hard)
# 811. [Subdomain Visit Count](Easy/String/811.subdomain-visit-count.ipynb)
# 812. [Largest Triangle Area](Easy/Maths/812.largest-triangle-area.ipynb)
# 813. [Largest Sum of Averages](Medium/Dynamic-Programming/Double-Sequence/813.largest-sum-of-averages.ipynb)
# 814. [Binary Tree Pruning](Medium/Tree/Recursion/814.binary-tree-pruning.ipynb)
# 815. Bus Routes (Hard)
# 816. [Ambiguous Coordinates](Medium/Maths/816.ambiguous-coordinates.ipynb)
#
# 817. [Linked List Components](Medium/Linked-List/817.linked-list-components.ipynb)
# 818. Race Car (Hard)
# 819. [Most Common Word](Easy/String/819.most-common-word.ipynb)
# 820. [Short Encoding of Words](Medium/Special-Data-Structure/820.short-encoding-of-words.ipynb)
# 821. [Shortest Distance to a Character](Easy/String/821.shortest-distance-to-a-character.ipynb)
# 822. [Card Flipping Game](Medium/Array/822.card-flipping-game.ipynb)
# 823. [Binary Trees With Factors](Medium/Dynamic-Programming/Sequence/823.binary-trees-with-factors.ipynb)
# 824. [Goat Latin](Easy/String/824.goat-latin.ipynb)
# 825. [riends Of Appropriate Ages](Medium/Array/825.friends-of-appropriate-ages.ipynb)
# 826. [Most Profit Assigning Work](Medium/Two-Pointers/826.most-profit-assigning-work.ipynb)
# 827. Making A Large Island (Hard)
# 828. Count Unique Characters of All Substrings of a Given String (Hard)
# 829. Consecutive Numbers Sum (Hard)
# 830. [Positions of Large Groups](Easy/Two-Pointers/Chasing-Two-Pointers/830.positions-of-large-groups.ipynb)
# 831. [Masking Personal Information](Medium/String/831.masking-personal-information.ipynb)
# 832. [Flipping an Image](Easy/Array/832.flipping-an-image.ipynb)
# 833. [Find And Replace in String](Medium/String/833.find-and-replace-in-string.ipynb)
# 834. Sum of Distances in Tree (Hard)
# 835. [Image Overlap](Medium/Array/835.image-overlap.ipynb)
#
# (08/16/2020 checkpoint, increment: 75, cumulative: 507)

# %% [markdown]
# 836. [Rectangle Overlap](Easy/Maths/836.rectangle-overlap.ipynb)
# 837. [New 21 Game](Medium/Dynamic-Programming/Double-Sequence/837.new-21-game.ipynb)
# 838. [Push Dominoes](Medium/Two-Pointers/Chasing-Two-Pointers/838.push-dominoes.ipynb)
# 839. Similar String Groups (Hard)
# 840. [Magic Squares In Grid](Easy/Maths/840.magic-squares-in-grid.ipynb)
# 841. [Keys and Rooms](Medium/Depth-First-Search/841.keys-and-rooms.ipynb)
# 842. [Split Array into Fibonacci Sequence](Medium/Maths/842.split-array-into-fibonacci-sequence.ipynb)
# 843. Guess the Word (Hard)
# 844. [Backspace String Compare](Easy/Two-Pointers/Racing-Two-Pointers/844.backspace-string-compare.ipynb)
# 845. [Longest Mountain in Array](Medium/Two-Pointers/Converging-Two-Pointers/845.longest-mountain-in-array.ipynb)
# 846. [Hand of Straights](Medium/Greedy/846.hand-of-straights.ipynb)
# 847. Shortest Path Visiting All Nodes (Hard)
# 848. [Shifting Letters](Medium/String/848.shifting-letters.ipynb)
#
# 849. [Maximize Distance to Closest Person](Easy/Array/849.maximize-distance-to-closest-person.ipynb)
# 850. Rectangle Area II (Hard)
# 851. [Loud and Rich](Medium/Depth-First-Search/851.loud-and-rich.ipynb)
# 852. [Peak Index in a Mountain Array](Easy/Binary-Search/852.peak-index-in-a-mountain-array.ipynb)
# 853. [Car Fleet](Medium/Sort/853.car-fleet.ipynb)
# 854. K-Similar Strings (Hard)
# 855. [Exam Room](Medium/Hash-Table/855.exam-room.ipynb)
# 856. [Score of Parentheses](Medium/Stack/856.score-of-parentheses.ipynb)
# 857. Minimum Cost to Hire K Workers (Hard)
# 858. [Mirror Reflection](Medium/Maths/858.mirror-reflection.ipynb)
# 859. [Buddy Strings](Easy/String/859.buddy-strings.ipynb)
# 860. [Lemonade Change](Easy/Greedy/860.lemonade-change.ipynb)
# 861. [Score After Flipping Matrix](Medium/Greedy/861.score-after-flipping-matrix.ipynb)
# 862. Shortest Subarray with Sum at Least K (Hard)
#
# 863. [All Nodes Distance K in Binary Tree](Medium/Tree/Level-Traversal/863.all-nodes-distance-K-in-binary-tree.ipynb)
# 864. Shortest Path to Get All Keys (Hard)
# 865. [Smallest Subtree with all the Deepest Nodes](Medium/Tree/Recursion/865.smallest-subtree-with-all-the-deepest-nodes.ipynb)
# 866. [Prime Palindrome](Medium/Maths/866.prime-palindrome.ipynb)
# 867. [Transpose Matrix](Easy/Maths/867.transpose-matrix.ipynb)
# 868. [Binary Gap](Easy/Bit-Manipulation/868.binary-gap.ipynb)
# 869. [Reordered Power of 2](Medium/Maths/869.reordered-power-of-2.ipynb)
# 870. [Advantage Shuffle](Medium/Greedy/870.advantage-shuffle.ipynb)
# 871. Minimum Number of Refueling Stops (Hard)
# 872. [Leaf-Similar Trees](Easy/Tree/Recursion/872.leaf-similar-trees.ipynb)
# 873. [Length of Longest Fibonacci Subsequence](Medium/Dynamic-Programming/Cached-Search/873.length-of-longest-fibonacci-subsequence.ipynb)
# 874. [Walking Robot Simulation](Easy/Greedy/874.walking-robot-simulation.ipynb)
#
# 875. [Koko Eating Bananas](Medium/Binary-Search/875.Koko-eating-bananas.ipynb)
# 876. [Middle of the Linked List](Easy/Linked-List/876.middle-of-the-linked-list.ipynb)
# 877. [Stone Game](Medium/Dynamic-Programming/Double-Sequence/877.stone-game.ipynb)
# 878. Nth Magical Number (Hard)
# 879. Profitable Schemes (Hard)
# 880. [Decoded String at Index](Medium/String/880.decoded-string-at-index.ipynb)
# 881. [Boats to Save People](Medium/Two-Pointers/Converging-Two-Pointers/881.boats-to-save-people.ipynb)
# 882. Reachable Nodes In Subdivided Graph (Hard)
# 883. [Projection Area of 3D Shapes](Easy/Maths/883.projection-area-of-3D-shapes.ipynb)
# 884. [Uncommon Words from Two Sentences](Easy/Hash-Table/884.uncommon-words-from-two-sentences.ipynb)
# 885. [Spiral Matrix III](Medium/Maths/885.spiral-matrix-III.ipynb)
# 886. [Possible Bipartition](Medium/Breadth-First-Search/Queue-Implementation/886.possible-bipartition.ipynb)
# 887. Super Egg Drop (Hard)
# 888. [Fair Candy Swap](Easy/Two-Pointers/Racing-Two-Pointers/888.fair-candy-swap.ipynb)
# 889. [Construct Binary Tree from Preorder and Postorder Traversal](Medium/Tree/Recursion/889.construct-binary-tree-from-preorder-and-postorder-traversal.ipynb)
#
# 890. [Find and Replace Pattern](Medium/Hash-Table/890.find-and-replace-pattern.ipynb)
# 891. Sum of Subsequence Widths (Hard)
# 892. [Surface Area of 3D Shapes](Easy/Maths/892.surface-area-of-3D-shapes.ipynb)
# 893. [Groups of Special-Equivalent Strings](Easy/Hash-Table/893.groups-of-special-equivalent-strings.ipynb)
# 894. [All Possible Full Binary Trees](Medium/Dynamic-Programming/Sequence/894.all-possible-full-binary-trees.ipynb)
# 895. Maximum Frequency Stack (Hard)
# 896. [Monotonic Array](Easy/Maths/896.monotonic-array.ipynb)
# 897. [Increasing Order Search Tree](Easy/Tree/Recursion/897.increasing-order-search-tree.ipynb)
# 898. [Bitwise ORs of Subarrays](Medium/Dynamic-Programming/Sequence/898.bitwise-ORs-of-subarrays.ipynb)
# 899. Orderly Queue (Hard)
# 900. [RLE Iterator](Medium/Array/900.RLE-iterator.ipynb)
# 901. [Online Stock Span](Medium/Stack/901.online-stock-span.ipynb)
# 902. Numbers At Most N Given Digit Set (Hard)
# 903. Valid Permutations for DI Sequence (Hard)
# 904. [Fruit Into Baskets](Medium/Two-Pointers/Chasing-Two-Pointers/904.fruit-into-baskets.ipynb)
#
# 905. [Sort Array By Parity](Easy/Array/905.sort-array-by-parity.ipynb)
# 906. Super Palindromes (Hard)
# 907. [Sum of Subarray Minimums](Medium/Dynamic-Programming/Sequence/907.sum-of-subarray-minimums.ipynb)
# 908. [Smallest Range I](Easy/Maths/908.smallest-range-I.ipynb)
# 909. [Snakes and Ladders](Medium/Breadth-First-Search/Shortest-Path/909.snakes-and-ladders.ipynb)
# 910. [Smallest Range II](Medium/Maths/910.smallest-range-II.ipynb)
# 911. [Online Election](Medium/Binary-Search/911.online-election.ipynb)
# 912. [Sort an Array](Medium/Sort/912.sort-an-array.ipynb)
# 913. Cat and Mouse (Hard)
# 914. [X of a Kind in a Deck of Cards](Easy/Maths/914.X-of-a-kind-in-a-deck-of-cards.ipynb)
# 915. [Partition Array into Disjoint Intervals](Medium/Array/915.partition-array-into-disjoint-intervals.ipynb)
# 916. [Word Subsets](Medium/Hash-Table/916.word-subsets.ipynb)
#
# 917. [Reverse Only Letters](Easy/String/917.reverse-only-letters.ipynb)
# 918. [Maximum Sum Circular Subarray](Medium/Cumsum/918.maximum-sum-circular-subarray.ipynb)
# 919. [Complete Binary Tree Inserter](Medium/Tree/Level-Traversal/919.complete-binary-tree-inserter.ipynb)
# 920. Number of Music Playlists (Hard)
# 921. [Minimum Add to Make Parentheses Valid](Medium/String/921.minimum-add-to-make-parentheses-valid.ipynb)
# 922. [Sort Array By Parity II](Easy/Array/922.sort-array-by-parity-II.ipynb)
# 923. [3Sum With Multiplicity](Medium/Two-Pointers/Converging-Two-Pointers/923.3Sum-with-multiplicity.ipynb)
# 924. Minimize Malware Spread (Hard)
# 925. [Long Pressed Name](Easy/Two-Pointers/Racing-Two-Pointers/925.long-pressed-name.ipynb)
# 926. [Flip String to Monotone Increasing](Medium/Array/926.flip-string-to-monotone-increasing.ipyb)
# 927. Three Equal Parts (Hard)
# 928. Minimize Malware Spread II (Hard)
# 929. [Unique Email Addresses](Easy/String/929.unique-email-addresses.ipynb)
# 930. [Binary Subarrays With Sum](Medium/Two-Pointers/Chasing-Two-Pointers/930.binary-subarrays-with-sum.ipynb)
#
# (08/23/2020 checkpoint, increment: 71, cumulative: 578)

# %% [markdown]
# 931. [Minimum Falling Path Sum](Medium/Dynamic-Programming/931.minimum-falling-path-sum.ipynb)
# 932. [Beautiful Array](Medium/Maths/932.beautiful-array.ipynb)
# 933. [Number of Recent Calls](Easy/Queue/933.number-of-recent-calls.ipynb)
# 934. [Shortest Bridge](Medium/Breadth-First-Search/Shortest-Path/934.shortest-bridge.ipynb)
# 935. [Knight Dialer](Medium/Dynamic-Programming/935.knight-dialer.ipynb)
# 936. Stamping The Sequence (Hard)
# 937. [Reorder Data in Log Files](Easy/String/937.reorder-data-in-log-files.ipynb)
# 938. [Range Sum of BST](Easy/Tree/Recursion/938.range-sum-of-BST.ipynb)
# 939. [Minimum Area Rectangle](Medium/Hash-Table/939.minimum-area-rectangle.ipynb)
# 940. Distinct Subsequences II (Hard)
# 941. [Valid Mountain Array](Easy/Array/.ipynb)
# 942. [DI String Match](Easy/Array/942.DI-string-match.ipynb)
# 943. Find the Shortest Superstring (Hard)
#
# 944. [Delete Columns to Make Sorted](Easy/Array/944.delete-columns-to-make-sorted.ipynb)
# 945. [Minimum Increment to Make Array Unique](Medium/Array/945.minimum-increment-to-make-array-unique.ipynb)
# 946. [Validate Stack Sequences](Medium/Stack/946.validate-stack-sequences.ipynb)
# 947. [Most Stones Removed with Same Row or Column](Medium/Breadth-First-Search/Queue-Implementation/947.most-stones-removed-with-same-row-or-column.ipynb)
# 948. [Bag of Tokens](Medium/Greedy/948.bag-of-tokens.ipynb)
# 949. [Largest Time for Given Digits](Easy/Maths/949.largest-time-for-given-digits.ipynb)
# 950. [Reveal Cards In Increasing Order](Medium/Array/950.reveal-cards-in-increasing-order.ipynb)
# 951. [Flip Equivalent Binary Trees](Medium/Tree/Recursion/951.flip-equivalent-binary-trees.ipynb)
# 952. Largest Component Size by Common Factor (Hard)
# 953. [Verifying an Alien Dictionary](Easy/Two-Pointers/Racing-Two-Pointers953.verifying-an-alien-dictionary.ipynb)
# 954. [Array of Doubled Pairs](Medium/Hash-Table/954.array-of-doubled-pairs.ipynb)
#
# 955. [Delete Columns to Make Sorted II](Medium/Greedy/955.delete-columns-to-make-sorted-II.ipynb)
# 956. Tallest Billboard (Hard)
# 957. [Prison Cells After N Days](Medium/Hash-Table/957.prison-cells-after-N-days.ipynb)
# 958. [Check Completeness of a Binary Tree](Medium/Tree/Level-Traversal/958.check-completeness-of-a-binary-tree.ipynb)
# 959. [Regions Cut By Slashes](Medium/Depth-First-Search/959.regions-cut-by-slashes.ipynb)
# 960. Delete Columns to Make Sorted III (Hard)
# 961. [N-Repeated Element in Size 2N Array](Easy/Hash-Table/961.N-repeated-element-in-size-2N-array.ipynb)
# 962. [Maximum Width Ramp](Medium/Sort/962.maximum-width-ramp.ipynb)
# 963. [Minimum Area Rectangle II](Medium/Maths/963.minimum-area-rectangle-II.ipynb)
# 964. Least Operators to Express Number (Hard)
# 965. [Univalued Binary Tree](Easy/Tree/Recursion/965.univalued-binary-tree.ipynb)
# 966. [Vowel Spellchecker](Medium/Hash-Table/966.vowel-spellchecker.ipynb)
# 967. [Numbers With Same Consecutive Differences](Medium/Dynamic-Programming/Cached-Search/967.numbers-with-same-consecutive-differences.ipynb)
# 968. Binary Tree Cameras (Hard)
#
# 969. [Pancake Sorting](Medium/Sort/969.pancake-sorting.ipynb)
# 970. [Powerful Integers](Easy/Maths/970.powerful-integers.ipynb)
# 971. [Flip Binary Tree To Match Preorder Traversal](Medium/Tree/Recursion/971.flip-binary-tree-to-match-preorder-traversal.ipynb)
# 972. Equal Rational Numbers (Hard)
# 973. [K Closest Points to Origin](Medium/Heap/973.K-closest-points-to-origin.ipynb)
# 974. [Subarray Sums Divisible by K](Medium/Hash-Table/974.subarray-sums-divisible-by-K.ipynb)
# 975. Odd Even Jump (Hard)
# 976. [Largest Perimeter Triangle](Easy/Sort/976.largest-perimeter-triangle.ipynb)
# 977. [Squares of a Sorted Array](Easy/Two-Pointers/Converging-Two-Pointers/977.squares-of-a-sorted-array.ipynb)
# 978. [Longest Turbulent Subarray](Medium/Dynamic-Programming/Cached-Search/978.longest-turbulent-subarray.ipynb)
# 979. [istribute Coins in Binary Tree](Medium/Tree/Recursion/979.distribute-coins-in-binary-tree.ipynb)
# 980. Unique Paths III (Hard)
# 981. [Time Based Key-Value Store](Medium/Binary-Search/981.time-based-key-value-store.ipynb)
# 982. Triples with Bitwise AND Equal To Zero (Hard)
#
# 983. [Minimum Cost For Tickets](Medium/Dynamic-Programming/Sequence/983.minimum-cost-for-tickets.ipynb)
# 984. [String Without AAA or BBB](Medium/Greedy/984.string-without-AAA-or-BBB.ipynb)
# 985. [Sum of Even Numbers After Queries](Easy/Array/985.sum-of-even-numbers-after-queries.ipynb)
# 986. [Interval List Intersections](Medium/Two-Pointers/Racing-Two-Pointers/986.interval-list-intersections.ipynb)
# 987. [Vertical Order Traversal of a Binary Tree](Medium/Tree/Recursion/987.vertical-order-traversal-of-a-binary-tree.ipynb)
# 988. [Smallest String Starting From Leaf](Medium/Tree/Recursion/988.smallest-string-starting-from-leaf.ipynb)
# 989. [Add to Array-Form of Integer](Easy/String/989.add-to-array-form-of-integer.ipynb)
# 990. [Satisfiability of Equality Equations](Medium/Graph/990.satisfiability-of-equality-equations.ipynb)
# 991. [Broken Calculator](Medium/Greedy/991.broken-calculator.ipynb)
# 992. Subarrays with K Different Integers (Hard)
# 993. [Cousins in Binary Tree](Easy/Tree/Level-Traversal/993.cousins-in-binary-tree.ipynb)
#
# 994. [Rotting Oranges](Medium/Breadth-First-Search/Shortest-Path/994.rotting-oranges.ipynb)
# 995. Minimum Number of K Consecutive Bit Flips (Hard)
# 996. Number of Squareful Arrays (Hard)
# 997. [Find the Town Judge](Easy/Hash-Table/997.find-the-town-judge.ipynb)
# 998. [Maximum Binary Tree II](Medium/Tree/Recursion/998.maximum-binary-tree-II.ipynb)
# 999. [Available Captures for Rook](Easy/Array/999.available-captures-for-rook.ipynb)
# 1000. Minimum Cost to Merge Stones (Hard)
# 1001. Grid Illumination (Hard)
# 1002. [Find Common Characters](Easy/Hash-Table/1002.find-common-characters.ipynb)
# 1003. [Check If Word Is Valid After Substitutions](Medium/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/1003.check-if-word-is-valid-after-substitutions.ipynb)
# 1004. [Max Consecutive Ones III](Medium/Two-Pointers/Chasing-Two-Pointers/1004.max-consecutive-ones-III.ipynb)
# 1005. [Maximize Sum Of Array After K Negations](Easy/Greedy/1005.maximize-sum-of-array-after-K-negations.ipynb)
# 1006. [Clumsy Factorial](Medium/Maths/1006.clumsy-factorial.ipynb)
# 1007. [Minimum Domino Rotations For Equal Row](Medium/Greedy/1007.minimum-domino-rotations-for-equal-row.ipynb)
#
# 1008. [Construct Binary Search Tree from Preorder Traversal](Medium/Tree/Recursion/1008.construct-binary-search-tree-from-preorder-traversal.ipynb)
# 1009. [Complement of Base 10 Integer](Easy/Bit-Manipulation/1009.complement-of-base-10-integer.ipynb)
# 1010. [Pairs of Songs With Total Durations Divisible by 60](Easy/Hash-Table/1010.pairs-of-songs-with-total-durations-divisible-by-60.ipynb)
# 1011. [Capacity To Ship Packages Within D Days](Medium/Binary-Search/1011.capacity-to-ship-packages-within-D-days.ipynb)
# 1012. Numbers With Repeated Digits (Hard)
# 1013. [Partition Array Into Three Parts With Equal Sum](Easy/Cumsum/1013.partition-array-into-three-parts-with-equal-sum.ipynb)
# 1014. [Best Sightseeing Pair](Medium/Array/1014.best-sightseeing-pair.ipynb)
# 1015. [Smallest Integer Divisible by K](Medium/Maths/1015.smallest-integer-divisible-by-K.ipynb)
# 1016. [Binary String With Substrings Representing 1 To N](Medium/Bit-Manipulation/1016.binary-string-with-substrings-representing-1-to-N.ipynb)
# 1017. [Convert to Base -2](Medium/Bit-Manipulation/1017.convert-to-base--2.ipynb)
# 1018. [Binary Prefix Divisible By 5](Easy/Array/1018.binary-prefix-divisible-by-5.ipynb)
#
# (08/30/2020 checkpoint, increment: 70, cumulative: 648 - Phase I concludes)

# %% [markdown]
# 1019. [Next Greater Node In Linked List](Medium/Stack/Monotonic-Stack/1019.next-greater-node-in-linked-list.ipynb)
# 1020. [Number of Enclaves](Medium/Breadth-First-Search/1020.number-of-enclaves.ipynb)
# 1021. [Remove Outermost Parentheses](Easy/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/1021.remove-outermost-parentheses.ipynb)
# 1022. [Sum of Root To Leaf Binary Numbers](Easy/Tree/Recursion/1022.sum-of-root-to-leaf-binary-numbers.ipynb)
# 1023. [Camelcase Matching](Medium/Two-Pointers/Rasing-Two-Pointers/1023.camelcase-matching.ipynb)
# 1024. [Video Stitching](Medium/Greedy/1024.video-stitching.ipynb)
# 1025. [Divisor Game](Easy/Dynamic-Programming/Sequence/1025.divisor-game.ipynb)

# %% [markdown]
# 1026. [Maximum Difference Between Node and Ancestor](Medium/Tree/Recursion/1026.maximum-difference-between-node-and-ancestor.ipynb)
# 1027. [Longest Arithmetic Subsequence](Medium/Dynamic-Programming/Cached-Search/1027.longest-arithmetic-subsequence.ipynb)
# 1028. Recover a Tree From Preorder Traversal (Hard)
# 1029. [Two City Scheduling](Medium/Greedy/1029.two-city-scheduling.ipynb)
# 1030. [Matrix Cells in Distance Order](Easy/Breadth-First-Search/Queue-Implementation/1030.matrix-cells-in-distance-order.ipynb)
# 1031. [Maximum Sum of Two Non-Overlapping Subarrays](Medium/Dynamic-Programming/Sequence/1031.maximum-sum-of-two-non-overlapping-subarrays.ipynb)
# 1032. Stream of Characters (Hard)
# 1033. [Moving Stones Until Consecutive](Easy/Maths/1033.moving-stones-until-consecutive.ipynb)
# 1034. [Coloring A Border](Medium/Breadth-First-Search/Queue-Implementation/1034.coloring-a-border.ipynb)

# %% [markdown]
# 1035. [Uncrossed Lines](Medimm/Dynamic-Programming/Double-Sequence/1035.uncrossed-lines.ipynb)
# 1036. Escape a Large Maze (Hard)
# 1037. [Valid Boomerang](Easy/Maths/1037.valid-boomerang.ipynb)
# 1038. [Binary Search Tree to Greater Sum Tree](Medium/Trees/BST/1038.binary-search-tree-to-greater-sum-tree.ipynb)
# 1039. [Minimum Score Triangulation of Polygon](Medium/Dynamic-Programming/Cached-Search/1039.minimum-score-triangulation-of-polygon.ipynb)
# 1040. [Moving Stones Until Consecutive II](Medium/Maths/1040.moving-stones-until-consecutive-II.ipynb)
# 1041. [Robot Bounded In Circle](Medium/Maths/1041.robot-bounded-in-circle.ipynb)
# 1042. [Flower Planting With No Adjacent](Easy/Graph/1042.flower-planting-with-no-adjacent.ipynb)

# %% [markdown]
# 1043. [Partition Array for Maximum Sum](Medium/Dynamic-Programming/Sequence/1043.partition-array-for-maximum-sum.ipynb)
# 1044. Longest Duplicate Substring (Hard)
# 1045. (Not algo)
# 1046. [Last Stone Weight](Easy/Heap/1046.last-stone-weight.ipynb)
# 1047. [Remove All Adjacent Duplicates In String](Easy/Stack/1047.remove-all-adjacent-duplicates-in-string.ipynb)
# 1048. [Longest String Chain](Medium/Dynamic-Programming/Sequence/1048.longest-string-chain.ipynb)
# 1049. [Last Stone Weight II](Medium/Dynamic-Programming/Backpack/1049.last-stone-weight-II.ipynb)
# 1050. (Not algo)
# 1051. [Height Checker](Easy/Sort/1051.height-checker.ipynb)
# 1052. [Grumpy Bookstore Owner](Medium/Two-Pointers/Chasing-Two-Pointers/1052.grumpy-bookstore-owner.ipynb)

# %% [markdown]
# 1053. [Previous Permutation With One Swap](Medium/Maths/1053.previous-permutation-with-one-swap.ipynb)
# 1054. [Distant Barcodes](Medium/Sort/1054.distant-barcodes.ipynb)
# 1055. Shortest Way to Form String (Hard)
# 1056. Confusing Number (Hard)
# 1057. Campus Bikes (Hard)
# 1058. Minimize Rounding Error to Meet Target (Hard)
# 1059. All Paths from Source Lead to Destination (Hard)
# 1060. Missing Element in Sorted Array (Hard)
# 1061. Lexicographically Smallest Equivalent String (Hard)
# 1062. Longest Repeating Substring (Hard)
# 1063. Number of Valid Subarrays (Hard)
# 1064. Fixed Point (Hard)
# 1065. Index Pairs of a String (Hard)
# 1066. Campus Bikes II (Hard)
# 1067. Digit Count in Range (Hard)
# 1068. (Not algo)
# 1069. (Not algo)
# 1070. (Not algo)
# 1071. [Greatest Common Divisor of Strings](Easy/String/1071.greatest-common-divisor-of-strings.ipynb)
# 1072. [Flip Columns For Maximum Number of Equal Rows](Medium/Hash-Table/1072.flip-columns-for-maximum-number-of-equal-rows.ipynb)
# 1073. [Adding Two Negabinary Numbers](Medium/Maths/1073.adding-two-negabinary-numbers.ipynb)
# 1074. (Not algo)
# 1075. (Not algo)
# 1076. (Not algo)
# 1077. (Not algo)
# 1078. [Occurrences After Bigram](Easy/String/1078.occurrences-after-bigram.ipynb)
# 1079. [Letter Tile Possibilities](Medium/Dynamic-Programming/Cached-Search/1079.letter-tile-possibilities.ipynb)

# %% [markdown]
# 1080. [Insufficient Nodes in Root to Leaf Paths](Medium/Tree/Recursion/1080.insufficient-nodes-in-root-to-leaf-paths.ipynb)
# 1081. [Smallest Subsequence of Distinct Characters](Medium/Greedy/1081.smallest-subsequence-of-distinct-characters.ipynb)
# 1082. (Not algo)
# 1083. (Not algo)
# 1084. (Not algo)
# 1085. Sum of Digits in the Minimum Number (Easy, Locked)
# 1086. High Five (Easy, Locked)
# 1087. Brace Expansion (Medium, Locked)
# 1088. Confusing Number II (Hard, Locked)
# 1089. [Duplicate Zeros](Easy/Array/1089.duplicate-zeros.ipynb)
# 1090. [Largest Values From Labels](Medium/Heap/1090.largest-values-from-labels.ipynb)
# 1091. [Shortest Path in Binary Matrix](Medium/Breadth-First-Search/Shortest-Path/1091.shortest-path-in-binary-matrix.ipynb)
# 1092. Shortest Common Supersequence (Hard)
# 1093. [Statistics from a Large Sample](Medium/Maths/1093.statistics-from-a-large-sample.ipynb)
# 1094. [Car Pooling](Medium/Sort/1094.car-pooling.ipynb)

# %% [markdown]
# 1095. Find in Mountain Array (Hard)
# 1096. Brace Expansion II (Hard)
# 1097. (Not algo)
# 1098. (Not algo)
# 1099. Two Sum Less Than K (Easy, Locked)
# 1100. Find K-Length Substrings With No Repeated Characters (Medium, Locked)
# 1101. The Earliest Moment When Everyone Become Friends (Medium, Locked)
# 1102. Path With Maximum Minimum Value (Medium, Locked)
# 1103. [Distribute Candies to People](Easy/Binary-Search/1103.distribute-candies-to-people.ipynb)
# 1104. [Path In Zigzag Labelled Binary Tree](Medium/Maths/1104.path-in-zigzag-labelled-binary-tree.ipynb)
# 1105. [Filling Bookcase Shelves](Medium/Dynamic-Programming/Sequence/1105.filling-bookcase-shelves.ipynb)
# 1106. Parsing A Boolean Expression (Hard)
# 1107. (Not algo)
# 1108. [Defanging an IP Address](Easy/String/1108.defanging-an-IP-address.ipynb)
# 1109. [Corporate Flight Bookings](Medium/Maths/1109.corporate-flight-bookings.ipynb)
# 1110. [Delete Nodes And Return Forest](Medium/Tree/Recursion/1110.delete-nodes-and-return-forest.ipynb)
# 1111. [Maximum Nesting Depth of Two Valid Parentheses Strings](Medium/Greedy/1111.maximum-nesting-depth-of-two-valid-parentheses-strings.ipynb)
# 1112. (Not algo)
# 1113. (Not algo)
# 1114. (Not algo)
# 1115. (Not algo)
# 1116. (Not algo)
# 1117. (Not algo)
# 1118. Number of Days in a Month (Easy, Locked)
# 1119. Remove Vowels from a String (Easy, Locked)
# 1120. Maximum Average Subtree (Medium, Locked)
# 1121. Divide Array Into Increasing Sequences (Hard, Locked)

# %% [markdown]
# 1122. [Relative Sort Array](Easy/Sort/1122.relative-sort-array.ipynb)
# 1123. [Lowest Common Ancestor of Deepest Leaves](Medium/Tree/Recursion/1123.lowest-common-ancestor-of-deepest-leaves.ipynb)
# 1124. [Longest Well-Performing Interval](Medium/Stack/Monotonic-Stack/1124.longest-well-performing-interval.ipynb)
# 1125. Smallest Sufficient Team (Hard)
# 1126. (Not algo)
# 1127. (Not algo)
# 1128. [Number of Equivalent Domino Pairs](Easy/Hash-Table/1128.number-of-equivalent-domino-pairs.ipynb)
# 1129. [Shortest Path with Alternating Colors](Medium/Breadth-First-Search/Shortest-Path/1129.shortest-path-with-alternating-colors.ipynb)
# 1130. [Minimum Cost Tree From Leaf Values](Medium/Dynamic-Programming/Cached-Search/1130.minimum-cost-tree-from-leaf-values.ipynb)
# 1131. [Maximum of Absolute Value Expression](Medium/Maths/1131.maximum-of-absolute-value-expression.ipynb)
# 1132. (Not algo)
# 1133. Largest Unique Number (Easy, Locked)
# 1134. Armstrong Number (Easy, Locked)
# 1135. Connecting Cities With Minimum Cost (Medium, Locked)
# 1136. Parallel Courses (Hard, Locked)

# %% [markdown]
# 1137. [N-th Tribonacci Number](Easy/Hash-Table/1137.N-th-tribonacci-number.ipynb)
# 1138. [Alphabet Board Path](Medium/Hash-Table/1138.alphabet-board-path.ipynb)
# 1139. [Largest 1-Bordered Square](Medium/Dynamic-Programming/Double-Sequence/1139.largest-1-bordered-square.ipynb)
# 1140. [Stone Game II](Medium/Dynamic-Programming/Double-Sequence/1140.stone-game-II.ipynb)
# 1141. (Not algo)
# 1142. (Not algo)
# 1143. [Longest Common Subsequence](Medium/Dynamic-Programming/Double-Sequence/1143.longest-common-subsequence.ipynb)
# 1144. [Decrease Elements To Make Array Zigzag](Medium/Maths/1144.decrease-elements-to-make-array-zigzag.ipynb)
# 1145. [Binary Tree Coloring Game](Medium/Tree/Recursion/1145.binary-tree-coloring-game.ipynb)

# %% [markdown]
# 1146. [Snapshot Array](Medium/Binary-Search/1146.snapshot-array.ipynb)
# 1147. Longest Chunked Palindrome Decomposition (Hard)
# 1148. (Not algo)
# 1149. (Not algo)
# 1150. Check If a Number Is Majority Element in a Sorted Array (Easy, Locked)
# 1151. Minimum Swaps to Group All 1's Together (Medium, Locked)
# 1152. Analyze User Website Visit Pattern (Medium, Locked)
# 1153. String Transforms Into Another String (Hard, Locked)
# 1154. [Day of the Year](Easy/Maths/1154.day-of-the-year.ipynb)
# 1155. [Number of Dice Rolls With Target Sum](Medium/Dynamic-Programming/Sequence/1155.number-of-dice-rolls-with-target-sum.ipynb)
# 1156. [Swap For Longest Repeated Character Substring](Medium/Two-Pointers/Chasing-Two-Pointers/1156.swap-for-longest-repeated-character-substring.ipynb)
# 1157. Online Majority Element In Subarray (Hard)
# 1158. (Not algo)
# 1159. (Not algo)
# 1160. [Find Words That Can Be Formed by Characters](Easy/Hash-Table/1160.find-words-that-can-be-formed-by-characters.ipynb)
# 1161. [Maximum Level Sum of a Binary Tree](Medium/Tree/Level-Traversal/1161.maximum-level-sum-of-a-binary-tree.ipynb)
# 1162. [As Far from Land as Possible](Medium/Breadth-First-Search/1162.as-far-from-land-as-possible.ipynb)
# 1163. Last Substring in Lexicographical Order (Hard)
# 1164. (Not algo)
# 1165. Single-Row Keyboard (Easy, Locked)
# 1166. Design File System (Medium, Locked)
# 1167. Minimum Cost to Connect Sticks (Medium, Locked)
# 1168. Optimize Water Distribution in a Village (Hard, Locked)

# %% [markdown]
# 1169. [Invalid Transactions](Medium/String/1169.invalid-transactions.ipynb)
# 1170. [Compare Strings by Frequency of the Smallest Character](Easy/Binary-Search/1170.compare-strings-by-frequency-of-the-smallest-character.ipynb)
# 1171. [Remove Zero Sum Consecutive Nodes from Linked List](Medium/Linked-List/1171.remove-zero-sum-consecutive-nodes-from-linked-list.ipynb)
# 1172. Dinner Plate Stacks (Hard)
# 1173. (not algo)
# 1174. (not algo)
# 1175. [Prime Arrangements](Easy/Maths/1175.prime-arrangements.ipynb)
# 1176. Diet Plan Performance (Easy, Locked)
# 1177. [Can Make Palindrome from Substring](Medium/Cumsum/1177.can-make-palindrome-from-substring.ipynb)
# 1178. Number of Valid Words for Each Puzzle (Hard)
# 1179. (not algo)
# 1180. Count Substrings with Only One Distinct Letter (Easy, Locked)
# 1181. Before and After Puzzle (Medium, Locked)
# 1182. Shortest Distance to Target Color (Medium, Locked)
# 1183. Maximum Number of Ones (Hard, Locked)
# 1184. [Distance Between Bus Stops](Easy/Breadth-First-Search/Shortest-Path/1184.distance-between-bus-stops.ipynb)
# 1185. [Day of the Week](Easy/Maths/1185.day-of-the-week.ipynb)

# %% [markdown]
# 1186. [Maximum Subarray Sum with One Deletion](Medium/Dynamic-Programming/1186.maximum-subarray-sum-with-one-deletion.ipynb)
# 1187. Make Array Strictly Increasing (Hard)
# 1188. (not algo)
# 1189. [Maximum Number of Balloons](Easy/Hash-Table/1189.maximum-number-of-balloons.ipynb)
# 1190. [Reverse Substrings Between Each Pair of Parentheses](Medium/Stack/1190.reverse-substrings-between-each-pair-of-parentheses.ipynb)
# 1191. [K-Concatenation Maximum Sum](Medium/Dynamic-Programming/Sequence/1191.k-concatenation-maximum-sum.ipynb)
# 1192. Critical Connections in a Network (Hard)
# 1193. (not algo)
# 1194. (not algo)
# 1195. (not algo)
# 1196. How Many Apples Can You Put into the Basket (Easy, Locked)
# 1197. Minimum Knight Moves (Medium, Locked)
# 1198. Find Smallest Common Element in All Rows (Medium, Locked)
# 1199. Minimum Time to Build Blocks (Hard, Locked)
# 1200. [Minimum Absolute Difference](Easy/Array/1200.minimum-absolute-difference.ipynb)
# 1201. [Ugly Number III](Medium/Maths/1201.ugly-number-III.ipynb)
# 1202. [Smallest String With Swaps](Medium/Depth-First-Search/Union-Find/1202.smallest-string-with-swaps.ipynb)

# %% [markdown]
# 1203. Sort Items by Groups Respecting Dependencies (Hard)
# 1204. (not algo)
# 1205. (not algo)
# 1206. Design Skiplist (Hard)
# 1207. [Unique Number of Occurrences](Easy/Hash-Table/1207.unique-number-of-occurrences.ipynb)
# 1208. [Get Equal Substrings Within Budget](Medium/Two-Pointers/Chasing-Two-Pointers/1208.get-equal-substrings-within-budget.ipynb)
# 1209. [Remove All Adjacent Duplicates in String II](Medium/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/1209.remove-all-adjacent-duplicates-in-string-II.ipynb)
# 1210. Minimum Moves to Reach Target with Rotations (Hard)
# 1211. (not algo)
# 1212. (not algo)
# 1213. Intersection of Three Sorted Arrays (Easy, Locked)
# 1214. Two Sum BSTs (Medium, Locked)
# 1215. Stepping Numbers (Medium, Locked)
# 1216. Valid Palindrome III (Hard, Locked)
# 1217. [Minimum Cost to Move Chips to The Same Position](Easy/Greedy/1217.minimum-cost-to-move-chips-to-the-same-position.ipynb)
# 1218. [Longest Arithmetic Subsequence of Given Difference](Medium/Dynamic-Programming/1218.longest-arithmetic-subsequence-of-given-difference.ipynb)
# 1219. [Path with Maximum Gold](Medium/Depth-First-Search/1219.path-with-maximum-gold.ipynb)
# 1220. Count Vowels Permutation (Hard)
# 1221. [Split a String in Balanced Strings](Easy/Greedy/1221.split-a-string-in-balanced-strings.ipynb)

# %% [markdown]
# 1222. [Queens That Can Attack the King](Medium/Array/1222.queens-that-can-attack-the-king.ipynb)
# 1223. [Dice Roll Simulation](Medium/Dynamic-Programming/Sequence/1223.dice-roll-simulation.ipynb)
# 1224. Maximum Equal Frequency (Hard)
# 1225. (not algo)
# 1226. (not algo)
# 1227. [Airplane Seat Assignment Probability](Medium/Maths/1227.airplane-seat-assignment-probability.ipynb)
# 1228. Missing Number In Arithmetic Progression (Easy, Locked)
# 1229. Meeting Scheduler (Hard, Locked)
# 1230. Toss Strange Coins (Medium, Locked)
# 1231. Divide Chocolate (Hard, Locked)
# 1232. [Check If It Is a Straight Line](Easy/Maths/1232.check-if-it-is-a-straight-line.ipynb)
# 1233. [Remove Sub-Folders from the Filesystem](Medium/Special-Data-Structure/1233.remove-sub-folders-from-the-filesystem.ipynb)
# 1234. [Replace the Substring for Balanced String](Medium/Two-Pointers/Chasing-Two-Pointers/1234.replace-the-substring-for-balanced-string.ipynb)1235
# 1235. Maximum Profit in Job Scheduling (Hard)
# 1236. Web Crawler (Medium, Locked)
# 1237. [Find Positive Integer Solution for a Given Equation](Easy/Binary-Search/1237.find-positive-integer-solution-for-a-given-equation.ipynb)

# %% [markdown]
# 1238. [Circular Permutation in Binary Representation](Medium/Bit-Manipulation/1238.circular-permutation-in-binary-representation.ipynb)
# 1239. [Maximum Length of a Concatenated String with Unique Characters](Medium/Dynamic-Programming/Cached-Search/1239.maximum-length-of-a-concatenated-string-with-unique-characters.ipynb)
# 1240. Tiling a Rectangle with the Fewest Squares (Hard)
# 1241. (not algo)
# 1242. (not algo)
# 1243. Array Transformation (Easy, Locked)
# 1244. Design A Leaderboard (Medium, Locked)
# 1245. Tree Diameter (Medium, Locked)
# 1246. Palindrome Removal (Hard, Locked)
# 1247. [Minimum Swaps to Make Strings Equal](Medium/Greedy/1247.minimum-swaps-to-make-strings-equal.ipynb)
# 1248. [Count Number of Nice Subarrays](Medium/Two-Pointers/1248.count-number-of-nice-subarrays.ipynb)
# 1249. [Minimum Remove to Make Valid Parentheses](Medium/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/1249.minimum-remove-to-make-valid-parentheses.ipynb)
# 1250. Check If It Is a Good Array (Hard)
# 1251. (not algo)
# 1252. [Cells with Odd Values in a Matrix](Easy/Array/1252.cells-with-odd-values-in-a-matrix.ipynb)
# 1253. [Reconstruct a 2-Row Binary Matrix](Medium/Greedy/1253.reconstruct-a-2-row-binary-matrix.ipynb)

# %% [markdown]
# 1254. [Number of Closed Islands](Medium/Depth-First-Search/1254.number-of-closed-islands.ipynb)
# 1255. Maximum Score Words Formed by Letters (Hard)
# 1256. Encode Number (Medium, Locked)
# 1257. Smallest Common Region (Medium, Locked)
# 1258. Synonymous Sentences (Medium, Locked)
# 1259. Handshakes That Don't Cross (Hard, Locked)
# 1260. [Shift 2D Grid](Easy/Array/1260.shift-2D-grid.ipynb)
# 1261. [Find Elements in a Contaminated Binary Tree](Medium/Tree/Recursion/1261.find-elements-in-a-contaminated-binary-tree.ipynb)
# 1262. [Greatest Sum Divisible by Three](Medium/Maths/1262.greatest-sum-divisible-by-three.ipynb)
# 1263. Minimum Moves to Move a Box to Their Target Location (Hard)
# 1264. (not algo)
# 1265. Print Immutable Linked List in Reverse (Medium, Locked)
# 1266. [Minimum Time Visiting All Points](Easy/Maths/1266.minimum-time-visiting-all-points.ipynb)
# 1267. [Count Servers that Communicate](Medium/Array/1267.count-servers-that-communicate.ipynb)
# 1268. [Search Suggestions System](Medium/Special-Data-Structure/1268.search-suggestions-system.ipynb)
# 1269. Number of Ways to Stay in the Same Place After Some Steps (Hard)
# 1270. (not algo)
# 1271. Hexspeak (Easy, Locked)
# 1272. Remove Interval (Medium, Locked)
# 1273. Delete Tree Nodes (Medium, Locked)
# 1274. Number of Ships in a Rectangle (Hard, Locked)

# %% [markdown]
# 1275. [Find Winner on a Tic Tac Toe Game](Easy/Array/1275.find-winner-on-a-tic-tac-toe-game.ipynb)
# 1276. [Number of Burgers with No Waste of Ingredients](Medium/Maths/1276.number-of-burgers-with-no-waste-of-ingredients.ipynb)
# 1277. [Count Square Submatrices with All Ones](Medium/Dynamic-Programming/1277.count-square-submatrices-with-all-ones.ipynb)
# 1278. Palindrome Partitioning III (Hard)
# 1279. (not algo)
# 1280. (not algo)
# 1281. [Subtract the Product and Sum of Digits of an Integer](Easy/Maths/1281.subtract-the-product-and-sum-of-digits-of-an-integer.ipynb)
# 1282. [Group the People Given the Group Size They Belong To](Medium/Greedy/1282.group-the-people-given-the-group-size-they-belong-to.ipynb)
# 1283. [Find the Smallest Divisor Given a Threshold](Medium/Binary-Search/1283.find-the-smallest-divisor-given-a-threshold.ipynb)
# 1284. Minimum Number of Flips to Convert Binary Matrix to Zero Matrix (Hard)
# 1285. (not algo)
# 1286. [Iterator for Combination](Medium/Dynamic-Programming/Cached-Search/1286.iterator-for-combination.ipynb)

# %% [markdown]
# 1287. [Element Appearing More Than 25% In Sorted Array](Easy/Two-Pointer/Chasing-Two-Pointer/1287.element-appearing-more-than-25%-in-sorted-array.ipynb)
# 1288. [Remove Covered Intervals](Medium/Stack/Monotonic-Stack/1288.remove-covered-intervals.ipynb)
# 1289. Minimum Falling Path Sum II (Hard)
# 1290. [Convert Binary Number in a Linked List to Integer](Easy/Bit-Manipulation/1290.convert-binary-number-in-a-linked-list-to-integer.ipynb)
# 1291. [Sequential Digits](Medium/String/1291.sequential-digits.ipynb)
# 1292. [Maximum Side Length of a Square with Sum Less than or Equal to Threshold](Medium/Cumsum/1292.maximum-side-length-of-a-square-with-sum-less-than-or-equal-to-threshold.ipynb)
# 1293. Shortest Path in a Grid with Obstacles Elimination (Hard)
# 1294. (not algo)
# 1295. [Find Numbers with Even Number of Digits](Easy/String/1295.find-numbers-with-even-number-of-digits.ipynb)
# 1296. [Divide Array in Sets of K Consecutive Numbers](Medium/Greedy/1296.divide-array-in-sets-of-K-consecutive-numbers.ipynb)
# 1297. [Maximum Number of Occurrences of a Substring](Medium/Two-Pointers/Chasing-Two-Pointers/1297.maximum-number-of-occurrences-of-a-substring.ipynb)
# 1298. Maximum Candies You Can Get from Boxes (Hard)

# %% [markdown]
# 1299. [Replace Elements with Greatest Element on Right Side](Easy/Array/1299.replace-elements-with-greatest-element-on-right-side.ipynb)
# 1300. [Sum of Mutated Array Closest to Target](Medium/Binary-Search/1300.sum-of-mutated-array-closest-to-target.ipynb)
# 1301. Number of Paths with Max Score (Hard)
# 1302. [Deepest Leaves Sum](Medium/Tree/Level-Traversal/1302.deepest-leaves-sum.ipynb)
# 1303. (not algo)
# 1304. [Find N Unique Integers Sum up to Zero](Easy/Array/1304.find-N-unique-integers-sum-up-to-zero.ipynb)
# 1305. [All Elements in Two Binary Search Trees](Medium/Tree/BST/1305.all-elements-in-two-binary-search-trees.ipynb)
# 1306. [Jump Game III](Medium/Breadth-First-Search/Queue-Implementation/1306.jump-game-III.ipynb)
# 1307. Verbal Arithmetic Puzzle (Hard)
# 1308. (not algo)
# 1309. [Decrypt String from Alphabet to Integer Mapping](Easy/String/1309.decrypt-string-from-alphabet-to-integer-mapping.ipynb)

# %% [markdown]
# 1310. [XOR Queries of a Subarray](Medium/Cumsum/1310.XOR-queries-of-a-subarray.ipynb)
# 1311. [Get Watched Videos by Your Friends](Medium/Breadth-First-Search/Shortest-Path/1311.get-watched-videos-by-your-friends.ipynb)
# 1312. Minimum Insertion Steps to Make a String Palindrome (Hard)
# 1313. [Decompress Run-Length Encoded List](Easy/Array/1313.decompress-run-length-encoded-list.ipynb)
# 1314. [Matrix Block Sum](Medium/Cumsum/1314.matrix-block-sum.ipynb)
# 1315. [Sum of Nodes with Even-Valued Grandparent](Medium/Tree/Recursion/1315.sum-of-nodes-with-even-valued-grandparent.ipynb)
# 1316. Distinct Echo Substrings (Hard)
# 1317. [Convert Integer to the Sum of Two No-Zero Integers](Medium/Maths/1317.convert-integer-to-the-sum-of-two-no-zero-integers.ipynb)
# 1318. [Minimum Flips to Make a OR b Equal to c](Medium/Bit-Manipulation/1318.minimum-flips-to-make-a-OR-b-equal-to-c.ipynb)

# %% [markdown]
# 1319. [Number of Operations to Make Network Connected](Medium/Depth-First-Search/Union-Find/1319.number-of-operations-to-make-network-connected.ipynb)
# 1320. Minimum Distance to Type a Word Using Two Fingers (Hard)
# 1321. (not algo)
# 1322. (not algo)
# 1323. [Maximum 69 Number](Easy/Maths/1323.maximum-69-number.ipynb)
# 1324. [Print Words Vertically](Medium/String/1324.print-words-vertically.ipynb)
# 1325. [Delete Leaves With a Given Value](Medium/Tree/Recursion/1325.delete-leaves-with-a-given-value.ipynb)
# 1326. Minimum Number of Taps to Open to Water a Garden (Hard)
# 1327. (not algo)
# 1328. [Break a Palindrome](Medium/String/1328.break-a-palindrome.ipynb)
# 1329. [ort the Matrix Diagonally](Medium/Array/1329.sort-the-matrix-diagonally.ipynb)
# 1330. Reverse Subarray To Maximize Array Value (Hard)
# 1331. [Rank Transform of an Array](Easy/Array/1331.rank-transform-of-an-array.ipynb)

# %% [markdown]
# 1332. [Remove Palindromic Subsequences](Easy/Maths/1332.remove-palindromic-subsequences.ipynb)
# 1333. [Filter Restaurants by Vegan-Friendly, Price and Distance](Medium/Array/1333.filter-restaurants-by-vegan-friendly-price-and-distance.ipynb)
# 1334. [Find the City With the Smallest Number of Neighbors at a Threshold Distance](Medium/Breadth-First-Search/Shortest-Path/1334.find-the-city-with-the-smallest-number-of-neighbors-at-a-threshold-distance.ipynb)
# 1335. Minimum Difficulty of a Job Schedule (Hard)
# 1336. (not algo)
# 1337. [The K Weakest Rows in a Matrix](Easy/Binary-Search/1337.the-K-weakest-rows-in-a-matrix.ipynb)
# 1338. [Reduce Array Size to The Half](Medium/Binary-Search/1338.reduce-array-size-to-the-half.ipynb)
# 1339. [Maximum Product of Splitted Binary Tree](Medium/Tree/Recursion/1339.maximum-product-of-splitted-binary-tree.ipynb)
# 1340. Jump Game V (Hard)
# 1341. (not algo)
# 1342. [Number of Steps to Reduce a Number to Zero](Easy/Bit-Manipulation/1342.number-of-steps-to-reduce-a-number-to-zero.ipynb)

# %% [markdown]
# 1343. [Number of Sub-arrays of Size K and Average Greater than or Equal to Threshold](Medium/Two-Pointers/Chasing-Two-Pointers/1343.number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold.ipynb)
# 1344. [Angle Between Hands of a Clock](Medium/Maths/1344.angle-between-hands-of-a-clock.ipynb)
# 1345. Jump Game IV (hard)
# 1346. [Check If N and Its Double Exist](Easy/Maths/1346.check-if-N-and-its-double-exist.ipynb)
# 1347. [Minimum Number of Steps to Make Two Strings Anagram](Medium/Greedy/1347.minimum-number-of-steps-to-make-two-strings-anagram.ipynb)
# 1348. Tweet Counts Per Frequency (Medium, not finished-background info too complex)
# 1349. Maximum Students Taking Exam (Hard)
# 1350. (not algo)
# 1351. [Count Negative Numbers in a Sorted Matrix](Easy/Binary-Search/1351.count-negative-numbers-in-a-sorted-matrix.ipynb)
# 1352. [Product of the Last K Numbers](Medium/Cumsum/1352.product-of-the-last-K-numbers.ipynb)
# 1353. [Maximum Number of Events That Can Be Attended](Medium/Greedy/1353.maximum-number-of-events-that-can-be-attended.ipynb)
# 1354. Construct Target Array With Multiple Sums (Hard)
# 1355. (not algo)

# %% [markdown]
# 1356. [Sort Integers by The Number of 1 Bits](Easy/Bit-Manipulation/1356.sort-integers-by-the-number-of-1-bits.ipynb)
# 1357. [Apply Discount Every n Orders](Medium/Design/1357.apply-discount-every-n-orders.ipynb)
# 1358. [Number of Substrings Containing All Three Characters](Medium/Two-Pointers/Chasing-Two-Pointers/1358.number-of-substrings-containing-all-three-characters.ipynb)
# 1359. Count All Valid Pickup and Delivery Options (Hard)
# 1360. [Number of Days Between Two Dates](Easy/String/1360.number-of-days-between-two-dates.ipynb)
# 1361. [Validate Binary Tree Nodes](Medium/Depth-First-Search/1361.validate-binary-tree-nodes.ipynb)
# 1362. [Closest Divisors](Medium/Maths/1362.closest-divisors.ipynb)
# 1363. Largest Multiple of Three (Hard)
# 1364. (not algo)
# 1365. [How Many Numbers Are Smaller Than the Current Number](Easy/Array/1365.how-many-numbers-are-smaller-than-the-current-number.ipynb)

# %% [markdown]
# 1366. [Rank Teams by Votes](Medium/String/1366.rank-teams-by-votes.ipynb)
# 1367. [Linked List in Binary Tree](Medium/Depth-First-Search/1367.linked-list-in-binary-tree.ipynb)
# 1368. Minimum Cost to Make at Least One Valid Path in a Grid (hard)
# 1369. (not algo)
# 1370. [Increasing Decreasing String](Easy/String/1370.increasing-decreasing-string.ipynb)
# 1371. [Find the Longest Substring Containing Vowels in Even Counts](Medium/Cumsum/1371.find-the-longest-substring-containing-vowels-in-even-counts.ipynb)
# 1372. [Longest ZigZag Path in a Binary Tree](Medium/Tree/Recursion/1372.longest-zigZag-path-in-a-binary-tree.ipynb)
# 1373. Maximum Sum BST in Binary Tree (Hard)
# 1374. [Generate a String With Characters That Have Odd Counts](Easy/String/1374.generate-a-string-with-characters-that-have-odd-counts.ipynb)
# 1375. [Bulb Switcher III](Medium/Array/1375.bulb-switcher-III.ipynb)

# %% [markdown]
# 1376. [Time Needed to Inform All Employees](Medium/Breadth-First-Search/Shortest-Path/1376.time-needed-to-inform-all-employees.ipynb)
# 1377. Frog Position After T Seconds (Hard)
# 1378. (not algo)
# 1379. [Find a Corresponding Node of a Binary Tree in a Clone of That Tree](Medium/Tree/Recursion/1379.find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree.ipynb)
# 1380. [Lucky Numbers in a Matrix](Easy/Array/1380.lucky-numbers-in-a-matrix.ipynb)
# 1381. [Design a Stack With Increment Operation](Medium/Design/1381.design-a-stack-with-increment-operation.ipynb)
# 1382. [Balance a Binary Search Tree](Medium/Tree/BST/1382.balance-a-binary-search-tree.ipynb)
# 1383. Maximum Performance of a Team (Hard)
# 1384. (not algo)
# 1385. [Find the Distance Value Between Two Arrays](Easy/Array/1385.find-the-distance-value-between-two-arrays.ipynb)
# 1386. [Cinema Seat Allocation](Medium/Greedy/1386.cinema-seat-allocation.ipynb)

# %% [markdown]
# 1387. [Sort Integers by The Power Value](Medium/Sort/1387.sort-integers-by-the-power-value.ipynb)
# 1388. Pizza With 3n Slices (Hard)
# 1389. [Create Target Array in the Given Order](Easy/Array/1389.create-target-array-in-the-given-order.ipynb)
# 1390. [Four Divisors](Medium/Maths/1390.four-divisors.ipynb)
# 1391. [Check if There is a Valid Path in a Grid](Medium/Depth-First-Search/1391.check-if-there-is-a-valid-path-in-a-grid.ipynb)
# 1392. Longest Happy Prefix (Hard)
# 1393. (not algo)
# 1394. [Find Lucky Integer in an Array](Easy/Array/1394.find-lucky-integer-in-an-array.ipynb)
# 1395. [Count Number of Teams](Medium/Array/1395.count-number-of-teams.ipynb)
# 1396. [Design Underground System](Medium/Design/1396.design-underground-system.ipynb)
# 1397. Find All Good Strings (Hard)
# 1398. (not algo)
# 1399. [Count Largest Group](Easy/Array/1399.count-largest-group.ipynb)
# 1400. [Construct K Palindrome Strings](Medium/Greedy/1400.construct-K-palindrome-strings.ipynb)
# 1401. [Circle and Rectangle Overlapping](Medium/Maths/1401.circle-and-rectangle-overlapping.ipynb)
# 1402. Reducing Dishes (Hard)

# %% [markdown]
# 1403. [Minimum Subsequence in Non-Increasing Order](Easy/Greedy/1403.minimum-subsequence-in-non-increasing-order.ipynb)
# 1404. [Number of Steps to Reduce a Number in Binary Representation to One](Medium/Bit-Manipulation/1404.number-of-steps-to reduce-a-number-in-binary-representation-to-one.ipynb)
# 1405. [Longest Happy String](Medium/Greedy/1405.longest-happy-string.ipynb)
# 1406. Stone Game III (Hard)
# 1407. (not algo)
# 1408. [String Matching in an Array](Easy/String/1408.string-matching-in-an-array.ipynb)
# 1409. [Queries on a Permutation With Key](Medium/Array/1409.queries-on-a-permutation-with-key.ipynb)
# 1410. HTML Entity Parser (Medium, not finished-background info too complex)
# 1411. Number of Ways to Paint N × 3 Grid (Hard)
# 1412. (not algo)
# 1413. [Minimum Value to Get Positive Step by Step Sum](Easy/Cumsum/1413.minimum-value-to-get-positive-step-by-step-sum.ipynb)
# 1414. [Find the Minimum Number of Fibonacci Numbers Whose Sum Is K](Medium/Maths/1414.find-the-minimum-number-of-fibonacci-numbers-whose-sum-is-K.ipynb)
# 1415. [The k-th Lexicographical String of All Happy Strings of Length n](Medium/Dynamic-Programming/Cached-Search/1415.the-k-th lexicographical-string-of-all-happy-strings-of-length-n.ipynb)
# 1416. Restore The Array (Hard)
# 1417. [Reformat The String](Easy/String/1417.reformat-the-string.ipynb)

# %% [markdown]
# 1418. [Display Table of Food Orders in a Restaurant](Medium/Hash-Table/1418.display-table-of-food-orders-in-a-restaurant.ipynb)
# 1419. [Minimum Number of Frogs Croaking](Medium/String/1419.minimum-number-of-frogs-croaking.ipynb)
# 1420. Build Array Where You Can Find The Maximum Exactly K Comparisons (Hard)
# 1421. (not algo)
# 1422. [Maximum Score After Splitting a String](Easy/String/1422.maximum-score-after-splitting-a-string.ipynb)
# 1423. [Maximum Points You Can Obtain from Cards](Medium/Two-Pointers/Chasing-Two-Pointers/1423.maximum-points-you-can-obtain-from-cards.ipynb)
# 1424. [Diagonal Traverse II](Medium/Array/1424.diagonal-traverse-II.ipynb)
# 1425. Constrained Subsequence Sum (Hard)
# 1426. Counting Elements (Easy, Locked)
# 1427. Perform String Shifts (Easy, Locked)
# 1428. Leftmost Column with at Least a One (Medium, Locked)
# 1429. First Unique Number (Medium, Locked)
# 1430. Check If a String Is a Valid Sequence from Root to Leaves Path in a Binary Tree (Medium, Locked)
# 1431. [Kids With the Greatest Number of Candies](Easy/Array/1431.kids-with-the-greatest-number-of-candies.ipynb)
# 1432. [Max Difference You Can Get From Changing an Integer](Medium/Maths/1432.max-difference-you-can-get-from-changing-an-integer.ipynb)
# 1433. [Check If a String Can Break Another String](Medium/Greedy/1433.check-if-a-string-can-break-another-string.ipynb)
# 1434. Number of Ways to Wear Different Hats to Each Other (Hard)
# 1435. (not algo)
# 1436. [Destination City](Easy/Graph/1436.destination-city.ipynb)
# 1437. [Check If All 1's Are at Least Length K Places Away](Easy/Array/1437.check-if-all-1's-are-at-least-length-K-places-away.ipynb)

# %% [markdown]
# 1438. [Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit](Medium/Two-Pointers/Chasing-Two-Pointers/1438.longest-continuous-subarray-with-absolute-diff-less-than-or-equal-to-limit.ipynb)
# 1439. Find the Kth Smallest Sum of a Matrix With Sorted Rows (Hard)
# 1440. (not algo)
# 1441. [Build an Array With Stack Operations](Easy/Array/1441.build-an-array-with-stack-operations.ipynb)
# 1442. [Count Triplets That Can Form Two Arrays of Equal XOR](Medium/Cumsum/1442.count-triplets-that-can-form-two-arrays-of-equal-XOR.ipynb)
# 1443. [Minimum Time to Collect All Apples in a Tree](Medium/Depth-First-Search/1443.minimum-time-to-collect-all-apples-in-a-tree.ipynb)
# 1444. Number of Ways of Cutting a Pizza (Hard)
# 1445. (not algo)
# 1446. [Consecutive Characters](Easy/Two-Pointers/Chasing-Two-Pointers/1446.consecutive-characters.ipynb)
# 1447. [Simplified Fractions](Medium/Maths/1447.simplified-fractions.ipynb)
# 1448. [Count Good Nodes in Binary Tree](Medium/Tree/Recursion/1448.count-good-nodes-in-binary-tree.ipynb)
# 1449. Form Largest Integer With Digits That Add up to Target (Hard)
# 1450. [Number of Students Doing Homework at a Given Time](Easy/Array/1450.number-of-students-doing-homework-at-a-given-time.ipynb)
# 1451. [Rearrange Words in a Sentence](Medium/String/1451.rearrange-words-in-a-sentence.ipynb)
# 1452. [People Whose List of Favorite Companies Is Not a Subset of Another List](Medium/Array/1452.people-whose-list-of-favorite-companies-is-not-a-subset-of-another-list.ipynb)
# 1453. Maximum Number of Darts Inside of a Circular Dartboard (Hard)
# 1454. (not algo)

# %% [markdown]
# 1455. [Check If a Word Occurs As a Prefix of Any Word in a Sentence](Easy/String/1455.check-if-a-word-occurs-as-a-prefix-of-any-word-in-a-sentence.ipynb)
# 1456. [Maximum Number of Vowels in a Substring of Given Length](Medium/Two-Pointers/Chasing-Two-Pointers/1456.maximum-number-of vowels-in-a-substring-of-given-length.ipynb)
# 1457. [Pseudo-Palindromic Paths in a Binary Tree](Medium/Tree/Recursion/1457.pseudo-palindromic-paths-in-a-binary-tree.ipynb)
# 1458. Max Dot Product of Two Subsequences (Hard)
# 1459. (not algo)
# 1460. [Make Two Arrays Equal by Reversing Sub-arrays](Easy/Sort/1460.make-two-arrays-equal-by-reversing-sub-arrays.ipynb)
# 1461. [Check If a String Contains All Binary Codes of Size K](Medium/Bit-Manipulation/1461.check-if-a-string-contains-all-binary-codes-of-size-K.ipynb)
# 1462. [Course Schedule IV](Medium/Depth-First-Search/1462.course-schedule-IV.ipynb)
# 1463. Cherry Pickup II (Hard)
# 1464. [Maximum Product of Two Elements in an Array](Easy/Array/1464.maximum-product-of-two-elements-in-an-array.ipynb)
# 1465. [Maximum Area of a Piece of Cake After Horizontal and Vertical Cuts](Medium/Maths/1465.maximum-area-of-a-piece-of-cake-after-horizontal-and-vertical-cuts.ipynb)
# 1466. [Reorder Routes to Make All Paths Lead to the City Zero](Medium/Breadth-First-Search/Queue-Implementation/1466.reorder-routes-to-make-all-paths-lead-to-the-city-zero.ipynb)
# 1467. Probability of a Two Boxes Having The Same Number of Distinct Balls (Hard)
# 1468. (not algo)
# 1469. Find All The Lonely Nodes (Easy, Locked)
# 1470. [Shuffle the Array](Easy/Array/1470.shuffle-the-array.ipynb)

# %% [markdown]
# 1471. [The k Strongest Values in an Array](Medium/Sort/1471.the-k-strongest-values-in-an-array.ipynb)
# 1472. [Design Browser History](Medium/Design/1472.design-browser-history.ipynb)
# 1473. Paint House III (Hard)
# 1474. Delete N Nodes After M Nodes of a Linked List (Easy, Locked)
# 1475. [Final Prices With a Special Discount in a Shop](Easy/Array/1475.final-prices-with-a-special-discount-in-a-shop.ipynb)
# 1476. [Subrectangle Queries](Medium/Array/1476.subrectangle-queries.ipynb)
# 1477. [Find Two Non-overlapping Sub-arrays Each With Target Sum](Medium/Dynamic-Programming/Sequence/1477.find-two-non-overlapping-sub-arrays-each-with-target-sum.ipynb)
# 1478. Allocate Mailboxes (Hard)
# 1479. (not algo)
# 1480. [Running Sum of 1d Array](Easy/Cumsum/1480.running-sum-of-1d-array.ipynb)
# 1481. [Least Number of Unique Integers after K Removals](Medium/Greedy/1481.least-number-of-unique-integers-after-K-removals.ipynb)
# 1482. [Minimum Number of Days to Make m Bouquets](Medium/Binary-Search/1482.minimum-number-of-days-to-make-m-bouquets.ipynb)
# 1483. Kth Ancestor of a Tree Node (Hard)
# 1484. (not algo)
# 1485. Clone Binary Tree With Random Pointer (Medium, Locked)
# 1486. [XOR Operation in an Array](Easy/Bit-Manipulation/1486.XOR-operation-in-an-array.ipynb)
# 1487. [Making File Names Unique](Medium/Hash-Table/1487.making-file-names-unique.ipynb)

# %% [markdown]
# 1488. [Avoid Flood in The City](Medium/Hash-Table/1488.avoid-flood-in-the-city.ipynb)
# 1489. Find Critical and Pseudo-Critical Edges in Minimum Spanning Tree (Hard)
# 1490. Clone N-ary Tree (Medium, Locked)
# 1491. [Average Salary Excluding the Minimum and Maximum Salary](Easy/Array/1491.average-salary-excluding-the-minimum-and-maximum-salary.ipynb)
# 1492. [The kth Factor of n](Medium/Maths/1492.the-kth-factor-of-n.ipynb)
# 1493. [Longest Subarray of 1's After Deleting One Element](Medium/Two-Pointers/Chasing-Two-Pointers/1493.longest-subarray-of-1's-after-deleting-one-element.ipynb)
# 1494. Parallel Courses II (Hard)
# 1495. (not algo)
# 1496. [Path Crossing](Easy/Hash-Table/1496.path-crossing.ipynb)
# 1497. [Check If Array Pairs Are Divisible by k](Medium/Hash-Table/1497.check-if-array-pairs-are-divisible-by-k.ipynb)
# 1498. [Number of Subsequences That Satisfy the Given Sum Condition](Medium/Binary-Search/1498.number-of-subsequences-that-satisfy-the-given-sum-condition.ipynb)
# 1499. Max Value of Equation (Hard)
# 1500. Design a File Sharing System (Medium, Locked)
# 1501. (not algo)
# 1502. [Can Make Arithmetic Progression From Sequence](Easy/Array/1502.can-make-arithmetic-progression-from-sequence.ipynb)
# 1503. [Last Moment Before All Ants Fall Out of a Plank](Medium/Maths/1503.last-moment-before-all-ants-fall-out-of-a-plank.ipynb)
# 1504. [Count Submatrices With All Ones](Medium/Dynamic-Programming/Coordinate/1504.count-submatrices-with-all-ones.ipynb)
# 1505. Minimum Possible Integer After at Most K Adjacent Swaps On Digits (Hard)
# 1506. Find Root of N-Ary Tree (Medium, Locked)

# %% [markdown]
# 1507. [Reformat Date](Easy/String/1507.reformat-date.ipynb)
# 1508. [Range Sum of Sorted Subarray Sums](Medium/Sort/1508.range-sum-of-sorted-subarray-sums.ipynb)
# 1509. [Minimum Difference Between Largest and Smallest Value in Three Moves](Medium/Sort/1509.minimum-difference-between-largest-and-smallest-value-in-three-moves.ipynb)
# 1510. Stone Game IV (Hard)
# 1511. (not algo)
# 1512. [Number of Good Pairs](Easy/Hash-Table/1512.number-of-good-pairs.ipynb)
# 1513. [Number of Substrings With Only 1s](Medium/Maths/1513.number-of-substrings-with-only-1s.ipynb)
# 1514. [Path with Maximum Probability](Medium/Breadth-First-Search/Shortest-Path/1514.path-with-maximum-probability.ipynb)
# 1515. Best Position for a Service Centre (Hard)
# 1516. Move Sub-Tree of N-Ary Tree (Hard, Locked)
# 1517. (not algo)
# 1518. [Water Bottles](Easy/Maths/1518.water-bottles.ipynb)
# 1519. [Number of Nodes in the Sub-Tree With the Same Label](Medium/Tree/Recursion/1519.number-of-nodes-in-the-sub-tree-with-the-same-label.ipynb)
# 1520. Maximum Number of Non-Overlapping Substrings (Hard)
# 1521. Find a Value of a Mysterious Function Closest to Target (Hard)
# 1522. Diameter of N-Ary Tree (Medium, Locked)
# 1523. [Count Odd Numbers in an Interval Range](Easy/Maths/1523.count-odd-numbers-in-an-interval-range.ipynb)
# 1524. [Number of Sub-arrays With Odd Sum](Medium/Dynamic-Programming/Sequence/1524.number-of-sub-arrays-with-odd-sum.ipynb)

# %% [markdown]
# 1525. [Number of Good Ways to Split a String](Medium/Hash-Table/1525.number-of-good-ways-to-split-a-string.ipynb)
# 1526. Minimum Number of Increments on Subarrays to Form a Target Array (Hard)
# 1527. (not algo)
# 1528. [Shuffle String](Easy/Sort/1528.shuffle-string.ipynb)
# 1529. [Bulb Switcher IV](Medium/Array/1529.bulb-switcher-IV.ipynb)
# 1530. [Number of Good Leaf Nodes Pairs](Medium/Tree/Recursion/1530.number-of-good-leaf-nodes-pairs.ipynb)
# 1531. String Compression II (Hard)
# 1532. (not algo)
# 1533. Find the Index of the Large Integer (Medium, Locked)
# 1534. [Count Good Triplets](Easy/Array/1534.count-good-triplets.ipynb)
# 1535. [Find the Winner of an Array Game](Medium/Array/1535.find-the-winner-of-an-array-game.ipynb)
# 1536. [Minimum Swaps to Arrange a Binary Grid](Medium/Greedy/1536.minimum-swaps-to-arrange-a-binary-grid.ipynb)
# 1537. Get the Maximum Score (Hard)
# 1538. Guess the Majority in a Hidden Array (Medium, locked)
# 1539. [Kth Missing Positive Number](Easy/Array/1539.kth-missing-positive-number.ipynb)
# 1540. [Can Convert String in K Moves](Medium/Greedy/1540.can-convert-string-in-K-moves.ipynb)
# 1541. [Minimum Insertions to Balance a Parentheses String](Medium/Stack/Check-if-Pattern-Occur-According-to-Order-in-Sequence/1541.minimum-insertions-to-balance-a-parentheses-string.ipynb)
# 1542. Find Longest Awesome Substring (Hard)
# 1543. (not algo)

# %% [markdown]
# 1544. [Make The String Great](Easy/Stack/1544.make-the-string-great.ipynb)
# 1545. [Find Kth Bit in Nth Binary String](Medium/String/1545.find-Kth-bit-in-Nth-binary-string.ipynb)
# 1546. [Maximum Number of Non-Overlapping Subarrays With Sum Equals Target](Medium/Dynamic-Programming/Sequence/1546.maximum-number-of-non-overlapping-subarrays-with-sum-equals-target.ipynb)
# 1547. Minimum Cost to Cut a Stick (Hard)
# 1548. The Most Similar Path in a Graph (Hard, Locked)
# 1549. (not algo)
# 1550. [Three Consecutive Odds](Easy/Array/1550.three-consecutive-odds.ipynb)
# 1551. [Minimum Operations to Make Array Equal](Medium/Maths/1551.minimum-operations-to-make-array-equal.ipynb)
# 1552. [Magnetic Force Between Two Balls](Medium/Binary-Search/1552.magnetic-force-between-two-balls.ipynb)
# 1553. Minimum Number of Days to Eat N Oranges (Hard)
# 1554. Strings Differ by One Character (Medium, Locked)
# 1555. (not algo)
# 1556. [Thousand Separator](Easy/String/1556.thousand-separator.ipynb)
# 1557. [Minimum Number of Vertices to Reach All Nodes](Medium/Depth-First-Search/Union-Find/1557.minimum-number-of-vertices-to-reach-all-nodes.ipynb)
# 1558. [Minimum Numbers of Function Calls to Make Target Array](Medium/Bit-Manipulation/1558.minimum-numbers-of-function-calls-to-make-target-array.ipynb)
# 1559. Detect Cycles in 2D Grid (Hard)
# 1560. [Most Visited Sector in a Circular Track](Easy/Hash-Table/1560.most-visited-sector-in-a-circular-track.ipynb)

# %% [markdown]
# 1561. [Maximum Number of Coins You Can Get](Medium/Sort/1561.maximum-number-of-coins-you-can-get.ipynb)
# 1562. [Find Latest Group of Size M](Medium/Array/1562.find-latest-group-of-size-M.ipynb)
# 1563. Stone Game V (Hard)
# 1564. Put Boxes Into the Warehouse I (Medium, Locked)
# 1565. (not algo)
# 1566. [Detect Pattern of Length M Repeated K or More Times](Easy/Array/1566.detect-pattern-of-length-m-repeated-k-or-more-times.ipynb)
# 1567. [Maximum Length of Subarray With Positive Product](Medium/Greedy/1567.maximum-length-of-subarray-with-positive-product.ipynb)
# 1568. Minimum Number of Days to Disconnect Island (Hard)
# 1569. Number of Ways to Reorder Array to Get Same BST (Hard)
# 1570. Dot Product of Two Sparse Vectors (Medium, Locked)
# 1571. (not algo)
# 1572. [Matrix Diagonal Sum](Easy/Array/1572.matrix-diagonal-sum.ipynb)
# 1573. [Number of Ways to Split a String](Medium/Array/1573.number-of-ways-to-split-a-string.ipynb)
# 1574. [Shortest Subarray to be Removed to Make Array Sorted](Medium/Binary-Search/1574.shortest-subarray-to-be-removed-to-make-array-sorted.ipynb)
# 1575. Count All Possible Routes (Hard)
# 1576. [Replace All ?'s to Avoid Consecutive Repeating Characters](Easy/Array/1576.replace-all-?'s-to-avoid-consecutive-repeating-characters.ipynb)
# 1577. [Number of Ways Where Square of Number Is Equal to Product of Two Numbers](Medium/Maths/1577.number-of-ways-where-square of-number-is-equal-to-product-of-two-numbers.ipynb)
# 1578. [Minimum Deletion Cost to Avoid Repeating Letters](Medium/Greedy/1578.minimum-deletion-cost-to-avoid-repeating-letters.ipynb)
# 1579. Remove Max Number of Edges to Keep Graph Fully Traversable (Hard)
# 1580. Put Boxes Into the Warehouse II (Medium, Locked)
# 1581. (not algo)

# %% [markdown]
# 1582. [Special Positions in a Binary Matrix](Easy/Array/1582.special-positions-in-a-binary-matrix.ipynb)
# 1583. [Count Unhappy Friends](Medium/Array/1583.count-unhappy-friends.ipynb)
# 1584. [Min Cost to Connect All Points](Medium/Array/1584.min-cost-to-connect-all-points.ipynb)
# 1585. Check If String Is Transformable With Substring Sort Operations (Hard)
# 1586. Binary Search Tree Iterator II (Medium, Locked)
# 1587. (not algo)
# 1588. [Sum of All Odd Length Subarrays](Easy/Cumsum/1588.sum-of-all-odd-length-subarrays.ipynb)
# 1589. [Maximum Sum Obtained of Any Permutation](Medium/Cumsum/1589.maximum-sum-obtained-of-any-permutation.ipynb)
# 1590. [Make Sum Divisible by P](Medium/Cumsum/1590.make-sum-divisible-by-P.ipynb)
# 1591. Strange Printer II (Hard)
# 1592. [Rearrange Spaces Between Words](Easy/String/1592.rearrange-spaces-between-words.ipynb)
# 1593. [Split a String Into the Max Number of Unique Substrings](Medium/Dynamic-Programming/Cached-Search/1593.split-a-string-into-the-max-number-of-unique-substrings.ipynb)
# 1594. [Maximum Non Negative Product in a Matrix](Medium/Dynamic-Programming/Coordinate/1594.maximum-non-negative-product-in-a-matrix.ipynb)
# 1595. Minimum Cost to Connect Two Groups of Points (Hard)
# 1596. (not algo)
# 1597. Build Binary Expression Tree From Infix Expression (Hard, Locked)
# 1598. [Crawler Log Folder](Easy/Stack/1598.crawler-log-folder.ipynb)

# %% [markdown]
# 1599. [Maximum Profit of Operating a Centennial Wheel](Medium/Greedy/1599.maximum-profit-of-operating-a-centennial-wheel.ipynb)
# 1600. [Throne Inheritance](Medium/Depth-First-Search/1600.throne-inheritance.ipynb)
# 1601. Maximum Number of Achievable Transfer Requests (Hard)
# 1602. Find Nearest Right Node in Binary Tree (Medium, Locked)
# 1603. [Design Parking System](Easy/Design/1603.design-parking-system.ipynb)
# 1604. [Alert Using Same Key-Card Three or More Times in a One Hour Period](Medium/Two-Pointers/Chasing-Two-Pointers/1604.alert-using-same-key-card-three-or-more-times-in-a-one-hour-period.ipynb)
# 1605. [Find Valid Matrix Given Row and Column Sums](Medium/Greedy/1605.find-valid-matrix-given-row-and-column-sums.ipynb)
# 1606. Find Servers That Handled Most Number of Requests (Hard)
# 1607. (not algo)
# 1608. [Special Array With X Elements Greater Than or Equal X](Easy/Binary-Search/1608.special-array-with-X-elements-greater-than-or-equal-X.ipynb)
# 1609. [Even Odd Tree](Medium/Trees/Level-Traversal/1609.even-odd-tree.ipynb)
# 1610. Maximum Number of Visible Points (Hard)
# 1611. Minimum One Bit Operations to Make Integers Zero (Hard)
# 1612. Check If Two Expression Trees are Equivalent (Medium, Locked)
# 1613. (not algo)
# 1614. [Maximum Nesting Depth of the Parentheses](Easy/Tree/Recursion/1614.maximum-nesting-depth-of-the-parentheses.ipynb)
# 1615. [Maximal Network Rank](Medium/Graph/1615.maximal-network-rank.ipynb)
# 1616. [Split Two Strings to Make Palindrome](Medium/String/1616.split-two-strings-to-make-palindrome.ipynb)
# 1617. Count Subtrees With Max Distance Between Cities (Hard)
# 1618. Maximum Font to Fit a Sentence in a Screen (Medium, Locked)

# %% [markdown]
# 1619. [Mean of Array After Removing Some Elements](Easy/Array/1619.mean-of-array-after-removing-some-elements.ipynb)
# 1620. [Coordinate With Maximum Network Quality](Medium/Greedy/1620.coordinate-with-maximum-network-quality.ipynb)
# 1621. [Number of Sets of K Non-Overlapping Line Segments](Medium/Dynamic-Programming/Double-Sequence/1621.number-of-sets-of-K-non-overlapping-line-segments.ipynb)
# 1622. Fancy Sequence (Hard)
# 1623. (not algo)
# 1624. [Largest Substring Between Two Equal Characters](Easy/String/1624.largest-substring-between-two-equal-characters.ipynb)
# 1625. [Lexicographically Smallest String After Applying Operations](Medium/Breadth-First-Search/1625.lexicographically-smallest-string-after-applying-operations.ipynb)
# 1626. [Best Team With No Conflicts](Medium/Dynamic-Programing/1626.best-team-with-no-conflicts.ipynb)
# 1627. Graph Connectivity With Threshold (Hard)
# 1628. Design an Expression Tree With Evaluate Function (Medium, Locked)
# 1629. [Slowest Key](Easy/Array/1629.slowest-key.ipynb)
# 1630. [Arithmetic Subarrays](Medium/Sort/1630.arithmetic-subarrays.ipynb)
# 1631. [Path With Minimum Effort](Medium/Breadth-First-Search/Shortest-Path/1631.path-with-minimum-effort.ipynb)
# 1632. Rank Transform of a Matrix (Hard)
# 1633. (not algo)
# 1634. Add Two Polynomials Represented as Linked Lists (Medium, Locked)
# 1635. (not algo)
# 1636. [Sort Array by Increasing Frequency](Easy/Sort/1636.sort-array-by-increasing-frequency.ipynb)

# %% [markdown]
# 1637. [Widest Vertical Area Between Two Points Containing No Points](Medium/Sort/1637.widest-vertical-area-between-two-points-containing-no-points.ipynb)
# 1638. [Count Substrings That Differ by One Character](Medium/String/1638.count-substrings-that-differ-by-one-character.ipynb)
# 1639. Number of Ways to Form a Target String Given a Dictionary (Hard)
# 1640. [Check Array Formation Through Concatenation](Easy/Array/1640.check-array-formation-through-concatenation.ipynb)
# 1641. [Count Sorted Vowel Strings](Medium/Dynamic-Programming/Cached-Search/1641.count-sorted-vowel-strings.ipynb)
# 1642. [Furthest Building You Can Reach](Medium/Binary-Search/1642.furthest-building-you-can-reach.ipynb)
# 1643. Kth Smallest Instructions (Hard)
# 1644. Lowest Common Ancestor of a Binary Tree II (Medium, Locked)
# 1645. (not algo)
# 1646. [Get Maximum in Generated Array](Easy/Array/1646.get-maximum-in-generated-array.ipynb)
# 1647. [Minimum Deletions to Make Character Frequencies Unique](Medium/Greedy/1647.minimum-deletions-to-make-character-frequencies-unique.ipynb)
# 1648. [Sell Diminishing-Valued Colored Balls](Medium/Heap/1648.sell-diminishing-valued-colored-balls.ipynb)
# 1649. Create Sorted Array through Instructions (Hard)
# 1650. Lowest Common Ancestor of a Binary Tree III (Medium, Locked)
# 1651. (not algo)
# 1652. [Defuse the Bomb](Easy/Array/1652.defuse-the-bomb.ipynb)
# 1653. [Minimum Deletions to Make String Balanced](Medium/Array/1653.minimum-deletions-to-make-string-balanced.ipynb)

# %% [markdown]
# 1654. [Minimum Jumps to Reach Home](Medium/Breadth-First-Search/Shortest-Path/1654.minimum-jumps-to-reach-home.ipynb)
# 1655. Distribute Repeating Integers (Hard)
# 1656. [Design an Ordered Stream](Easy/Design/1656.design-an-ordered-stream.ipynb)
# 1657. [Determine if Two Strings Are Close](Medium/Hash-Table/1657.determine-if-two-strings-are-close.ipynb)
# 1658. [Minimum Operations to Reduce X to Zero](Medium/Two-Pointers/1658.minimum-operations-to-reduce-X-to-zero.ipynb)
# 1659. Maximize Grid Happiness (Hard)
# 1660. Correct a Binary Tree (Medium, Locked)
# 1661. (not algo)
# 1662. [Check If Two String Arrays are Equivalent](Easy/String/1662.check-if-two-string-arrays-are-equivalent.ipynb)
# 1663. [Smallest String With A Given Numeric Value](Medium/Greedy/1663.smallest-string-with-a-given-numeric-value.ipynb)
# 1664. [Ways to Make a Fair Array](Medium/Cumsum/1664.ways-to-make-a-fair-array.ipynb)
# 1665. Minimum Initial Energy to Finish Tasks (Hard)
# 1666. Change the Root of a Binary Tree (Medium, Locked)
# 1667. (not algo)
# 1668. [Maximum Repeating Substring](Easy/Binary-Search/1668.maximum-repeating-substring.ipynb)
# 1669. [Merge In Between Linked Lists](Medium/Linked-List/1669.merge-in-between-linked-lists.ipynb)
# 1670. [Design Front Middle Back Queue](Medium/Design/1670.design-front-middle-back-queue.ipynb)
# 1671. Minimum Number of Removals to Make Mountain Array (Hard)

# %% [markdown]
# 1672. [Richest Customer Wealth](Easy/Array/1672.richest-customer-wealth.ipynb)
# 1673. [Find the Most Competitive Subsequence](Medium/Stack/Monotonic-Stack/1673.find-the-most-competitive-subsequence.ipynb)
# 1674. [Minimum Moves to Make Array Complementary](Medium/Cumsum/1674.minimum-moves-to-make-array-complementary.ipynb)
# 1675. Minimize Deviation in Array (Hard)
# 1676. Lowest Common Ancestor of a Binary Tree IV (Medium, Locked)
# 1677. (not algo)
# 1678. [Goal Parser Interpretation](Easy/String/1678.goal-parser-interpretation.ipynb)
# 1679. [Max Number of K-Sum Pairs](Medium/Hash-Table/1679.max-number-of-k-sum-pairs.ipynb)
# 1680. [Concatenation of Consecutive Binary Numbers](Medium/Bit-Manipulation/1680.concatenation-of-consecutive-binary-numbers.ipynb)
# 1681. Minimum Incompatibility (Hard)
# 1682. Longest Palindromic Subsequence II (Medium, Locked)
# 1683. (Not algo)
# 1684. [Count the Number of Consistent Strings](Easy/String/1684.count-the-number-of-consistent-strings.ipynb)
# 1685. [Sum of Absolute Differences in a Sorted Array](Medium/Cumsum/1685.sum-of-absolute-differences-in-a-sorted-array.ipynb)
# 1686. [Stone Game VI](Medium/Greedy/1686.stone-game-VI.ipynb)
# 1687. Delivering Boxes from Storage to Ports (Hard)
# 1688. [Count of Matches in Tournament](Easy/Maths/1688.count-of-matches-in-tournament.ipynb)

# %% [markdown]
# 1689. [Partitioning Into Minimum Number Of Deci-Binary Numbers](Medium/Greedy/1689.partitioning-into-minimum-number-of-deci-binary-numbers.ipynb)
# 1690. [Stone Game VII](Medium/Dynamic-Programming/Double-Sequence/1690.stone-game-VII.ipynb)
# 1691. Maximum Height by Stacking Cuboids (Hard)
# 1692. Count Ways to Distribute Candies (Hard, Locked)
# 1693. (not algo)
# 1694. [Reformat Phone Number](Easy/String/1694.reformat-phone-number.ipynb)
# 1695. [Maximum Erasure Value](Medium/Two-Pointers/Chasing-Two-Pointers/1695.maximum-erasure-value.ipynb)
# 1696. [Jump Game VI](Medium/Dynamic-Programming/Sequence/1696.jump-game-VI.ipynb)
# 1697. Checking Existence of Edge Length Limited Paths (Hard)
# 1698. Number of Distinct Substrings in a String (Medium, Locked)
# 1699. (Not algo)
# 1700. [Number of Students Unable to Eat Lunch](Easy/Array/1700.number-of-students-unable-to-eat-lunch.ipynb)
# 1701. [Average Waiting Time](Medium/Array/1701.average-waiting-time.ipynb)
# 1702. [Maximum Binary String After Change](Medium/Greedy/1702.maximum-binary-string-after-change.ipynb)
# 1703. Minimum Adjacent Swaps for K Consecutive Ones (Hard)
# 1704. [Determine if String Halves Are Alike](Easy/String/1704.determine-if-string-halves-are-alike.ipynb)
# 1705. [Maximum Number of Eaten Apples](Medium/Heap/1705.maximum-number-of-eaten-apples.ipynb)

# %% [markdown]
# 1706. [Where Will the Ball Fall](Medium/Array/1706.where-will-the-ball-fall.ipynb)
# 1707. Maximum XOR With an Element From Array (Hard)
# 1708. Largest Subarray Length K (Easy, Locked)
# 1709. (Not algo)
# 1710. [Maximum Units on a Truck](Easy/Binary-Search/1710.maximum-units-on-a-truck.ipynb)
# 1711. [Count Good Meals](Medium/Array/1711.count-good-meals.ipynb)
# 1712. [Ways to Split Array Into Three Subarrays](Medium/Binary-Search/1712.ways-to-split-array-into-three-subarrays.ipynb)
# 1713. Minimum Operations to Make a Subsequence (Hard)
# 1714. sum-of-special-evenly-spaced-elements-in-array (Hard, Locked)
# 1715. (Not algo)
# 1716. [Calculate Money in Leetcode Bank](Easy/Maths/1716.calculate-money-in-leetcode-bank.ipynb)
# 1717. [Maximum Score From Removing Substrings](Medium/Greedy/1717.maximum-score-from-removing-substrings.ipynb)
# 1718. [Construct the Lexicographically Largest Valid Sequence](Medium/Depth-First-Search/1718.construct-the-lexicographically-largest-valid-sequence.ipynb)
# 1719. Number Of Ways To Reconstruct A Tree (Hard)
# 1720. [Decode XORed Array](Easy/Bit-Manipulation/1720.decode-XORed-array.ipynb)
# 1721. [Swapping Nodes in a Linked List](Medium/Linked-List/1721.wrapping-nodes-in-a-linked-list.ipynb)
# 1722. [Minimize Hamming Distance After Swap Operations](Medium/Depth-First-Search/Union-Find/1722.minimize-hamming-distance-after-swap-operations.ipynb)
# 1723. find-minimum-time-to-finish-all-jobs (Hard)
# 1724. checking-existence-of-edge-length-limited-paths-ii (Hard)

# %% [markdown]
# 1725. [Number Of Rectangles That Can Form The Largest Square](Easy/Array/1725.number-of-rectangles-that-can-form-the-largest-square.ipynb)
# 1726. [Tuple with Same Product](Medium/Bread-First-Search/1726.tuple-with-same-product.ipynb)
# 1727. [Largest Submatrix With Rearrangements](Medium/Dynamic-Programming/1727.largest-submatrix-with-rearrangements.ipynb)
# 1728. Cat and Mouse II (Hard)
# 1729. (Not algo)
# 1730. Shortest Path to Get Food (Medium, Locked)
# 1731. (Not algo)
# 1732. [Find the Highest Altitude](Easy/Cumsum/1732.find-the-highest-altitude.ipynb)
# 1733. [Minimum Number of People to Teach](Medium/Array/1733.minimum-number-of-people-to-teach.ipynb)
# 1734. [Decode XORed Permutation](Medium/Bit-Manipulation/1734.decode-XORed-permutation.ipynb)
# 1735. Count Ways to Make Array With Product (Hard)
# 1736. [Latest Time by Replacing Hidden Digits](Easy/String/1736.latest-time-by-replacing-hidden-digits.ipynb)
# 1737. [Change Minimum Characters to Satisfy One of Three Conditions](Medium/Cumsum/1737.change-minimum-characters-to-satisfy-one-of-three-conditions.ipynb)
# 1738. [Find Kth Largest XOR Coordinate Value](Medium/Dynamic-Programming/Double-Sequence/1738.find-Kth-largest-XOR-coordinate-value.ipynb)
# 1739. Building Boxes (Hard)
# 1740. Find Distance in a Binary Tree (Medium, Locked)
# 1741. (Not algo)
# 1742. [Maximum Number of Balls in a Box](Easy/Hash-Table/1742.maximum-number-of-balls-in-a-box.ipynb)

# %% [markdown]
# 1743. [Restore the Array From Adjacent Pairs](Medium/Array/1743.restore-the-array-from-adjacent-pairs.ipynb)
# 1744. [Can You Eat Your Favorite Candy on Your Favorite Day?](Medium/Cumsum/1744.can-you-eat-your-favorite-candy-on-your-favorite-day.ipynb)
# 1745. Palindrome Partitioning IV (Hard)
# 1746. maximum-subarray-sum-after-one-operation (Medium, Locked)
# 1747. (Not algo)
# 1748. [Sum of Unique Elements](Easy/Hash-Table/1748.sum-of-unique-elements.ipynb)
# 1749. [Maximum Absolute Sum of Any Subarray](Medium/Dynamic-Programming/Sequence/1749.maximum-absolute-sum-of-any-subarray.ipynb)
# 1750. [Minimum Length of String After Deleting Similar Ends](Medium/Two-Pointers/Converging-Two-Pointers/1750.minimum-length-of-string-after-deleting-similar-ends.ipynb)
# 1751. Maximum Number of Events That Can Be Attended II (Hard)
# 1752. [Check if Array Is Sorted and Rotated](Easy/Array/1752.check-if-array-is-sorted-and-rotated.ipynb)
# 1753. [Maximum Score From Removing Stones](Medium/Greedy/1753.maximum-score-from-removing-stones.ipynb)
# 1754. [Largest Merge Of Two Strings](Medium/Two-Pointers/Racing-Two-Pointers/1753.maximum-score-from-removing-stones.ipynb)
# 1755. Closest Subsequence Sum (Hard)
# 1756. design-most-recently-used-queue (Medium, Locked)
# 1757. (Not algo)
# 1758. [Minimum Changes To Make Alternating Binary String](Easy/Array/1758.minimum-changes-to-make-alternating-binary-string.ipynb)
# 1759. [Count Number of Homogenous Substrings](Medium/Two-Pointers/Chasing-Two-Pointers/1759.count-number-of-homogenous-substrings.ipynb)
# 1760. [Minimum Limit of Balls in a Bag](Medium/Binary-Search/1760.minimum-limit-of-balls-in-a-bag.ipynb)
# 1761. Minimum Degree of a Connected Trio in a Graph (Hard)
# 1762. buildings-with-an-ocean-view (Medium, Locked)

# %% [markdown]
# 1763. [Longest Nice Substring](Easy/String/1763.longest-nice-substring.ipynb)
# 1764. [Form Array by Concatenating Subarrays of Another Array](Medium/Two-Pointers/Chasing-Two-Pointers/1764.form-array-by-concatenating-subarrays-of-another-array.ipynb)
# 1765. [Map of Highest Peak](Medium/Breadth-First-Search/Queue-Implementation/1765.map-of-highest-peak.ipynb)
# 1766. Tree of Coprimes (Hard)
# 1767. (Not algo)
# 1768. [Merge Strings Alternately](Easy/String/1768.merge-strings-alternately.ipynb)
# 1769. [Minimum Number of Operations to Move All Balls to Each Box](Medium/Array/1769.minimum-number-of-operations-to-move-all-balls-to-each-box.ipynb)
# 1770. [Maximum Score from Performing Multiplication Operations](Medium/Dynamic-Programming/Sequence/1770.maximum-score-from-performing-multiplication-operations.ipynb)
# 1771. Maximize Palindrome Length From Subsequences (Hard)
# 1772. sort-features-by-popularity (Medium, Locked)
# 1773. [Count Items Matching a Rule](Easy/Array/1773.count-items-matching-a-rule.ipynb)
# 1774. [Closest Dessert Cost](Medium/Dynamic-Programming/Backpack/1774.closest-dessert-cost.ipynb)
# 1775. [Equal Sum Arrays With Minimum Number of Operations](Medium/Greedy/1775.equal-sum-arrays-with-minimum-number-of-operations.ipynb)
# 1776. Car Fleet II (Hard)
# 1777. (Not algo)
# 1778. shortest-path-in-a-hidden-grid (Medium, Locked)
# 1779. [Find Nearest Point That Has the Same X or Y Coordinate](Easy/Array/1779.find-nearest-point-that-has-the-same-X-or-Y-coordinate.ipynb)
# 1780. [Check if Number is a Sum of Powers of Three](Medium/Maths/1780.check-if-number-is-a-sum-of-powers-of-three.ipynb)
# 1781. [Sum of Beauty of All Substrings](Medium/String/1781.sum-of-beauty-of-all-substrings.ipynb)
# 1782. Count Pairs Of Nodes (Hard)
# 1783. (Not algo)
# 1784. [Check if Binary String Has at Most One Segment of Ones](Easy/String/1784.check-if-binary-string-has-at-most-one-segment-of-ones.ipynb)
# 1785. [Minimum Elements to Add to Form a Given Sum](Medium/Greedy/1785.minimum-elements-to-add-to-form-a-given-sum.ipynb)
# 1786. [Number of Restricted Paths From First to Last Node](Medium/Depth-First-Search/1786.number-of-restricted-paths-from-first-to-last-node.ipynb)
# 1787. Make the XOR of All Segments Equal to Zero (Hard)
# 1788. maximize-the-beauty-of-the-garden (Hard, Locked)
# 1789. (Not algo)
# 1790. [Check if One String Swap Can Make Strings Equal](Easy/String/1790.check-if-one-string-swap-can-make-strings-equal.ipynb)
# 1791. [Find Center of Star Graph](Easy/Graph/1791.find-center-of-star-graph.ipynb)
# 1792. [Maximum Average Pass Ratio](Medium/Heap/1792.maximum-average-pass-ratio.ipynb)
# 1793. Maximum Score of a Good Subarray (Hard)
# 1794. count-pairs-of-equal-substrings-with-minimum-difference (Medium, Locked)
# 1795. (Not algo)
# 1796. [Second Largest Digit in a String](Easy/String/1796.second-largest-digit-in-a-string.ipynb)
# 1797. [Design Authentication Manager](Medium/Design/1797.design-authentication-manager.ipynb)
# 1798. [Maximum Number of Consecutive Values You Can Make](Medium/Maths/1798.maximum-number-of-consecutive-values-you-can-make.ipynb)
# 1799. Maximize Score After N Operations (Hard)
# 1800. [Maximum Ascending Subarray Sum](Easy/Two-Pointers/Chasing-Two-Pointers/1800.maximum-ascending-subarray-sum.ipynb)

# %% [markdown]
# 1801. [Number of Orders in the Backlog](Medium/Heap/1801.number-of-orders-in-the-backlog.ipynb)
# 1802. [Maximum Value at a Given Index in a Bounded Array](Medium/Binary-Search/1802.maximum-value-at-a-given-index-in-a-bounded-array.ipynb)
# 1803. Count Pairs With XOR in a Range (Hard)
# 1804. implement-trie-ii-prefix-tree (Medium, Locked)
# 1805. [Number of Different Integers in a String](Easy/String/1805.number-of-different-integers-in-a-string.ipynb)
# 1806. [Minimum Number of Operations to Reinitialize a Permutation](Medium/Array/1806.minimum-number-of-operations-to-reinitialize-a-permutation.ipynb)
# 1807. [Evaluate the Bracket Pairs of a String](Medium/String/1807.evaluate-the-bracket-pairs-of-a-string.ipynb)
# 1808. Maximize Number of Nice Divisors (Hard)
# 1809. (Not algo)
# 1810. minimum-path-cost-in-a-hidden-grid (Medium, Locked)
# 1811. (Not algo)
# 1812. [Determine Color of a Chessboard Square](Easy/Array/1812.determine-color-of-a-chessboard-square.ipynb)
# 1813. [Sentence Similarity III](Medium/String/1813.sentence-similarity-III.ipynb)
# 1814. [Count Nice Pairs in an Array](Medium/String/1814.count-nice-pairs-in-an-array.ipynb)
# 1815. Maximum Number of Groups Getting Fresh Donuts (Hard)
# 1816. [Truncate Sentence](Easy/String/1816.truncate-sentence.ipynb)
# 1817. [Finding the Users Active Minutes](Medium/Array/1817.finding-the-users-active-minutes.ipynb)
# 1818. [Minimum Absolute Sum Difference](Medium/Binary-Search/1818.minimum-absolute-sum-difference.ipynb)
# 1819. Number of Different Subsequences GCDs (Hard)
# 1820. maximum-number-of-accepted-invitations (Medium, Locked)
# 1821. (Not algo)

# %% [markdown]
# 1822. [Sign of the Product of an Array](Easy/Array/1822.sign-of-the-product-of-an-array.ipynb)
# 1823. [Find the Winner of the Circular Game](Medium/Array/1823.find-the-winner-of-the-circular-game.ipynb)
# 1824. [Minimum Sideway Jumps](Medium/Dynamic-Programming/Sequence/1824.minimum-sideway-jumps.ipynb)
# 1825. Finding MK Average (Hard)
# 1826. Faulty Sensor (Easy, Locked)
# 1827. [Minimum Operations to Make the Array Increasing](Easy/Array/1827.minimum-operations-to-make-the-array-increasing.ipynb)
# 1828. [Queries on Number of Points Inside a Circle](Medium/Maths/1828.queries-on-number-of-points-inside-a-circle.ipynb)
# 1829. [Maximum XOR for Each Query](Medium/Bit-Manipulation/1829.maximum-XOR-for-each-query.ipynb)
# 1830. Minimum Number of Operations to Make String Sorted (Hard)
# 1831. (Not algo)
# 1832. [Check if the Sentence Is Pangram](Easy/String/1832.check-if-the-sentence-is-pangram.ipynb)
# 1833. [Maximum Ice Cream Bars](Medium/Binary-Search/1833.maximum-ice-cream-bars.ipynb)
# 1834. [Single-Threaded CPU](Medium/Heap/1834.single-threaded-CPU.ipynb)
# 1835. Find XOR Sum of All Pairs Bitwise AND (Hard)
# 1836. remove-duplicates-from-an-unsorted-linked-list (Medium, Locked)
# 1837. [Sum of Digits in Base K](Easy/Maths/1837.sum-of-digits-in-base-K.ipynb)
# 1838. [Frequency of the Most Frequent Element](Medium/Two-Pointers/Chasing-Two-Pointers/1838.frequency-of-the-most-frequent-element.ipynb)
# 1839. [Longest Substring Of All Vowels in Order](Medium/Two-Pointers/Chasing-Two-Pointers/1839.longest-substring-of-all-vowels-in-order.ipynb)
# 1840. Maximum Building Height (Hard)
# 1841. (Not algo)
# 1842. next-palindrome-using-same-digits (Hard, Locked)
# 1843. (Not algo)
# 1844. [Replace All Digits with Characters](Easy/String/1844.replace-all-digits-with-characters.ipynb)

# %% [markdown]
# 1845. [Seat Reservation Manager](Medium/Heap/1845.seat-reservation-manager.ipynb)
# 1846. [Maximum Element After Decreasing and Rearranging](Medium/Maths/1846.maximum-element-after-decreasing-and-rearranging.ipynb)
# 1847. Closest Room (Hard)
# 1848. [Minimum Distance to the Target Element](Easy/Array/1848.minimum-distance-to-the-target-element.ipynb)
# 1849. [Splitting a String Into Descending Consecutive Values](Medium/Depth-First-Search/1849.splitting-a-string-into-descending-consecutive-values.ipynb)
# 1850. [Minimum Adjacent Swaps to Reach the Kth Smallest Number](Medium/Array/1850.minimum-adjacent-swaps-to-reach-the-Kth-smallest-number.ipynb)
# 1851. Minimum Interval to Include Each Query (Hard)
# 1852. distinct-numbers-in-each-subarray (Medium, Locked)
# 1853. (Not algo)
# 1854. [Maximum Population Year](Easy/Hash-Table/1854.maximum-population-year.ipynb)
# 1855. [Maximum Distance Between a Pair of Values](Medium/Two-Pointers/Racing-Two-Pointers/1855.maximum-distance-between-a-pair-of-values.ipynb)
# 1856. [Maximum Subarray Min-Product](Medium/Stack/Monotonic-Stack/1856.maximum-subarray-min-product.ipynb)
# 1857. Largest Color Value in a Directed Graph (Hard)
# 1858. longest-word-with-all-prefixes (Medium, Locked)
# 1859. [Sorting the Sentence](Easy/String/1859.sorting-the-sentence.ipynb)
# 1860. [Incremental Memory Leak](Medium/Array/1860.incremental-memory-leak.ipynb)

# %% [markdown]
# 1861. [Rotating the Box](Medium/Array/1861.rotating-the-box.ipynb)
# 1862. Sum of Floored Pairs (Hard)
# 1863. [Sum of All Subset XOR Totals](Easy/Bit-Manipulation/1863.sum-of-all-subset-XOR-totals.ipynb)
# 1864. [Minimum Number of Swaps to Make the Binary String Alternating](Medium/Greedy/1864.minimum-number-of-swaps-to-make-the-binary-string-alternating.ipynb)
# 1865. [Finding Pairs With a Certain Sum](Easy/Design/1865.finding-pairs-with-a-certain-sum.ipynb)
# 1866. Number of Ways to Rearrange Sticks With K Sticks Visible (Hard)
# 1867. (Not algo)
# 1868. product-of-two-run-length-encoded-arrays (Medium, Locked)
# 1869. [Longer Contiguous Segments of Ones than Zeros](Easy/Array/1869.longer-contiguous-segments-of-ones-than-zeros.ipynb)
# 1870. [Minimum Speed to Arrive on Time](Medium/Binary-Search/1870.minimum-speed-to-arrive-on-time.ipynb)
# 1871. [Jump Game VII](Medium/Dynamic-Programming/Sequence/1871.jump-game-VII.ipynb)
# 1872. Stone Game VIII (Hard)
# 1873. (Not algo)
# 1874. minimize-product-sum-of-two-arrays (Medium, Locked)
# 1875. (Not algo)
# 1876. [Substrings of Size Three with Distinct Characters](Easy/Hash-Table/1876.substrings-of-size-three-with-distinct-characters.ipynb)
# 1877. [Minimize Maximum Pair Sum in Array](Medium/Greedy/1877.minimize-maximum-pair-sum-in-array.ipynb)
# 1878. [Get Biggest Three Rhombus Sums in a Grid](Medium/Array/1878.get-biggest-three-rhombus-sums-in-a-grid.ipynb)
# 1879. Minimum XOR Sum of Two Arrays (Hard)

# %% [markdown]
# 1880. [Check if Word Equals Summation of Two Words](Easy/String/1880.check-if-word-equals-summation-of-two-words.ipynb)
# 1881. [Maximum Value after Insertion](Medium/Greedy/1881.maximum-value-after-insertion.ipynb)
# 1882. [Process Tasks Using Servers](Medium/Heap/1882.process-tasks-using-servers.ipynb)
# 1883. Minimum Skips to Arrive at Meeting On Time (Hard)
# 1884. [Egg Drop With 2 Eggs and N Floors](Medium/Maths/1884.egg-drop-with-2-eggs-and-N-floors.ipynb)
# 1885. count-pairs-in-two-arrays (Medium, Locked)
# 1886. [Determine Whether Matrix Can Be Obtained By Rotation](Medium/Array/1886.determine-whether-matrix-can-be-obtained-by-rotation.ipynb)
# 1887. [Reduction Operations to Make the Array Elements Equal](Medium/Array/1887.reduction-operations-to-make-the-array-elements-equal.ipynb)
# 1888. [Minimum Number of Flips to Make the Binary String Alternating](Medium/Greedy/1888.minimum-number-of-flips-to-make-the-binary-string-alternating.ipynb)
# 1889. Minimum Space Wasted From Packaging (Hard)
# 1890. (Not algo)
# 1891. Cutting Ribbons (Medium, Locked)
# 1892. (Not algo)
# 1893. [Check if All the Integers in a Range Are Covered](Easy/Cumsum/1893.check-if-all-the-integers-in-a-range-are-covered.ipynb)

# %% [markdown]
# 1894. [Find the Student that Will Replace the Chalk](Medium/Binary-Search/1894.find-the-student-that-will-replace-the-chalk.ipynb)
# 1895. [Largest Magic Square](Medium/Cumsum/1895.largest-magic-square.ipynb)
# 1896. Minimum Cost to Change the Final Value of Expression (Hard)
# 1897. [Redistribute Characters to Make All Strings Equal](Easy/Array/1897.redistribute-characters-to-make-all-strings-equal.ipynb)
# 1898. [Maximum Number of Removable Characters](Medium/Binary-Search/1898.maximum-number-of-removable-characters.ipynb)
# 1899. [Merge Triplets to Form Target Triplet](Medium/Array/1899.merge-triplets-to-form-target-triplet.ipynb)
# 1900. The Earliest and Latest Rounds Where Players Compete (Hard)
# 1901. [Find a Peak Element II](Medium/Binary-Search/1901.find-a-peak-element-II.ipynb)
# 1902. depth-of-bst-given-insertion-order (Medium, Locked)
# 1903. [Largest Odd Number in String](Easy/Maths/1903.largest-odd-number-in-string.ipynb)
# 1904. [The Number of Full Rounds You Have Played](Medium/Maths/1904.the-number-of-full-rounds-you-have-played.ipynb)
# 1905. [Count Sub Islands](Medium/Depth-First-Search/1905.count-sub-islands.ipynb)
# 1906. [Minimum Absolute Difference Queries](Medium/Cumsum/1906.minimum-absolute-difference-queries.ipynb)
# 1907. (Not algo)
# 1908. game-of-nim (Medium, Locked)
# 1909. [Remove One Element to Make the Array Strictly Increasing](Easy/Array/1909.remove-one-element-to-make-the-array-strictly-increasing.ipynb)
# 1910. [Remove All Occurrences of a Substring](Medium/String/1910.remove-all-occurrences-of-a-substring.ipynb)
# 1911. [Maximum Alternating Subsequence Sum](Medium/Dynamic-Programming/Sequence/1911.maximum-alternating-subsequence-sum.ipynb)
# 1912. Design Movie Rental System (Hard)
# 1913. [Maximum Product Difference Between Two Pairs](Easy/Heap/1913.maximum-product-difference-between-two-pairs.ipynb)

# %% [markdown]
# 1914. [Cyclically Rotating a Grid](Medium/Array/1914.cyclically-rotating-a-grid.ipynb)
# 1915. [Number of Wonderful Substrings](Medium/Cumsum/1915.number-of-wonderful-substrings.ipynb)
# 1916. Count Ways to Build Rooms in an Ant Colony (Hard)
# 1917. (Not algo)
# 1918. kth-smallest-subarray-sum (Medium, Locked)
# 1919. (Not algo)
# 1920. [Build Array from Permutation](Easy/Array/1920.build-array-from-permutation.ipynb)
# 1921. [Eliminate Maximum Number of Monsters](Medium/Sort/1921.eliminate-maximum-number-of-monsters.ipynb)
# 1922. [Count Good Numbers](Medium/Maths/1922.count-good-numbers.ipynb)
# 1923. Longest Common Subpath (Hard)
# 1924. Erect the Fence II (Hard, Locked)
# 1925. [Count Square Sum Triples](Easy/Maths/1925.count-square-sum-triples.ipynb)
# 1926. [Nearest Exit from Entrance in Maze](Medium/Breadth-First-Search/Shortest-Path/1926.nearest-exit-from-entrance-in-maze.ipynb)
# 1927. [Sum Game](Medium/Maths/1927.sum-game.ipynb)
# 1928. Minimum Cost to Reach Destination in Time (Hard)
# 1929. [Concatenation of Array](Easy/Array/1929.concatenation-of-array.ipynb)
# 1930. [Unique Length-3 Palindromic Subsequences](Medium/Hash-Table/1930.unique-length-3-palindromic-subsequences.ipynb)
# 1931. Painting a Grid With Three Different Colors (Hard)
# 1932. Merge BSTs to Create Single BST (Hard)
# 1933. check-if-string-is-decomposable-into-value-equal-substrings (Easy, Locked)
# 1934. (Not algo)

# %% [markdown]
# 1935. [Maximum Number of Words You Can Type](Easy/String/1935.maximum-number-of-words-you-can-type.ipynb)
# 1936. [Add Minimum Number of Rungs](Medium/Greedy/1936.add-minimum-number-of-rungs.ipynb)
# 1937. [Maximum Number of Points with Cost](Medium/Dynamic-Programming/Sequence/1937.maximum-number-of-points-with-cost.ipynb)
# 1938. Maximum Genetic Difference Query (Hard)
# 1939. (Not algo)
# 1940. longest-common-subsequence-between-sorted-arrays (Medium, Locked)
# 1941. [Check if All Characters Have Equal Number of Occurrences](Easy/Hash-Table/1941.check-if-all-characters-have-equal-number of-occurrences.ipynb)
# 1942. [The Number of the Smallest Unoccupied Chair](Medium/Heap/1942.the-number-of-the-smallest-unoccupied-chair.ipynb)
# 1943. [Describe the Painting](Medium/Cumsum/1943.describe-the-painting.ipynb)
# 1944. Number of Visible People in a Queue (Hard)
# 1945. [Sum of Digits of String After Convert](Easy/String/1945.sum-of-digits-of-string-after-convert.ipynb)
# 1946. [Largest Number After Mutating Substring](Medium/Greedy/1946.largest-number-after-mutating-substring.ipynb)
# 1947. [Maximum Compatibility Score Sum](Medium/Dynamic-Programming/Cached-Search/1947.maximum-compatibility-score-sum.ipynb)
# 1948. Delete Duplicate Folders in System (Hard)
# 1949. (Not algo)
# 1950. maximum-of-minimum-values-in-all-subarrays (Medium, Locked)
# 1951. (Not algo)
# 1952. [Three Divisors](Easy/Maths/1952.three-divisors.ipynb)

# %% [markdown]
# 1953. [Maximum Number of Weeks for Which You Can Work](Medium/Greedy/1953.maximum-number-of-weeks-for-which-you-can-work.ipynb)
# 1954. [Minimum Garden Perimeter to Collect Enough Apples](Medium/Binary-Search/1954.minimum-garden-perimeter-to-collect-enough-apples.ipynb)
# 1955. Count Number of Special Subsequences (Hard)
# 1956. minimum-time-for-k-virus-variants-to-spread (Hard, Locked)
# 1957. [Delete Characters to Make Fancy String](Easy/Greedy/1957.delete-characters-to-make-fancy-string.ipynb)
# 1958. [Check if Move is Legal](Medium/Array/1958.check-if-move-is-legal.ipynb)
# 1959. [Minimum Total Space Wasted With K Resizing Operations](Medium/Dynamic-Programming/Sequence/1959.minimum-total-space-wasted-with-K-resizing-operations.ipynb)
# 1960. Maximum Product of the Length of Two Palindromic Substrings (Hard)
# 1961. [Check If String Is a Prefix of Array](Easy/String/1961.check-if-string-is-a-prefix-of-array.ipynb)
# 1962. [Remove Stones to Minimize the Total](Medium/Heap/1962.remove-stones-to-minimize-the-total.ipynb)
# 1963. [Minimum Number of Swaps to Make the String Balanced](Medium/Stack/1963.minimum-number-of-swaps-to-make-the-string-balanced.ipynb)
# 1964. Find the Longest Valid Obstacle Course at Each Position (Hard)
# 1965. binary-searchable-numbers-in-an-unsorted-array (Medium, Locked)
# 1966. (Not algo)
# 1967. [Number of Strings That Appear as Substrings in Word](Easy/String/1967.number-of-strings-that-appear-as-substrings-in-word.ipynb)
# 1968. [Array With Elements Not Equal to Average of Neighbors](Medium/Sort/1968.array-with-elements-not-equal-to-average-of-neighbors.ipynb)

# %% [markdown]
# 1969. [Minimum Non-Zero Product of the Array Elements](Medium/Maths/1969.minimum-non-zero-product-of-the-array-elements.ipynb)
# 1970. Last Day Where You Can Still Cross (Hard)
# 1971. [Find if Path Exists in Graph](Medium/Breadth-First-Search/Shortest-Path/1971.find-if-path-exists-in-graph.ipynb)
# 1972. (Not algo)
# 1973. count-nodes-equal-to-sum-of-descendants (Medium, Locked)
# 1974. [Minimum Time to Type Word Using Special Typewriter](Easy/Greedy/1974.minimum-time-to-type-word-using-special-typewriter.ipynb)
# 1975. [Maximum Matrix Sum](Medium/Greedy/1975.maximum-matrix-sum.ipynb)
# 1976. [Number of Ways to Arrive at Destination](Medium/Breadth-First-Search/Shortest-Path/1976.number-of-ways-to-arrive-at-destination.ipynb)
# 1977. Number of Ways to Separate Numbers (Hard)
# 1978. (Not algo)
# 1979. [Find Greatest Common Divisor of Array](Easy/Maths/1979.find-greatest-common-divisor-of-array.ipynb)
# 1980. [Find Unique Binary String](Medium/Bit-Manipulation/1980.find-unique-binary-string.ipynb)
# 1981. [Minimize the Difference Between Target and Chosen Elements](Medium/Dynamic-Programming/Sequence/1981.minimize-the difference-between-target-and-chosen-elements.ipynb)
# 1982. Find Array Given Subset Sums (Hard)
# 1983. widest-pair-of-indices-with-equal-range-sum (Medium, Locked)
# 1984. [Minimum Difference Between Highest and Lowest of K Scores](Easy/Sorting/1984.minimum-difference-between-highest-and-lowest-of-K-scores.ipynb)
# 1985. [Find the Kth Largest Integer in the Array](Easy/Heap/1985.find-the-Kth-largest-integer-in-the-array.ipynb)

# %% [markdown]
# 1986. [Minimum Number of Work Sessions to Finish the Tasks](Medium/Dynamic-Programming/Cached-Search/1986.minimum-number-of-work-sessions-to-finish-the-tasks.ipynb)
# 1987. Number of Unique Good Subsequences (Hard)
# 1988. (Not algo)
# 1989. maximum-number-of-people-that-can-be-caught-in-tag (Medium, Locked)
# 1990. (Not algo)
# 1991. [Find the Middle Index in Array](Easy/Array/1991.find-the-middle-index-in-array.ipynb)
# 1992. [Find All Groups of Farmland](Medium/Depth-First-Search/1992.find-all-groups-of-farmland.ipynb)
# 1993. [Operations on Tree](Medium/Design/1993.operations-on-tree.ipynb)
# 1994. The Number of Good Subsets (Hard)
# 1995. [Count Special Quadruplets](Easy/Array/1995.count-special-quadruplets.ipynb)
# 1996. [The Number of Weak Characters in the Game](Medium/Stack/Monotonic-Stack/1996.the-number-of-weak-characters-in-the-game.ipynb)
# 1997. [First Day Where You Have Been in All the Rooms](Medium/Dynamic-Programming/Sequence/1997.first-day-where-you-have-been-in-all-the-rooms.ipynb)
# 1998. GCD Sort of an Array (Hard)
# 1999. smallest-greater-multiple-made-of-two-digits (Medium, Locked)
# 2000. [Reverse Prefix of Word](Easy/String/2000.reverse-prefix-of-word.ipynb)
# 2001. [Number of Pairs of Interchangeable Rectangles](Medium/Hash-Table/2001.number-of-pairs-of-interchangeable-rectangles.ipynb)
# 2002. [Maximum Product of the Length of Two Palindromic Subsequences](Medium/Dynamic-Programming/Cached-Search/2002.maximum-product-of-the-length-of-two-palindromic-subsequences.ipynb)
# 2003. Smallest Missing Genetic Value in Each Subtree (Hard)
# 2004. (Not algo)
# 2005. subtree-removal-game-with-fibonacci-tree (Hard, Locked)

# %% [markdown]
# 2006. [Count Number of Pairs With Absolute Difference K](Easy/Array/2006.count-number-of-pairs-with-absolute-difference-K.ipynb)
# 2007. [Find Original Array From Doubled Array](Medium/Sort/2007.find-original-array-from-doubled-array.ipynb)
# 2008. [Maximum Earnings From Taxi](Medium/Dynamic-Programming/Sequence/2008.maximum-earnings-from-taxi.ipynb)
# 2009. Minimum Number of Operations to Make Array Continuous (Hard)
# 2010. (Not algo)
# 2011. [Final Value of Variable After Performing Operations](Easy/String/2011.final-value-of-variable-after-performing-operations.ipynb)
# 2012. [Sum of Beauty in the Array](Medium/Array/2012.sum-of-beauty-in-the-array.ipynb)
# 2013. [Detect Squares](Medium/Hash-Table/2013.detect-squares.ipynb)
# 2014. Longest Subsequence Repeated k Times (Hard)
# 2015. average-height-of-buildings-in-each-segment (Medium, Locked)
# 2016. [Maximum Difference Between Increasing Elements](Easy/Array/2016.maximum-difference-between-increasing-elements.ipynb)
# 2017. [Grid Game](Medium/Cumsum/2017.grid-game.ipynb)
# 2018. [Check if Word Can Be Placed In Crossword](Medium/String/2018.check-if-word-can-be-placed-in-crossword.ipynb)
# 2019. The Score of Students Solving Math Expression (Hard)
# 2020. (Not algo)
# 2021. brightest-position-on-street (Medium, Locked)
# 2022. [Convert 1D Array Into 2D Array](Easy/Array/2022.convert-1D-array-into-2D-array.ipynb)

# %% [markdown]
# 2023. [Number of Pairs of Strings With Concatenation Equal to Target](Medium/String/2023.number-of-pairs-of-strings-with-concatenation-equal-to-target.ipynb)
# 2024. [Maximize the Confusion of an Exam](Medium/Two-Pointers/Chasing-Two-Pointers/2024.maximize-the-confusion-of-an-exam.ipynb)
# 2025. Maximum Number of Ways to Partition an Array (Hard)
# 2026. (Not algo)
# 2027. [Minimum Moves to Convert String](Easy/Greedy/2027.minimum-moves-to-convert-string.ipynb)
# 2028. [Find Missing Observations](Medium/Maths/2028.find-missing-observations.ipynb)
# 2029. [Stone Game IX](Medium/Maths/2029.stone-game-IX.ipynb)
# 2030. Smallest K-Length Subsequence With Occurrences of a Letter (Hard)
# 2031. [Count Subarrays With More Ones Than Zeros](Medium/Dynamic-Programming/Sequence/2031.count-subarrays-with-more-ones-than-zeros.ipynb)
# 2032. [Two Out of Three](Easy/Hash-Table/2032.two-out-of-three.ipynb)
# 2033. [Minimum Operations to Make a Uni-Value Grid](Medium/Maths/2033.minimum-operations-to-make-a-uni-value-grid.ipynb)
# 2034. [Stock Price Fluctuation](Medium/Binary-Search/2034.stock-price-fluctuation.ipynb)
# 2035. Partition Array Into Two Arrays to Minimize Sum Difference (Hard)
# 2036. [Maximum Alternating Subarray Sum](Medium/Dynamic-Programming/Sequence/2036.maximum-alternating-subarray-sum.ipynb)
#
# (159 + 45 + 0 = 204, unlocked, Phase II concludes)
