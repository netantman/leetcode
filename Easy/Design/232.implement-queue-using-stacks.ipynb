# %% [markdown]
# ## Attempt 1 - Accepted

# %%
class MyQueue:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.stack1=[]
        self.stack2=[]

    def push(self, x: int) -> None:
        """
        Push element x to the back of queue.
        """
        self.stack1.append(x)
        

    def pop(self) -> int:
        """
        Removes the element from in front of queue and returns that element.
        """
        self.stack2=self.stack1[::-1]
        res=self.stack2[-1]
        self.stack2=self.stack2[:-1]
        self.stack1=self.stack2[::-1]
        self.stack2=[]
        return res

    def peek(self) -> int:
        """
        Get the front element.
        """
        self.stack2=self.stack1[::-1]
        res=self.stack2[-1]
        self.stack1=self.stack2[::-1]
        self.stack2=[]
        return res
        

    def empty(self) -> bool:
        """
        Returns whether the queue is empty.
        """
        return len(self.stack1)==0
        


# Your MyQueue object will be instantiated and called as such:
# obj = MyQueue()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.peek()
# param_4 = obj.empty()

# %% [markdown]
# ## Attempt 2 - Accepted

# %%
class MyQueue {
public:
    vector<int> d0; ## how data member is defined
    vector<int> d1; ## vectors are essentially stacks in C++
    
    MyQueue() {
        this->d0 = {};
        this->d1 = {};
    }
    
    void push(int x) {
        this->d1.push_back(x);
    }
    
    int pop() {
        if (this->d0.size() > 0) {
            int res = this->d0.back();
            this->d0.pop_back();
            return res;
        }
        while (this->d1.size() > 0) {
            int curr = this->d1.back();
            this->d1.pop_back();
            this->d0.push_back(curr);
        }
        int res = this->d0.back();
        this->d0.pop_back();
        return res;
    }
    
    int peek() {
        if (this->d0.size() > 0) {
            return this->d0.back();
        }
        while (this->d1.size() > 0) {
            int curr = this->d1.back();
            this->d1.pop_back();
            this->d0.push_back(curr);
        }
        return this->d0.back();
    }
    
    bool empty() {
        return (this->d0.size() < 1) & (this->d1.size() < 1);
    }
};

/**
 * Your MyQueue object will be instantiated and called as such:
 * MyQueue* obj = new MyQueue();
 * obj->push(x);
 * int param_2 = obj->pop();
 * int param_3 = obj->peek();
 * bool param_4 = obj->empty();
 */

# %% [markdown]
# ## Lessons and Thoughts
# - Don't get confused - do you meant for $0$ or $-1$ to be the head of the stack?
